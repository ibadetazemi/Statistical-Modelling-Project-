# %% [markdown]
# # CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
## I had sent a request to CitiBikes using the codes below and I chose New York City

import requests

request_url = 'http://api.citybik.es/v2/networks/citi-bike-nyc'

response = requests.get(request_url)
response.text

## Reading the response from the json file
res_json = response.json()
res_json

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
## Reading the response from the json file
res_json = response.json()
res_json

# %%
{'network': {'company': ['NYC Bike Share, LLC',
   'Motivate International, Inc.',
   'PBSC Urban Solutions'],
  'ebikes': True,
  'gbfs_href': 'https://gbfs.citibikenyc.com/gbfs/gbfs.json',
  'href': '/v2/networks/citi-bike-nyc',
  'id': 'citi-bike-nyc',
  'location': {'city': 'New York, NY',
   'country': 'US',
   'latitude': 40.7143528,
   'longitude': -74.00597309999999},
  'name': 'Citi Bike',
  'stations': [{'empty_slots': 37,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321315,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66de099d-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': '46a983722ee1f51813a6a3eb6534a6e4',
    'latitude': 40.795,
    'longitude': -73.9645,
    'name': 'W 100 St & Manhattan Ave',
    'timestamp': '2023-08-29T15:03:08.482000Z'},
   {'empty_slots': 60,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321276,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 81,
     'uid': 'b94cc90e-9ca2-4471-8371-23be051e0157'},
    'free_bikes': 17,
    'id': '81872dcff5f0e5f1e042aafcc0bab6fd',
    'latitude': 40.7667405590595,
    'longitude': -73.9790689945221,
    'name': '7 Ave & Central Park South',
    'timestamp': '2023-08-29T15:03:08.196000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321251,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': 'a2f71eea-05a2-4fe7-99ab-f74535c880ae'},
    'free_bikes': 1,
    'id': '1ce1f825efba7112c62e0b05624fa501',
    'latitude': 40.676368,
    'longitude': -73.952918,
    'name': 'Bedford Ave & Bergen St',
    'timestamp': '2023-08-29T15:03:07.999000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321336,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '9a40cb60-6ede-4c9e-9d64-dc55cae57f31'},
    'free_bikes': 17,
    'id': '75a634e2473d7e3abf789c09c44fdf26',
    'latitude': 40.751047,
    'longitude': -73.93797,
    'name': '28 St & 41 Ave',
    'timestamp': '2023-08-29T15:03:07.770000Z'},
   {'empty_slots': 27,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321278,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 37,
     'uid': '46bdd925-fb6c-4654-85d8-e0db4da62abf'},
    'free_bikes': 9,
    'id': 'fdb4831d3335a9aea380117ea4f4b81a',
    'latitude': 40.801694,
    'longitude': -73.957145,
    'name': 'Frederick Douglass Blvd & W 112 St',
    'timestamp': '2023-08-29T15:03:08.605000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321335,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '594b4656-9d83-4301-8967-3b92c126531c'},
    'free_bikes': 15,
    'id': '678fea3bb3afe05788a35750358db726',
    'latitude': 40.795508,
    'longitude': -73.941606,
    'name': '3 Ave & E 112 St',
    'timestamp': '2023-08-29T15:03:08.261000Z'},
   {'empty_slots': 69,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321319,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 97,
     'uid': '66ddbd20-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 17,
    'id': '7ca4ed0b4fba2b2fb259ba84bd43e2ad',
    'latitude': 40.7505853470215,
    'longitude': -73.9946848154068,
    'name': '8 Ave & W 31 St',
    'timestamp': '2023-08-29T15:03:08.309000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321335,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '8caf71df-76c3-43fb-be98-d555d2291460'},
    'free_bikes': 10,
    'id': '032adb4e82f406f3e04c4b40c2f43e96',
    'latitude': 40.6794388,
    'longitude': -73.9680438,
    'name': 'Bergen St & Vanderbilt Ave',
    'timestamp': '2023-08-29T15:03:07.993000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321253,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66dbb869-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': 'ca4f75006e50239fd4d3024e2effc750',
    'latitude': 40.6851443,
    'longitude': -73.95380904,
    'name': 'Monroe St & Bedford Ave',
    'timestamp': '2023-08-29T15:03:08.432000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321274,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '60c5a043-1367-4a27-96ee-394ba60e2154'},
    'free_bikes': 12,
    'id': '387d971321c72e3ecba9ceaa2bfac75a',
    'latitude': 40.7557327,
    'longitude': -73.9236611,
    'name': '35 Ave & 37 St',
    'timestamp': '2023-08-29T15:03:08.287000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321290,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66dbbc4a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': '9df6386d8677d42c8ba69a15548e61a7',
    'latitude': 40.73652889,
    'longitude': -74.00618026,
    'name': 'Bank St & Hudson St',
    'timestamp': '2023-08-29T15:03:08.184000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321255,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 80,
     'uid': '66dbbeda-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 76,
    'id': 'ae9a9c4ce9623b172f0ca91825aa0825',
    'latitude': 40.728846,
    'longitude': -74.008591,
    'name': 'Greenwich St & W Houston St',
    'timestamp': '2023-08-29T15:03:07.865000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321288,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66db9cc4-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 18,
    'id': '72394bda9e3303d03667935bc0ecdc47',
    'latitude': 40.71269042,
    'longitude': -73.98776323,
    'name': 'Madison St & Clinton St',
    'timestamp': '2023-08-29T15:03:08.457000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321304,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66db9e99-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 14,
    'id': 'c3a53bb0015652fad12cffb1534c029a',
    'latitude': 40.71782143,
    'longitude': -73.97628939,
    'name': 'Stanton St & Mangin St',
    'timestamp': '2023-08-29T15:03:08.710000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 10,
     'has_ebikes': True,
     'last_updated': 1693321259,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66dba303-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': '2d5ca34d7071296701458ee1a4bf12cd',
    'latitude': 40.69794,
    'longitude': -73.96986848,
    'name': 'Clinton Ave & Flushing Ave',
    'timestamp': '2023-08-29T15:03:07.790000Z'},
   {'empty_slots': 38,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321232,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 61,
     'uid': '66dbc37a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 17,
    'id': 'ac5c956abf7f95a75627664be5d7c200',
    'latitude': 40.71850211,
    'longitude': -73.98329859,
    'name': 'Rivington St & Ridge St',
    'timestamp': '2023-08-29T15:03:07.903000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321290,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 26,
     'uid': '566935d6-4d66-4b42-9822-f2a816e357b9'},
    'free_bikes': 21,
    'id': '07f0bd022f67e8d3c6df62aac6489e4f',
    'latitude': 40.7945663,
    'longitude': -73.9362541,
    'name': 'E 114 St & 1 Ave',
    'timestamp': '2023-08-29T15:03:08.468000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321262,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 37,
     'uid': '66de0cab-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': 'e71577342c522f803be610a89edb38ef',
    'latitude': 40.6747055,
    'longitude': -74.0075572,
    'name': 'Columbia St & Lorraine St',
    'timestamp': '2023-08-29T15:03:09.233000Z'},
   {'empty_slots': 49,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321323,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 55,
     'uid': '66dc41bb-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 2,
    'id': 'a71ac277c068151817eea703b2286b83',
    'latitude': 40.76030096,
    'longitude': -73.99884222,
    'name': '11 Ave & W 41 St',
    'timestamp': '2023-08-29T15:03:08.130000Z'},
   {'empty_slots': 53,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321334,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 58,
     'uid': '66de0bcb-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': '91af89740b1c50290e92bae27bb25b99',
    'latitude': 40.8013434,
    'longitude': -73.9711457439,
    'name': 'Riverside Dr & W 104 St',
    'timestamp': '2023-08-29T15:03:08.663000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321277,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66de103b-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 22,
    'id': '2c17cfae12ac9bb921675bceb0c72184',
    'latitude': 40.67363551341504,
    'longitude': -74.01195555925369,
    'name': 'Dwight St & Van Dyke St',
    'timestamp': '2023-08-29T15:03:09.027000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 8,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 41,
     'uid': '66de0dfd-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 34,
    'id': 'a7df126dc423385450b5a626993a1f1b',
    'latitude': 40.787801,
    'longitude': -73.953559,
    'name': 'E 97 St & Madison Ave',
    'timestamp': '2023-08-29T15:03:07.926000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321303,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 28,
     'uid': '66de0d91-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': 'daa4b5e1cac4dfb931b7e85c44db3339',
    'latitude': 40.6772744,
    'longitude': -73.98282002,
    'name': 'Union St & 4 Ave',
    'timestamp': '2023-08-29T15:03:08.873000Z'},
   {'empty_slots': 23,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321270,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 41,
     'uid': '66de110b-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 17,
    'id': '1b5365e00848878fbaa6cf71c5e231a9',
    'latitude': 40.6765304,
    'longitude': -73.97846879,
    'name': 'Berkeley Pl & 6 Ave',
    'timestamp': '2023-08-29T15:03:07.744000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321235,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'bfbd1f09-afd2-49d2-8674-3a07b3c929a4'},
    'free_bikes': 12,
    'id': '40e1522fdfd3337ac0a5cf5258751815',
    'latitude': 40.71019,
    'longitude': -73.93734,
    'name': 'Waterbury St & Stagg St',
    'timestamp': '2023-08-29T15:03:08.937000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321318,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '66db69d0-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 27,
    'id': '07b25a978540d6aa50b1574f7641d443',
    'latitude': 40.68683208,
    'longitude': -73.9796772,
    'name': '3 Ave & Schermerhorn St',
    'timestamp': '2023-08-29T15:03:07.814000Z'},
   {'empty_slots': 27,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321257,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 34,
     'uid': '66db6889-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 6,
    'id': '88c0b3f44427945e77e67491110d3405',
    'latitude': 40.71406667,
    'longitude': -73.99293911,
    'name': 'Pike St & E Broadway',
    'timestamp': '2023-08-29T15:03:09.300000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 21,
     'has_ebikes': True,
     'last_updated': 1693321334,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 105,
     'uid': '66db65aa-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 87,
    'id': '50e28014a9b46fa320fd816c6af4a49e',
    'latitude': 40.73020660529954,
    'longitude': -73.99102628231049,
    'name': 'Lafayette St & E 8 St',
    'timestamp': '2023-08-29T15:03:08.888000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321339,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '29223935-a682-411c-9f25-577bbb9804fc'},
    'free_bikes': 16,
    'id': 'd8bf2f87cc329894c610360558e9220d',
    'latitude': 40.70539,
    'longitude': -73.92976,
    'name': 'Knickerbocker Ave & Thames St',
    'timestamp': '2023-08-29T15:03:09.122000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321299,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '84a7baff-415b-4ab9-a859-74c2801483ce'},
    'free_bikes': 12,
    'id': 'cf98029721ab6d5a1ccf65cee9cebd1b',
    'latitude': 40.713811,
    'longitude': -73.93515,
    'name': 'Devoe St & Morgan Ave',
    'timestamp': '2023-08-29T15:03:08.755000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321338,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': 'b03adb87-2bd9-43a5-a822-7d06a9ee2d81'},
    'free_bikes': 28,
    'id': 'd2ccf83ad960756b6f73c0b6acddb11c',
    'latitude': 40.706237,
    'longitude': -73.933871,
    'name': 'McKibbin St & Bogart St',
    'timestamp': '2023-08-29T15:03:08.315000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321261,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '3a89411a-0bc6-4ba3-bc56-fab950c8eba1'},
    'free_bikes': 19,
    'id': '010f92292461543f36314829cb02afac',
    'latitude': 40.702831,
    'longitude': -73.9333,
    'name': 'Central Ave & Flushing Ave',
    'timestamp': '2023-08-29T15:03:08.474000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321299,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'd11b9869-8964-4b79-aafc-4b60ad1b44c4'},
    'free_bikes': 1,
    'id': '2923dae1f9c925711be47f55c0180aa3',
    'latitude': 40.700003,
    'longitude': -73.92834,
    'name': 'Central Ave & Starr Street',
    'timestamp': '2023-08-29T15:03:09.336000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321295,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '7af717b9-99ce-4cce-94b4-b445a40537a1'},
    'free_bikes': 9,
    'id': 'd0602c69b366b808ecc3936c206e04bb',
    'latitude': 40.704425,
    'longitude': -73.92836,
    'name': 'Knickerbocker Ave & George St',
    'timestamp': '2023-08-29T15:03:09.137000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321319,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': 'd5d589e6-457f-4cd4-bf78-59165dce28b2'},
    'free_bikes': 17,
    'id': '5b7746fc518ac94da102c0672b9e3184',
    'latitude': 40.7027,
    'longitude': -73.92095,
    'name': 'Irving Ave & DeKalb Ave',
    'timestamp': '2023-08-29T15:03:08.264000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321304,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 28,
     'uid': '66db5c14-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': 'd840fae588435ad6c219db0d4c252447',
    'latitude': 40.69308257,
    'longitude': -73.97178913,
    'name': 'Adelphi St & Myrtle Ave',
    'timestamp': '2023-08-29T15:03:09.242000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 25,
     'has_ebikes': True,
     'last_updated': 1693321335,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 62,
     'uid': '66dd42eb-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 35,
    'id': '6e43cd37a571f8a9bff43fcea0b6d295',
    'latitude': 40.76500525,
    'longitude': -73.95818491,
    'name': '1 Ave & E 68 St',
    'timestamp': '2023-08-29T15:03:07.853000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321316,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 45,
     'uid': '66dd4356-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 19,
    'id': '5ba135e7eb13cb933f2fcaca980276b5',
    'latitude': 40.7612274,
    'longitude': -73.96094022,
    'name': '1 Ave & E 62 St',
    'timestamp': '2023-08-29T15:03:08.705000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321321,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 47,
     'uid': '66dd43bd-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': '91e510ea32dfbee99aa27395695b457d',
    'latitude': 40.77632142182271,
    'longitude': -73.96427392959595,
    'name': '5 Ave & E 78 St',
    'timestamp': '2023-08-29T15:03:08.142000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321256,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66db5d92-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 3,
    'id': '0c31a89981605645db5d73705b766bac',
    'latitude': 40.68650065,
    'longitude': -73.96563307,
    'name': 'Washington Ave & Greene Ave',
    'timestamp': '2023-08-29T15:03:08.435000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321307,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66db5e6a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 5,
    'id': 'f3a68c3b4b6614f7c5c706b96c867386',
    'latitude': 40.69766564,
    'longitude': -73.98476437,
    'name': 'Concord St & Bridge St',
    'timestamp': '2023-08-29T15:03:09.102000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321328,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '915057d4-edbc-4c73-8d81-dda33d600d58'},
    'free_bikes': 0,
    'id': 'fe77d499d0064660a936aa00f1519bb2',
    'latitude': 40.72755146730012,
    'longitude': -74.07106071710587,
    'name': 'Glenwood Ave',
    'timestamp': '2023-08-29T15:03:07.892000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321278,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '43eac213-4603-4bc2-b6d6-b45013396282'},
    'free_bikes': 31,
    'id': '0eb723b81edb20e3c37f880c08349b69',
    'latitude': 40.701403172577244,
    'longitude': -73.98672670125961,
    'name': 'Jay St & York St',
    'timestamp': '2023-08-29T15:03:08.243000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321300,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66de43a5-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': 'b403bf73c64da4222ff782e461c685ea',
    'latitude': 40.7934337,
    'longitude': -73.94945003,
    'name': 'E 106 St & Madison Ave',
    'timestamp': '2023-08-29T15:03:09.249000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321335,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66de4078-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 15,
    'id': '7f71de48a1ae570569fa1246d05f5a7a',
    'latitude': 40.6787242,
    'longitude': -73.99599099,
    'name': 'Smith St & 3 St',
    'timestamp': '2023-08-29T15:03:08.306000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321336,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66de3fde-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': 'd8cc1bee00e38a208fe6a86d56e1899c',
    'latitude': 40.804213,
    'longitude': -73.96699104,
    'name': 'Cathedral Pkwy & Broadway',
    'timestamp': '2023-08-29T15:03:08.101000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321221,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 53,
     'uid': '66de2b2f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 47,
    'id': '41fe4253b2718d27817c0327887bf19a',
    'latitude': 40.6777287,
    'longitude': -73.99364123,
    'name': '3 St & Hoyt St',
    'timestamp': '2023-08-29T15:03:09.215000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 27,
     'has_ebikes': True,
     'last_updated': 1693321280,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 80,
     'uid': '66dc8382-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 77,
    'id': '3b6d288572e702d96fe3a28c150adc1b',
    'latitude': 40.75594159,
    'longitude': -74.0021163,
    'name': 'W 34 St & 11 Ave',
    'timestamp': '2023-08-29T15:03:08.113000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 16,
     'has_ebikes': True,
     'last_updated': 1693321320,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 60,
     'uid': '66dc840f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 31,
    'id': '6563287f413683fd05df03545ae7dc07',
    'latitude': 40.74765947,
    'longitude': -73.98490707,
    'name': 'E 33 St & 5 Ave',
    'timestamp': '2023-08-29T15:03:08.704000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 23,
     'has_ebikes': True,
     'last_updated': 1693321285,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 75,
     'uid': '66dc81ce-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 72,
    'id': '794d5d269c3cec97db767f747a12594f',
    'latitude': 40.75714758,
    'longitude': -73.97207836,
    'name': 'E 51 St & Lexington Ave',
    'timestamp': '2023-08-29T15:03:08.155000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321310,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 57,
     'uid': '66dc8527-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 50,
    'id': '80e56214df3108c1777ec61c3a79a63b',
    'latitude': 40.74290902,
    'longitude': -73.97706058,
    'name': '2 Ave & E 31 St',
    'timestamp': '2023-08-29T15:03:08.536000Z'},
   {'empty_slots': 28,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321283,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': 'add829db-2feb-4e81-af61-056791a6e53b'},
    'free_bikes': 0,
    'id': '810be6dc6e1af5fd4e2c3853f9c5d7ed',
    'latitude': 40.6737236,
    'longitude': -73.9631611,
    'name': 'St Johns Pl & Washington Ave',
    'timestamp': '2023-08-29T15:03:08.691000Z'},
   {'empty_slots': 22,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321289,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': 'c83e1ef5-776e-417e-8ee2-d08ca121f884'},
    'free_bikes': 0,
    'id': 'a7638c15dde84c27b842458a7aa12d6a',
    'latitude': 40.6740123,
    'longitude': -73.9671457,
    'name': 'Underhill Ave & Lincoln Pl',
    'timestamp': '2023-08-29T15:03:08.140000Z'},
   {'empty_slots': 27,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321303,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 28,
     'uid': '2b54cb2c-31be-4620-a13c-0fa72b58c90a'},
    'free_bikes': 0,
    'id': 'b298d4e026b8cace01b5c031c9c0a8bd',
    'latitude': 40.6721683,
    'longitude': -73.9609,
    'name': 'Lincoln Pl & Classon Ave',
    'timestamp': '2023-08-29T15:03:08.850000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321306,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '17aeb1e3-fd18-4cf9-9473-17dfa5b0a312'},
    'free_bikes': 2,
    'id': 'd577ae3fa5542a100948e4c54cba8f18',
    'latitude': 40.6691783,
    'longitude': -73.9554162,
    'name': 'Union St & Bedford Ave',
    'timestamp': '2023-08-29T15:03:08.272000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321322,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'ec42fb3a-af54-46aa-a8b3-b17d72ed4475'},
    'free_bikes': 15,
    'id': 'bf15eefc998dc8bf6d95dc4d4aeb330e',
    'latitude': 40.7638753,
    'longitude': -73.9364848,
    'name': '34 Ave & 13 St',
    'timestamp': '2023-08-29T15:03:08.211000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321234,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66dc192f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 3,
    'id': '4449cb908b55ad07a725cc4c1412baac',
    'latitude': 40.70853074,
    'longitude': -73.96408963,
    'name': 'Bedford Ave & S 9 St',
    'timestamp': '2023-08-29T15:03:08.687000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 17,
     'has_ebikes': True,
     'last_updated': 1693321303,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 46,
     'uid': '66dc17df-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 41,
    'id': '141163c2b3b7cee1e063f53191c19095',
    'latitude': 40.75255434,
    'longitude': -73.97282625,
    'name': 'E 45 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:07.809000Z'},
   {'empty_slots': 97,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321318,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 107,
     'uid': '66dc1beb-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 6,
    'id': 'e99f3e89fa8216f552ec1b01f29e4077',
    'latitude': 40.72740794,
    'longitude': -73.98142006,
    'name': 'E 10 St & Avenue A',
    'timestamp': '2023-08-29T15:03:08.415000Z'},
   {'empty_slots': 24,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321314,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 42,
     'uid': '66dd4772-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 17,
    'id': '177ac66dec88695ba730f8b5d04850db',
    'latitude': 40.76873687,
    'longitude': -73.96119945,
    'name': '3 Ave & E 71 St',
    'timestamp': '2023-08-29T15:03:08.991000Z'},
   {'empty_slots': 44,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321327,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 47,
     'uid': '66dd470b-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 2,
    'id': '1ddfe7ef2cc8b16bda7e139c2ae76d2b',
    'latitude': 40.7728384,
    'longitude': -73.94989233,
    'name': 'E 81 St & York Ave',
    'timestamp': '2023-08-29T15:03:09.351000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321335,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66dd1585-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': 'c7479c9a2a0cc60e199bffe89ad2cbcc',
    'latitude': 40.71924,
    'longitude': -73.95242,
    'name': 'Union Ave & N 12 St',
    'timestamp': '2023-08-29T15:03:08.835000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321326,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 26,
     'uid': '66dd0808-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 5,
    'id': '5f7338a7df326201bdb40c3a305e3fb6',
    'latitude': 40.71929301,
    'longitude': -73.94500379,
    'name': 'Graham Ave & Herbert St',
    'timestamp': '2023-08-29T15:03:08.769000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321318,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66dc1545-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': '8c3b74f9dc3ad4b96966efcf949bdfd7',
    'latitude': 40.68216564,
    'longitude': -73.95399026,
    'name': 'Hancock St & Bedford Ave',
    'timestamp': '2023-08-29T15:03:08.853000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 14,
     'has_ebikes': True,
     'last_updated': 1693321217,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '66dc1687-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': '4a1c8658155444641bdb4e418fa30794',
    'latitude': 40.6809833854,
    'longitude': -73.9500479759,
    'name': 'Macon St & Nostrand Ave',
    'timestamp': '2023-08-29T15:03:08.203000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 7,
     'has_ebikes': True,
     'last_updated': 1693321297,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 74,
     'uid': '66dc120f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 55,
    'id': 'b514523a295a23616e434d2b7fcd308d',
    'latitude': 40.74173969,
    'longitude': -73.99415556,
    'name': 'W 21 St & 6 Ave',
    'timestamp': '2023-08-29T15:03:07.750000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321303,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '2868db5b-df51-4c36-8515-ef77a5b092c2'},
    'free_bikes': 12,
    'id': '7904c5b866ef0c09101e84fdda91e11c',
    'latitude': 40.70538,
    'longitude': -73.92535,
    'name': 'Irving Ave & Jefferson St',
    'timestamp': '2023-08-29T15:03:08.657000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321310,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66db9675-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 22,
    'id': '68d2b9e52ce081a319bdad2514ea2463',
    'latitude': 40.72903917,
    'longitude': -73.99404649,
    'name': 'Washington Pl & Broadway',
    'timestamp': '2023-08-29T15:03:08.572000Z'},
   {'empty_slots': 37,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321336,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 44,
     'uid': '66db95e5-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 6,
    'id': '5f5b167751bfb54c354d9ca2a527f09e',
    'latitude': 40.74238787,
    'longitude': -73.99726235,
    'name': 'W 20 St & 7 Ave',
    'timestamp': '2023-08-29T15:03:09.010000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321295,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66db930d-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': '506ef3941933df4d38b00a3ae3fae8f2',
    'latitude': 40.71173107,
    'longitude': -73.99193043,
    'name': 'Pike St & Monroe St',
    'timestamp': '2023-08-29T15:03:07.890000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 13,
     'has_ebikes': True,
     'last_updated': 1693321305,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 62,
     'uid': '66db90f1-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 44,
    'id': 'b6d8f527e18cf6480eee00936e1b6e82',
    'latitude': 40.71450451,
    'longitude': -74.00562789,
    'name': 'Reade St & Broadway',
    'timestamp': '2023-08-29T15:03:08.249000Z'},
   {'empty_slots': 26,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321254,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 36,
     'uid': '66db93a1-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 6,
    'id': 'a350375466cc6ca0ebb140916c3a2257',
    'latitude': 40.71219906,
    'longitude': -73.97948148,
    'name': 'Cherry St',
    'timestamp': '2023-08-29T15:03:08.366000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321282,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '66dde703-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 11,
    'id': 'c5ae12324e657ff1f5a2a702a573f56a',
    'latitude': 40.686371,
    'longitude': -73.99383324,
    'name': 'Warren St & Court St',
    'timestamp': '2023-08-29T15:03:09.086000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 18,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66dde76a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': 'b8235d3025c1626351d5291f4f5e14b3',
    'latitude': 40.78813,
    'longitude': -73.95206,
    'name': 'E 98 St & Park Ave',
    'timestamp': '2023-08-29T15:03:09.301000Z'},
   {'empty_slots': 32,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321325,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 73,
     'uid': '66dde630-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 38,
    'id': 'ebb1cf8510ded98f7e9ee8cf76a9ea28',
    'latitude': 40.782454175279874,
    'longitude': -73.9489196240902,
    'name': 'E 93 St & 2 Ave',
    'timestamp': '2023-08-29T15:03:08.624000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321310,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '66dde4ef-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 6,
    'id': '0bda8150467a951310434df139d9e32e',
    'latitude': 40.7921,
    'longitude': -73.9739,
    'name': 'W 92 St & Broadway',
    'timestamp': '2023-08-29T15:03:08.621000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321294,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 43,
     'uid': '66dea4bf-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 27,
    'id': '21a780d76029121d494a44fc546334e0',
    'latitude': 40.71915571696044,
    'longitude': -73.94885390996933,
    'name': 'Bayard St & Leonard St',
    'timestamp': '2023-08-29T15:03:08.747000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321298,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66dea52b-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 12,
    'id': '1909fdefee61c79081ff155421ce2448',
    'latitude': 40.71335226222875,
    'longitude': -73.9491033554077,
    'name': 'Devoe St & Lorimer St',
    'timestamp': '2023-08-29T15:03:08.291000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321327,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 34,
     'uid': '7e36cd9b-b271-42e5-b344-b7a3771c795e'},
    'free_bikes': 24,
    'id': '479a4d7c88a5cbea3a6a7d68264808e0',
    'latitude': 40.808442,
    'longitude': -73.9452087,
    'name': 'Lenox Ave & W 126 St',
    'timestamp': '2023-08-29T15:03:08.122000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321228,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '66dea674-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 8,
    'id': 'ca5e1b633e2b93ce75ec83b3cfe316e6',
    'latitude': 40.71638031973561,
    'longitude': -73.94821286201477,
    'name': 'Jackson St & Leonard St',
    'timestamp': '2023-08-29T15:03:08.158000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321291,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '66dea596-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 11,
    'id': 'e8577befa5165b22b8efd20965598772',
    'latitude': 40.7103685423523,
    'longitude': -73.94705951213837,
    'name': 'Leonard St & Maujer St',
    'timestamp': '2023-08-29T15:03:08.317000Z'},
   {'empty_slots': 25,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321263,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '6cd10426-b4e9-40e1-9b35-61f609190ac0'},
    'free_bikes': 10,
    'id': '8f1dd5054688ae4a26aec411780ae2d5',
    'latitude': 40.7711528,
    'longitude': -73.9170074,
    'name': '31 St & Hoyt Ave N',
    'timestamp': '2023-08-29T15:03:09.271000Z'},
   {'empty_slots': 22,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321288,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': 'fc774664-3c9b-4a8f-a79e-f6907db00a1d'},
    'free_bikes': 9,
    'id': 'c05a894b939f7ebc1f999520707aed0a',
    'latitude': 40.7767,
    'longitude': -73.927631,
    'name': 'Astoria Park S & Shore Blvd',
    'timestamp': '2023-08-29T15:03:08.941000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321254,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': 'dccaeeb5-c53a-4f48-80e6-05675b71a8c8'},
    'free_bikes': 21,
    'id': '560ecd2ba03d9e261d4b9d4c8394c929',
    'latitude': 40.809725,
    'longitude': -73.953149,
    'name': 'St Nicholas Ave & Manhattan Ave',
    'timestamp': '2023-08-29T15:03:08.043000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321336,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 26,
     'uid': '66dd7f10-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': 'e886fd011f16b1c5bb33f2acb4e584e9',
    'latitude': 40.7376037,
    'longitude': -74.0524783,
    'name': 'Oakland Ave',
    'timestamp': '2023-08-29T15:03:08.533000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321266,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 26,
     'uid': '66dd7cab-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 3,
    'id': 'f91821d395298c1654b5890bdcb79bec',
    'latitude': 40.7311689,
    'longitude': -74.0575736,
    'name': 'Hilltop',
    'timestamp': '2023-08-29T15:03:08.072000Z'},
   {'empty_slots': 26,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321318,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 26,
     'uid': '66dd7b37-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': 'f6d5f0d1ca571465c335d6970de828f0',
    'latitude': 40.727595966,
    'longitude': -74.044247311,
    'name': 'Hamilton Park',
    'timestamp': '2023-08-29T15:03:08.601000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 10,
     'has_ebikes': True,
     'last_updated': 1693321328,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '66dd6721-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 17,
    'id': '3f07a543eef48fd465a0cbacb379de96',
    'latitude': 40.7272235,
    'longitude': -74.0337589,
    'name': 'Newport PATH',
    'timestamp': '2023-08-29T15:03:09.202000Z'},
   {'empty_slots': 22,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321309,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '66dd7fe2-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': '6fd339c9f7f92b83b2e02cbfb93dd089',
    'latitude': 40.7241765,
    'longitude': -74.0506564,
    'name': 'Brunswick St',
    'timestamp': '2023-08-29T15:03:08.958000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321320,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66dccd65-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 22,
    'id': 'cf31c0e43bed8ac4be38950b620f06d4',
    'latitude': 40.7016657,
    'longitude': -73.9437303,
    'name': 'Broadway & Whipple St',
    'timestamp': '2023-08-29T15:03:08.205000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321253,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 62,
     'uid': '66db3d2a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 41,
    'id': '7e90c995b31039ca8d76eb029e79bd7b',
    'latitude': 40.69196566,
    'longitude': -73.9813018,
    'name': 'Willoughby St & Fleet St',
    'timestamp': '2023-08-29T15:03:08.373000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': 'f841ae52-0bbb-49db-b6eb-f898fbce6108'},
    'free_bikes': 9,
    'id': '2455cde3408d55c05596f2c87ce2730e',
    'latitude': 40.7242941,
    'longitude': -74.0354826,
    'name': 'Washington St',
    'timestamp': '2023-08-29T15:03:08.968000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 12,
     'has_ebikes': True,
     'last_updated': 1693321309,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '2de92329-48d0-4cf7-85df-172f91bbb320'},
    'free_bikes': 17,
    'id': '38db8a3f71cd3fa93df107ecc71582d7',
    'latitude': 40.7192517,
    'longitude': -74.034234,
    'name': 'Harborside',
    'timestamp': '2023-08-29T15:03:08.476000Z'},
   {'empty_slots': 24,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321265,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 37,
     'uid': 'cae4f2f4-9642-474c-95cc-6cc07592f120'},
    'free_bikes': 11,
    'id': 'e59d4e19628c6e90bed3df77eb6d2ab1',
    'latitude': 40.7675487799971,
    'longitude': -73.9209334552288,
    'name': '31 St & Newtown Ave',
    'timestamp': '2023-08-29T15:03:08.236000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321274,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': 'ca4e4962-2169-4559-8f60-b05ab7809750'},
    'free_bikes': 16,
    'id': '87398d0a3d90499cda3701b0f02708ab',
    'latitude': 40.8038654,
    'longitude': -73.9559308,
    'name': 'Frederick Douglass Blvd & W 115 St',
    'timestamp': '2023-08-29T15:03:07.966000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321332,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '66dcca76-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 15,
    'id': 'a51071afa04ac7a5eb1157951a7c94da',
    'latitude': 40.69527008,
    'longitude': -73.95238108,
    'name': 'Nostrand Ave & Myrtle Ave',
    'timestamp': '2023-08-29T15:03:08.158000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321323,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66dcca0d-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 23,
    'id': 'b69d830a701a1fceb2a474097d48c449',
    'latitude': 40.69539817,
    'longitude': -73.94954908,
    'name': 'Myrtle Ave & Marcy Ave',
    'timestamp': '2023-08-29T15:03:09.135000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321275,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '66dcc920-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 15,
    'id': 'cf0e4540220f69ab4064080de80f2675',
    'latitude': 40.69622937,
    'longitude': -73.94371094,
    'name': 'Throop Ave & Myrtle Ave',
    'timestamp': '2023-08-29T15:03:09.050000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321237,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '66db3cab-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 8,
    'id': '663962dd5882cc2a3142fd1f4fc8fc9d',
    'latitude': 40.7361967,
    'longitude': -74.00859207,
    'name': 'Bank St & Washington St',
    'timestamp': '2023-08-29T15:03:09.342000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 11,
     'has_ebikes': True,
     'last_updated': 1693321285,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '66dccc99-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': '9190afca949ebaed2d792aa8b7f0eccc',
    'latitude': 40.70029511,
    'longitude': -73.95032283,
    'name': 'Union Ave & Wallabout St',
    'timestamp': '2023-08-29T15:03:08.960000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321282,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': '66dce4fc-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 11,
    'id': 'df8f52e24c61a15be77c2c6dd3e6e3fb',
    'latitude': 40.70411791,
    'longitude': -73.94818595,
    'name': 'Lorimer St & Broadway',
    'timestamp': '2023-08-29T15:03:08.420000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321230,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 32,
     'uid': '66de1516-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 24,
    'id': '0a0d9d6e93abd05548c672b60bfa9099',
    'latitude': 40.677236,
    'longitude': -74.015665,
    'name': 'Coffey St & Conover St',
    'timestamp': '2023-08-29T15:03:08.579000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 7,
     'has_ebikes': True,
     'last_updated': 1693321323,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 42,
     'uid': '66dce2a4-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 29,
    'id': '5d17ca9635db0c7f367743b299010296',
    'latitude': 40.7031724,
    'longitude': -73.940636,
    'name': 'Humboldt St & Varet St',
    'timestamp': '2023-08-29T15:03:09.273000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321301,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66de1295-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 19,
    'id': 'f3429c91fe2ab4d84ff2dc15caa59076',
    'latitude': 40.6777748,
    'longitude': -74.0094613,
    'name': 'Pioneer St & Richards St',
    'timestamp': '2023-08-29T15:03:08.628000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321315,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 36,
     'uid': '66de14af-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 20,
    'id': 'c2c6d7385a8c127c4ed83d66f868d6d5',
    'latitude': 40.6773429,
    'longitude': -74.01275056,
    'name': 'Van Brunt St & Wolcott St',
    'timestamp': '2023-08-29T15:03:07.911000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321291,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66de1368-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 34,
    'id': '4081ac99ac6fa036539a136ea8bcc645',
    'latitude': 40.679043,
    'longitude': -74.011169,
    'name': 'Pioneer St & Van Brunt St',
    'timestamp': '2023-08-29T15:03:08.481000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321329,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 50,
     'uid': '66db2d2b-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 31,
    'id': 'd840ae5054d55060af7786d28bc291f8',
    'latitude': 40.69239502,
    'longitude': -73.99337909,
    'name': 'Clinton St & Joralemon St',
    'timestamp': '2023-08-29T15:03:08.713000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321326,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 43,
     'uid': 'eafa19ed-88c2-4efc-bd73-3961f85b6063'},
    'free_bikes': 33,
    'id': '461f47defcc688ad14984bb186072d6d',
    'latitude': 40.735445,
    'longitude': -73.99431,
    'name': 'W 13 St & 5 Ave',
    'timestamp': '2023-08-29T15:03:08.931000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321303,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'c72970e7-7f1a-4671-bf55-fc34be7c9413'},
    'free_bikes': 18,
    'id': 'ff2ae7535e4713928b83a5e8fabcae8d',
    'latitude': 40.7437524099784,
    'longitude': -73.94176483154297,
    'name': '47 Ave & Skillman Ave',
    'timestamp': '2023-08-29T15:03:08.864000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 10,
     'has_ebikes': True,
     'last_updated': 1693321234,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 45,
     'uid': '66dd2292-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 37,
    'id': '4bbbed23270a34498c42e1188dcbe9bc',
    'latitude': 40.74232744,
    'longitude': -73.95411749,
    'name': 'Vernon Blvd & 50 Ave',
    'timestamp': '2023-08-29T15:03:08.009000Z'},
   {'empty_slots': 24,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321336,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66dd217d-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': '10bae30699dc4d002884eaffadbc9f15',
    'latitude': 40.73564,
    'longitude': -73.95866,
    'name': 'Franklin St & Dupont St',
    'timestamp': '2023-08-29T15:03:08.238000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321270,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '66dd1eb2-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 24,
    'id': 'e256cfe16e29d02ca42a0bcb84bc57ac',
    'latitude': 40.72906,
    'longitude': -73.95779,
    'name': 'Milton St & Franklin St',
    'timestamp': '2023-08-29T15:03:09.200000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321310,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 28,
     'uid': '66dd1d9c-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 5,
    'id': '63bf84b2b0a1701aa1744fce5ba51690',
    'latitude': 40.72708584,
    'longitude': -73.95299117,
    'name': 'Meserole Ave & Manhattan Ave',
    'timestamp': '2023-08-29T15:03:08.239000Z'},
   {'empty_slots': 27,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321324,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '3f36c26d-c57f-47cc-9672-20f19babb36a'},
    'free_bikes': 7,
    'id': '7275a0e7a9cbe5a5c6fb72acf3fe9a28',
    'latitude': 40.761584,
    'longitude': -73.925921,
    'name': '31 St & Broadway',
    'timestamp': '2023-08-29T15:03:08.795000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321308,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '9d95a4a9-bcfe-4189-bb7d-abd9992ecbaf'},
    'free_bikes': 13,
    'id': '64a28a2c71b7707dbd658fb016f44d85',
    'latitude': 40.7633589,
    'longitude': -73.9286471,
    'name': 'Crescent St & Broadway',
    'timestamp': '2023-08-29T15:03:09.360000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321313,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66de5d57-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 16,
    'id': 'a5c4f1fcc7d877dbfe8b983ad6648b81',
    'latitude': 40.6776147,
    'longitude': -73.97324283,
    'name': '7 Ave & Park Pl',
    'timestamp': '2023-08-29T15:03:08.382000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321277,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 48,
     'uid': '66de542a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 37,
    'id': '9a8d2b588b89023dde9d5d833a86c107',
    'latitude': 40.6867443,
    'longitude': -73.99063168,
    'name': 'Bergen St & Smith St',
    'timestamp': '2023-08-29T15:03:07.847000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321298,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 77,
     'uid': '66de5613-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 54,
    'id': 'b8f8ebf2786573a65dd5c0703e7e956c',
    'latitude': 40.6864442,
    'longitude': -73.98759104,
    'name': 'Dean St & Hoyt St',
    'timestamp': '2023-08-29T15:03:07.746000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321312,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66de56e5-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 17,
    'id': 'e357bb5c3c85cb16915cc4aaf70ee742',
    'latitude': 40.6849668,
    'longitude': -73.98620772,
    'name': 'Bond St & Bergen St',
    'timestamp': '2023-08-29T15:03:08.224000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321299,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 65,
     'uid': '66dc741f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 51,
    'id': '37d6fbbf8cb6fd3bf3beaa5a186357c8',
    'latitude': 40.73726186,
    'longitude': -73.99238967,
    'name': 'E 16 St & 5 Ave',
    'timestamp': '2023-08-29T15:03:08.053000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321312,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '3f878b81-324e-4673-9221-43d34647e76f'},
    'free_bikes': 16,
    'id': 'ccc896fa086291ae165b2f06b0320d4a',
    'latitude': 40.671907,
    'longitude': -73.993612,
    'name': '10 St & 2 Ave',
    'timestamp': '2023-08-29T15:03:08.712000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 9,
     'has_ebikes': True,
     'last_updated': 1693321289,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 32,
     'uid': '5faf99b8-9046-450f-9d2a-d13279b3d016'},
    'free_bikes': 18,
    'id': 'f6bfa1354cdaffd45b300d23b6c7615a',
    'latitude': 40.73520838045357,
    'longitude': -74.04696375131607,
    'name': 'Hoboken Ave at Monmouth St',
    'timestamp': '2023-08-29T15:03:08.136000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693251179,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 0,
     'returning': 0,
     'slots': 37,
     'uid': 'c1c33a35-751f-4dd6-baef-82db46f7ab46'},
    'free_bikes': 29,
    'id': 'f1f2bee911363f224c77a971752f2575',
    'latitude': 40.7003,
    'longitude': -73.991581,
    'name': 'Henry St & Middagh St',
    'timestamp': '2023-08-29T15:03:07.829000Z'},
   {'empty_slots': 33,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321293,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 42,
     'uid': '66dbf062-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 2,
    'id': 'da5a7b1ea0523c9a02baca5ae8deb0e4',
    'latitude': 40.72019576,
    'longitude': -73.98997825,
    'name': 'Allen St & Rivington St',
    'timestamp': '2023-08-29T15:03:09.334000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321294,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 45,
     'uid': '66dbf362-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 30,
    'id': '867565660402c4c853537f75c91f6482',
    'latitude': 40.71076228,
    'longitude': -73.99400398,
    'name': 'Market St & Cherry St',
    'timestamp': '2023-08-29T15:03:08.715000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321332,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '305c221f-4e0b-4a5a-902c-3d1043dfe606'},
    'free_bikes': 5,
    'id': '7d28ffda6e5853fa016073299ea57f63',
    'latitude': 40.7595701,
    'longitude': -73.9142678,
    'name': 'Newton Rd & 44 St',
    'timestamp': '2023-08-29T15:03:08.904000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321331,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': '35b8b636-18d3-4860-b0a9-39c0bce96a10'},
    'free_bikes': 8,
    'id': '7246c9d4ac2c9ff0f583423e1960a5c1',
    'latitude': 40.757186,
    'longitude': -73.932719,
    'name': '28 St & 36 Ave',
    'timestamp': '2023-08-29T15:03:07.825000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321310,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66ddb95a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 17,
    'id': '7f1e0d4bd55a3d36902826327850c7f4',
    'latitude': 40.6803560840434,
    'longitude': -73.9476791024208,
    'name': 'Verona Pl & Fulton St',
    'timestamp': '2023-08-29T15:03:08.433000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 26,
     'uid': '12279d2b-29f6-4e02-a7f0-244970f7edd5'},
    'free_bikes': 7,
    'id': '723bd1b30046f966525befd16df1276a',
    'latitude': 40.7531106,
    'longitude': -73.9279917,
    'name': '37 Ave & 35 St',
    'timestamp': '2023-08-29T15:03:08.891000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321329,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': 'd265dbc7-ef55-4f5b-8a2b-f2015dc71fb8'},
    'free_bikes': 12,
    'id': '8c04d3a3a6d1c111bab5db559d401a7e',
    'latitude': 40.7596276,
    'longitude': -73.9321455,
    'name': 'Crescent St & 35 Ave',
    'timestamp': '2023-08-29T15:03:07.878000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321227,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'b94d0241-bce7-44a9-ab1c-ece0740a4134'},
    'free_bikes': 18,
    'id': '57ed6148bed3c8647f9ce825c88051ce',
    'latitude': 40.7601853,
    'longitude': -73.9362726,
    'name': '21 St & 36 Ave',
    'timestamp': '2023-08-29T15:03:07.775000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321271,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '822d96e8-fb6c-463a-b866-aec9e408ad5e'},
    'free_bikes': 12,
    'id': '4c29f2b86862def0267a5c26f5309630',
    'latitude': 40.7614376,
    'longitude': -73.9411265,
    'name': '36 Ave & 10 St',
    'timestamp': '2023-08-29T15:03:09.318000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321290,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66ddb595-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': 'e5f5c621a5435d2c4d68293befe114f5',
    'latitude': 40.686203,
    'longitude': -73.944694,
    'name': 'Monroe St & Tompkins Ave',
    'timestamp': '2023-08-29T15:03:08.417000Z'},
   {'empty_slots': 22,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321291,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': '66f68197-4897-4576-896a-48e0312104c5'},
    'free_bikes': 1,
    'id': '07d590106453c2c2cda0ef86d3e7a4c1',
    'latitude': 40.6758324,
    'longitude': -73.9561677,
    'name': 'Franklin Ave & St Marks Ave',
    'timestamp': '2023-08-29T15:03:09.205000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66dbe250-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 12,
    'id': 'c58d768ea95146699edc7248d885d383',
    'latitude': 40.69331716,
    'longitude': -73.95381995,
    'name': 'Willoughby Ave & Walworth St',
    'timestamp': '2023-08-29T15:03:08.278000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321325,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66dbe15d-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 18,
    'id': 'abc69ed93b17d3f2c7afa573c83f0057',
    'latitude': 40.694546087246025,
    'longitude': -73.95801365375519,
    'name': 'Franklin Ave & Myrtle Ave',
    'timestamp': '2023-08-29T15:03:08.733000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 15,
     'has_ebikes': True,
     'last_updated': 1693321311,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 73,
     'uid': '66dbe441-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 66,
    'id': 'b9554e8c88f31e91bc9ee6ec37a5eeab',
    'latitude': 40.72243797,
    'longitude': -74.00566443,
    'name': '6 Ave & Canal St',
    'timestamp': '2023-08-29T15:03:08.232000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321320,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 43,
     'uid': '66dbe3a2-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 22,
    'id': '55f82beb526f29b488d66723b99a8c80',
    'latitude': 40.70862144,
    'longitude': -74.00722156,
    'name': 'John St & William St',
    'timestamp': '2023-08-29T15:03:08.932000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321321,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 48,
     'uid': '66dbea8d-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 43,
    'id': '867f8f82cb432da3ebd0aec92530a23d',
    'latitude': 40.69221589,
    'longitude': -73.9842844,
    'name': 'Duffield St & Willoughby St',
    'timestamp': '2023-08-29T15:03:09.036000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321315,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66dbeded-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 10,
    'id': '355c5191d078ff9f5a4b14f033ae21de',
    'latitude': 40.680342423,
    'longitude': -73.9557689392,
    'name': 'Lefferts Pl & Franklin Ave',
    'timestamp': '2023-08-29T15:03:07.855000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321297,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66db277a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 18,
    'id': 'c777d2de6259e5d7a8092f8a9ec2f197',
    'latitude': 40.71117416,
    'longitude': -74.00016545,
    'name': 'St James Pl & Pearl St',
    'timestamp': '2023-08-29T15:03:08.209000Z'},
   {'empty_slots': 35,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321301,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 62,
     'uid': '66db281e-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 24,
    'id': 'b34976c728b08c32118a701422920d23',
    'latitude': 40.68382604,
    'longitude': -73.97632328,
    'name': 'Atlantic Ave & Fort Greene Pl',
    'timestamp': '2023-08-29T15:03:08.240000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321321,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66dbef85-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 22,
    'id': '668bd328d1337cb7e4d0910dd424d856',
    'latitude': 40.68851534,
    'longitude': -73.9647628,
    'name': 'Lafayette Ave & St James Pl',
    'timestamp': '2023-08-29T15:03:09.345000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321256,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 37,
     'uid': '66dbef15-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 22,
    'id': '751012f449f2e3dd3ff3e518b3ef3e3e',
    'latitude': 40.69165183,
    'longitude': -73.9999786,
    'name': 'Atlantic Ave & Furman St',
    'timestamp': '2023-08-29T15:03:09.034000Z'},
   {'empty_slots': 36,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321247,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 40,
     'uid': '66dde8ac-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': '5b04234fe2f954f067061341e0fdf055',
    'latitude': 40.7969347,
    'longitude': -73.9643412291,
    'name': 'Columbus Ave & W 103 St',
    'timestamp': '2023-08-29T15:03:08.044000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321284,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '66dde914-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 33,
    'id': '366690b096fe22c9fbbf95088d1fa0da',
    'latitude': 40.6849894,
    'longitude': -73.99440329,
    'name': 'Butler St & Court St',
    'timestamp': '2023-08-29T15:03:08.025000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321329,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66dde7dc-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 16,
    'id': '8ddfa6df18ee02eb60a70acdfdff93dd',
    'latitude': 40.66514681533792,
    'longitude': -73.97637605667114,
    'name': 'Prospect Park West & 8 St',
    'timestamp': '2023-08-29T15:03:07.837000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '999865d2-0735-4e85-a9d4-00810231530e'},
    'free_bikes': 21,
    'id': 'a8e4749c71546b114fdd015fbdcb9279',
    'latitude': 40.697950315695444,
    'longitude': -73.97077560424805,
    'name': 'Flushing Ave & Vanderbilt Ave',
    'timestamp': '2023-08-29T15:03:07.901000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321269,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': 'c1e24edf-7192-433f-8d38-be5b6b3647c5'},
    'free_bikes': 3,
    'id': 'ecf7cfb2c3340b06f426a1fb940537c4',
    'latitude': 40.72019521437465,
    'longitude': -74.0103006362915,
    'name': 'North Moore St & Greenwich St',
    'timestamp': '2023-08-29T15:03:07.899000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321316,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '81a98b0b-cfd6-48b4-90bd-806ebbc264a0'},
    'free_bikes': 3,
    'id': 'd01e77bf2b80759ad982e03f66e8a6ce',
    'latitude': 40.666439306870814,
    'longitude': -73.9605563879013,
    'name': 'Montgomery St & Franklin Ave',
    'timestamp': '2023-08-29T15:03:08.561000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321322,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '59ad8f95-32a4-43de-b1c3-79c667b2d2df'},
    'free_bikes': 7,
    'id': '626f7062c32f4e3e0546e45b8df89485',
    'latitude': 40.75651272984955,
    'longitude': -73.92957486212252,
    'name': '36 Ave & 31 St',
    'timestamp': '2023-08-29T15:03:08.257000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321261,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 36,
     'uid': '7a771842-c090-4da1-8c13-72b7f4f50a87'},
    'free_bikes': 32,
    'id': '7bb810f534a2b0e60c722c6a98bf3ba8',
    'latitude': 40.7239567849954,
    'longitude': -73.94984364509583,
    'name': 'Leonard St & Nassau Ave',
    'timestamp': '2023-08-29T15:03:08.557000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321277,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 56,
     'uid': '66db3f62-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 33,
    'id': '02bf7e13e59999365fcd5ee33a58c319',
    'latitude': 40.69327018,
    'longitude': -73.97703874,
    'name': 'Myrtle Ave & St Edwards St',
    'timestamp': '2023-08-29T15:03:07.818000Z'},
   {'empty_slots': 30,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321254,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 51,
     'uid': '66db3f01-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 12,
    'id': '225f061a319c2114543d5297f2f3453d',
    'latitude': 40.69196035,
    'longitude': -73.96536851,
    'name': 'Willoughby Ave & Hall St',
    'timestamp': '2023-08-29T15:03:08.938000Z'},
   {'empty_slots': 51,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321224,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 79,
     'uid': '66db3fc9-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 19,
    'id': '16d43ac1d583eb259e0f1269598faa30',
    'latitude': 40.73535398,
    'longitude': -74.00483091,
    'name': 'Perry St & Bleecker St',
    'timestamp': '2023-08-29T15:03:07.860000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321324,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66db3da9-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 3,
    'id': 'ee298e091236cd09cdef22cfec693257',
    'latitude': 40.68981035,
    'longitude': -73.97493121,
    'name': 'DeKalb Ave & S Portland Ave',
    'timestamp': '2023-08-29T15:03:09.004000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321325,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 37,
     'uid': '66dd491c-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 28,
    'id': 'cb33a0abadc7f41d98cb09a2355207ea',
    'latitude': 40.76663814,
    'longitude': -73.95348296,
    'name': 'E 72 St & York Ave',
    'timestamp': '2023-08-29T15:03:08.487000Z'},
   {'empty_slots': 24,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321232,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '66dd4a52-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': 'd672d4670a9402ce7b5971260df90bab',
    'latitude': 40.77492513,
    'longitude': -73.98266566,
    'name': 'W 67 St & Broadway',
    'timestamp': '2023-08-29T15:03:08.706000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321306,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66db408f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 35,
    'id': 'c3a1de77381133a52e574d6510cd1257',
    'latitude': 40.71870987,
    'longitude': -74.0090009,
    'name': 'Harrison St & Hudson St',
    'timestamp': '2023-08-29T15:03:09.251000Z'},
   {'empty_slots': 51,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321332,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 87,
     'uid': '66db402c-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 33,
    'id': '81f948b8d0003856865c70cc653d6994',
    'latitude': 40.72185379,
    'longitude': -74.00771779,
    'name': 'Laight St & Hudson St',
    'timestamp': '2023-08-29T15:03:08.258000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321324,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 26,
     'uid': '66de4594-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 9,
    'id': '03a28341ce7760f95b2a2ca12f5cc994',
    'latitude': 40.7892529,
    'longitude': -73.93956237,
    'name': 'E 106 St & 1 Ave',
    'timestamp': '2023-08-29T15:03:07.825000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321256,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66de482a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 16,
    'id': '21d389324e52d02bb44e5775b6d4345d',
    'latitude': 40.6794327,
    'longitude': -74.00785041,
    'name': 'Richards St & Delavan St',
    'timestamp': '2023-08-29T15:03:09.355000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321328,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66de47bf-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 19,
    'id': '90f71ca4d32c956c6804d16b1ce5805f',
    'latitude': 40.6812117,
    'longitude': -74.00860912,
    'name': 'Commerce St & Van Brunt St',
    'timestamp': '2023-08-29T15:03:09.200000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321297,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66de48f9-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 16,
    'id': '713834e7e60e4aeffbb7e7bd1a003727',
    'latitude': 40.6763744,
    'longitude': -74.00324957,
    'name': 'Henry St & W 9 St',
    'timestamp': '2023-08-29T15:03:08.151000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321313,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '66de4897-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 9,
    'id': 'b1e9612ff834ff526c3b54562c4e9ef9',
    'latitude': 40.6769993,
    'longitude': -74.00647134,
    'name': 'Columbia St & W 9 St',
    'timestamp': '2023-08-29T15:03:09.313000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321237,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '66de4b0b-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 28,
    'id': 'd83b7b370493311cc4599f47f3f7c8f3',
    'latitude': 40.6763947,
    'longitude': -73.99869893,
    'name': 'Court St & Nelson St',
    'timestamp': '2023-08-29T15:03:08.071000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321308,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66de4959-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 10,
    'id': 'de67b1642fa1e4c29d6771336cc7a608',
    'latitude': 40.6783563,
    'longitude': -74.00014502,
    'name': 'Clinton St & 4 Place',
    'timestamp': '2023-08-29T15:03:08.887000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321283,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '66de4c32-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 20,
    'id': 'de73c97362ddfdae0a1870168a0fa86f',
    'latitude': 40.67260298150126,
    'longitude': -73.98983001708984,
    'name': '7 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:08.218000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321314,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '66de4bbb-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 15,
    'id': '277d39e6570d4000d11f8e4489d36a09',
    'latitude': 40.6746957,
    'longitude': -73.99785768,
    'name': 'Smith St & 9 St',
    'timestamp': '2023-08-29T15:03:07.843000Z'},
   {'empty_slots': 111,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321334,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 117,
     'uid': '66dc7de9-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': 'a0efd92793a29910b2f603347e2c58c4',
    'latitude': 40.76009437,
    'longitude': -73.99461843,
    'name': 'W 43 St & 10 Ave',
    'timestamp': '2023-08-29T15:03:07.944000Z'},
   {'empty_slots': 41,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321330,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 76,
     'uid': '66dc7d58-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 31,
    'id': '690892feeba5b15469cd9aff7b53edff',
    'latitude': 40.76087502,
    'longitude': -74.00277668,
    'name': '12 Ave & W 40 St',
    'timestamp': '2023-08-29T15:03:09.128000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321319,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 45,
     'uid': '66dc22a7-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 31,
    'id': 'fa541f645c63caaefaa15ad6daf5d01b',
    'latitude': 40.751396,
    'longitude': -74.005226,
    'name': '11 Ave & W 27 St',
    'timestamp': '2023-08-29T15:03:08.235000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321332,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '2ec1235f-a043-4e3a-9ba1-56f7dd4624b7'},
    'free_bikes': 12,
    'id': '24498951e503e4c3f28d5476ba1608e1',
    'latitude': 40.7659,
    'longitude': -73.930819,
    'name': '21 St & 31 Dr',
    'timestamp': '2023-08-29T15:03:08.917000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321235,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'b90574d1-e9e7-45be-8adb-e38cb285fea5'},
    'free_bikes': 1,
    'id': '6787be179afb2f79fc6f27f08494d63d',
    'latitude': 40.6679411,
    'longitude': -73.9588,
    'name': 'Carroll St & Franklin Ave',
    'timestamp': '2023-08-29T15:03:07.941000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321314,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '1208a3c2-8f70-4af9-8362-648e5845fe9e'},
    'free_bikes': 6,
    'id': '8919c3c845a2113552bdf7d4b130c200',
    'latitude': 40.6642406,
    'longitude': -73.9574686,
    'name': 'Sullivan Pl & Bedford Ave',
    'timestamp': '2023-08-29T15:03:08.676000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '8c2ed08f-1660-4db8-9168-4709427c23ed'},
    'free_bikes': 3,
    'id': '1a7915f448f3a6d97a9c8d95ce10a5ab',
    'latitude': 40.760339,
    'longitude': -73.9222427,
    'name': '35 St & Broadway',
    'timestamp': '2023-08-29T15:03:08.924000Z'},
   {'empty_slots': 59,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321246,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 66,
     'uid': '66dc209c-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 2,
    'id': '532140f75e114872ad465550560cdc19',
    'latitude': 40.74475148,
    'longitude': -73.99915362,
    'name': 'W 22 St & 8 Ave',
    'timestamp': '2023-08-29T15:03:08.427000Z'},
   {'empty_slots': 27,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321285,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '66dc210e-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 5,
    'id': 'dade337f32b3d73e0533530605ebd67c',
    'latitude': 40.75455731,
    'longitude': -73.96592976,
    'name': 'E 51 St & 1 Ave',
    'timestamp': '2023-08-29T15:03:08.247000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321307,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '66db34fc-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 11,
    'id': '8353969a6d50dc34d111e7af545257f2',
    'latitude': 40.7381765,
    'longitude': -73.97738662,
    'name': 'E 25 St & 1 Ave',
    'timestamp': '2023-08-29T15:03:07.923000Z'},
   {'empty_slots': 24,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321255,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': 'b442a648-e9f4-4893-951a-64d258bc0e55'},
    'free_bikes': 3,
    'id': '4b2b2849716d6a762418d6231296f6db',
    'latitude': 40.763604677958625,
    'longitude': -73.98917958140373,
    'name': 'W 50 St & 9 Ave',
    'timestamp': '2023-08-29T15:03:08.553000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 21,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 54,
     'uid': '18fcd2c1-dc8b-4a52-9f18-e9b9003bbea5'},
    'free_bikes': 44,
    'id': '0550a3831fe79a33fec2d9ae092b0498',
    'latitude': 40.71334184275907,
    'longitude': -74.00935515761375,
    'name': 'Park Pl & Church St',
    'timestamp': '2023-08-29T15:03:09.327000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321286,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '0e3dedfb-df10-4900-a67b-95349a81bc5c'},
    'free_bikes': 24,
    'id': 'ed090d8ebb24e2c2c7a1891e802b1e22',
    'latitude': 40.72248188638219,
    'longitude': -73.95921930670738,
    'name': 'N 11 St & Kent Ave',
    'timestamp': '2023-08-29T15:03:07.785000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321281,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '1ec24ce3-2b69-4f3a-a153-c73e583d11f3'},
    'free_bikes': 3,
    'id': 'a8e4f53caa637ea159141c4a55b7fa19',
    'latitude': 40.71113,
    'longitude': -74.0789,
    'name': 'Jackson Square',
    'timestamp': '2023-08-29T15:03:08.425000Z'},
   {'empty_slots': 41,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321326,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 43,
     'uid': 'b0cc08dc-e7dd-48d1-8901-ba496f3ff2f5'},
    'free_bikes': 0,
    'id': 'c82c0dc67fe9113b4a6835210e3802a4',
    'latitude': 40.77515953434235,
    'longitude': -73.98918695747852,
    'name': 'W 64 St & Thelonious Monk Circle',
    'timestamp': '2023-08-29T15:03:07.955000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321293,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66dcfaf6-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 10,
    'id': 'e621ac77460ef50b56824719c16af20f',
    'latitude': 40.7160751,
    'longitude': -73.952029,
    'name': 'Union Ave & Jackson St',
    'timestamp': '2023-08-29T15:03:08.566000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321235,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66dcf640-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 11,
    'id': '70fd339ebc71f9b91cf1a793127bf811',
    'latitude': 40.71469,
    'longitude': -73.95739,
    'name': 'Roebling St & N 4 St',
    'timestamp': '2023-08-29T15:03:08.603000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321332,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '66dcf922-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 17,
    'id': 'f9651104d04d2006f9184cc619d35943',
    'latitude': 40.71413311,
    'longitude': -73.95234386,
    'name': 'Metropolitan Ave & Meeker Ave',
    'timestamp': '2023-08-29T15:03:08.581000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321320,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': '66dcf0b3-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 9,
    'id': '596e14c4edbaf011856da88ac1acd206',
    'latitude': 40.711863,
    'longitude': -73.944024,
    'name': 'Graham Ave & Grand St',
    'timestamp': '2023-08-29T15:03:07.754000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321323,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '66dcf023-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 5,
    'id': 'd9df7b743d847ef7b88d5d637230fa9e',
    'latitude': 40.70934,
    'longitude': -73.95608,
    'name': 'S 4 St & Rodney St',
    'timestamp': '2023-08-29T15:03:08.761000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321278,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66dcf30d-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 14,
    'id': 'bd5f65798878be60ee862326bed73a5f',
    'latitude': 40.71167351,
    'longitude': -73.95141312,
    'name': 'Hope St & Union Ave',
    'timestamp': '2023-08-29T15:03:08.044000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321278,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '66dd630c-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': '094b135c3b161c1dc288618f59364bc9',
    'latitude': 40.7443187,
    'longitude': -74.0439909,
    'name': 'Riverview Park',
    'timestamp': '2023-08-29T15:03:08.075000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321329,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '3e1bdcec-e762-4e83-b447-007f05923cce'},
    'free_bikes': 5,
    'id': '128cb47e0068eadfce6fcd56476e16b9',
    'latitude': 40.7774552,
    'longitude': -73.9225403,
    'name': '19 St & 24 Ave',
    'timestamp': '2023-08-29T15:03:09.320000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321305,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'a04bf523-3c76-4fad-88bf-e99037f9b796'},
    'free_bikes': 13,
    'id': '82bea6c2ef7eaf0e5be215a485435073',
    'latitude': 40.776165,
    'longitude': -73.9153175,
    'name': '23 Ave & 27 St',
    'timestamp': '2023-08-29T15:03:09.001000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321280,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '0630217a-3913-47d9-9540-cf85688296a5'},
    'free_bikes': 2,
    'id': '3f44a12f4b16508439f6a9ff5356d01d',
    'latitude': 40.7701477,
    'longitude': -73.9120938,
    'name': '37 St & 24 Ave',
    'timestamp': '2023-08-29T15:03:08.261000Z'},
   {'empty_slots': 31,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321259,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 45,
     'uid': '3299ff79-36aa-42ef-b7f1-c40e95c8f570'},
    'free_bikes': 12,
    'id': '5d6517b1bdb193f1d5863768b6331ac5',
    'latitude': 40.7729,
    'longitude': -73.916142,
    'name': '24 Ave & 29 St',
    'timestamp': '2023-08-29T15:03:08.692000Z'},
   {'empty_slots': 29,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321310,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 32,
     'uid': '66dde343-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 2,
    'id': '46d1c2e42b6f10e61005e27ec9bb44f9',
    'latitude': 40.79017948095081,
    'longitude': -73.97288918495178,
    'name': 'W 90 St & Amsterdam Ave',
    'timestamp': '2023-08-29T15:03:07.984000Z'},
   {'empty_slots': 45,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321240,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 47,
     'uid': '66dde079-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': '1a4738bbd47dbf6d5022ec59b514bf79',
    'latitude': 40.7882213,
    'longitude': -73.97041561,
    'name': 'W 89 St & Columbus Ave',
    'timestamp': '2023-08-29T15:03:08.270000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321225,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 14,
     'uid': '66dddf5f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': '5d0ec4325ee93b8fde9848a2467daf1d',
    'latitude': 40.74590996631558,
    'longitude': -74.0572714805603,
    'name': 'Leonard Gordon Park',
    'timestamp': '2023-08-29T15:03:09.212000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321311,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 13,
     'uid': '66ddded0-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': '13c100f37fe94746e59d12b13a0a8df3',
    'latitude': 40.71928220070702,
    'longitude': -74.07126188278198,
    'name': 'Astor Place',
    'timestamp': '2023-08-29T15:03:08.069000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 8,
     'has_ebikes': True,
     'last_updated': 1693321322,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': 'd80c274e-d17d-4a00-9b76-274c9fe4d0e1'},
    'free_bikes': 30,
    'id': '9e9e6b1d0d2fb6354723803e47511b5f',
    'latitude': 40.81028506306003,
    'longitude': -73.95736455917358,
    'name': 'Morningside Dr & Amsterdam Ave',
    'timestamp': '2023-08-29T15:03:08.237000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 30,
     'has_ebikes': True,
     'last_updated': 1693321264,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 59,
     'uid': '66de8a86-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 54,
    'id': 'f653e3ef579ba04306c5ddf5bd829d82',
    'latitude': 40.76132983124814,
    'longitude': -73.97982001304626,
    'name': 'W 52 St & 6 Ave',
    'timestamp': '2023-08-29T15:03:09.234000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321323,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 14,
     'uid': 'e2c00264-9eea-446d-a1b7-27cef3aed403'},
    'free_bikes': 0,
    'id': '9bb00cab3aa0f8f0f0590ef64f2f1e1e',
    'latitude': 40.722103786686034,
    'longitude': -74.07145500183105,
    'name': 'Bergen Ave',
    'timestamp': '2023-08-29T15:03:08.823000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321303,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '66dca6f4-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 25,
    'id': '40bbbf4f0d230a323ccd1dab4035e97d',
    'latitude': 40.759107,
    'longitude': -73.959223,
    'name': 'E 60 St & York Ave',
    'timestamp': '2023-08-29T15:03:07.958000Z'},
   {'empty_slots': 37,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321269,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 45,
     'uid': '66dd448f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 2,
    'id': '64462ee3ec7d472b51b1bd579450e353',
    'latitude': 40.77862688,
    'longitude': -73.95772073,
    'name': 'E 84 St & Park Ave',
    'timestamp': '2023-08-29T15:03:07.907000Z'},
   {'empty_slots': 44,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 47,
     'uid': '66dd44f7-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': '59e3545c2ec9bbf5b0b02e06d53c63a7',
    'latitude': 40.77573034,
    'longitude': -73.9567526,
    'name': 'E 81 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:09.031000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321254,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '66dd8b48-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': '55932df0d281403cd0bbfba5c909da27',
    'latitude': 40.734961020009514,
    'longitude': -74.0595030784607,
    'name': '5 Corners Library',
    'timestamp': '2023-08-29T15:03:08.620000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321286,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '26176e86-8362-4c91-a693-6aa3f9ce0b73'},
    'free_bikes': 4,
    'id': 'ffa1de1039109f34b259df1275fda2a6',
    'latitude': 40.67759206937376,
    'longitude': -73.955637216568,
    'name': 'Dean St & Franklin Ave',
    'timestamp': '2023-08-29T15:03:09.123000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321295,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '66dd5f99-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 5,
    'id': 'b836b664ab3ad75720121abf2b8b6e10',
    'latitude': 40.7246050998869,
    'longitude': -74.07840594649315,
    'name': 'Lincoln Park',
    'timestamp': '2023-08-29T15:03:09.223000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 8,
     'has_ebikes': True,
     'last_updated': 1693321270,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66dd9b0f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 20,
    'id': 'c56e3128d3a0e02119066f95859fa309',
    'latitude': 40.76780080148132,
    'longitude': -73.96592080593109,
    'name': 'E 67 St & Park Ave',
    'timestamp': '2023-08-29T15:03:07.781000Z'},
   {'empty_slots': 29,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321335,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '66dda55f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': 'd04d4a21dd9d44d3203edcceb1b9c136',
    'latitude': 40.75898481399634,
    'longitude': -73.99379968643188,
    'name': 'W 42 St & Dyer Ave',
    'timestamp': '2023-08-29T15:03:09.278000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321265,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66db88f5-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 36,
    'id': 'bd794eb1a774746b9980debee598bb9c',
    'latitude': 40.69236178,
    'longitude': -73.98631746,
    'name': 'Lawrence St & Willoughby St',
    'timestamp': '2023-08-29T15:03:09.154000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321303,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66db7a71-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 29,
    'id': '8789a7c17e0124c5b5a262e87ce8f338',
    'latitude': 40.69991755,
    'longitude': -73.98971773,
    'name': 'Cadman Plaza E & Red Cross Pl',
    'timestamp': '2023-08-29T15:03:08.351000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 15,
     'has_ebikes': True,
     'last_updated': 1693321325,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 57,
     'uid': '66db8d89-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 53,
    'id': '84472575df839d62c561db14eb4cf8f6',
    'latitude': 40.7153379,
    'longitude': -74.01658354,
    'name': 'Vesey Pl & River Terrace',
    'timestamp': '2023-08-29T15:03:08.024000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321277,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 74,
     'uid': '66db89a3-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 64,
    'id': '7ed8023ee32feb4c327bc62d3d598e68',
    'latitude': 40.689888,
    'longitude': -73.981013,
    'name': 'DeKalb Ave & Hudson Ave',
    'timestamp': '2023-08-29T15:03:08.934000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321223,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '66db8fde-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 34,
    'id': '01fd1b84c1d36f31e3fdabe864d9728d',
    'latitude': 40.72405549,
    'longitude': -74.00965965,
    'name': 'Watts St & Greenwich St',
    'timestamp': '2023-08-29T15:03:08.798000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321307,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': 'dc8223ad-4108-40a8-9ff5-35e8490b4077'},
    'free_bikes': 10,
    'id': 'f804768d8511f13d950c2dfd28dfbe76',
    'latitude': 40.8025566,
    'longitude': -73.9490782,
    'name': 'Lenox Ave & W 117 St',
    'timestamp': '2023-08-29T15:03:08.129000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 11,
     'has_ebikes': True,
     'last_updated': 1693321277,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': 'bb32aad7-8308-4ff8-b073-d5b518ffdd09'},
    'free_bikes': 37,
    'id': '94c941584a396adf83c2a56d98b4631e',
    'latitude': 40.8109494,
    'longitude': -73.9634,
    'name': 'W 120 St & Claremont Ave',
    'timestamp': '2023-08-29T15:03:09.325000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 12,
     'has_ebikes': True,
     'last_updated': 1693321301,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'c63a83a0-bda1-40a6-835b-f82c363543b9'},
    'free_bikes': 18,
    'id': '49fe6f14b8c6b4ae4fad7f6cbea58a25',
    'latitude': 40.80756,
    'longitude': -73.939182,
    'name': 'E 128 St & Madison Ave',
    'timestamp': '2023-08-29T15:03:09.141000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321315,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66de1a1f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': '1a61da20961a265b7158d88091913707',
    'latitude': 40.76800889305947,
    'longitude': -73.96845281124115,
    'name': 'E 66 St & Madison Ave',
    'timestamp': '2023-08-29T15:03:08.353000Z'},
   {'empty_slots': 30,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321315,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '66de19ab-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': 'e0e259489d692a26bbdb5f11a0bf7856',
    'latitude': 40.668132,
    'longitude': -73.97363831,
    'name': '3 St & Prospect Park West',
    'timestamp': '2023-08-29T15:03:08.974000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 10,
     'has_ebikes': True,
     'last_updated': 1693321219,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '66de1af4-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 15,
    'id': '3edff0feb66b3e113adb903c40ae3f7a',
    'latitude': 40.8008363,
    'longitude': -73.9664492472,
    'name': 'W 106 St & Amsterdam Ave',
    'timestamp': '2023-08-29T15:03:07.864000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321285,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '66de1a8a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': '6206dc8b98001c37bf3fd43543d5280c',
    'latitude': 40.7746671,
    'longitude': -73.98470567,
    'name': 'Amsterdam Ave & W 66 St',
    'timestamp': '2023-08-29T15:03:08.200000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321279,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66de186f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 18,
    'id': 'dda5125a571d0c45015a07ac67bed4d8',
    'latitude': 40.7869946,
    'longitude': -73.94164802,
    'name': 'E 102 St & 1 Ave',
    'timestamp': '2023-08-29T15:03:09.183000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321311,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '66dcc5ca-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 11,
    'id': 'f11d436444d971ffe42c91026d74a42b',
    'latitude': 40.69237074,
    'longitude': -73.93705428,
    'name': 'Lewis Ave & Kosciuszko St',
    'timestamp': '2023-08-29T15:03:08.595000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321235,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66dcc65c-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': '671d9c0e7074209fe6baf467827c0331',
    'latitude': 40.6933982,
    'longitude': -73.939877,
    'name': 'Pulaski St & Marcus Garvey Blvd',
    'timestamp': '2023-08-29T15:03:08.906000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321246,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66dcc3e5-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 12,
    'id': 'ecd995e9eed2c8fe60ee895616c13fe3',
    'latitude': 40.69072549,
    'longitude': -73.95133465,
    'name': 'Kosciuszko St & Nostrand Ave',
    'timestamp': '2023-08-29T15:03:09.190000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321260,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '66dcc44a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 6,
    'id': '423d0371490a34b937f4c8e6e1876c9d',
    'latitude': 40.69128258,
    'longitude': -73.9452416,
    'name': 'Kosciuszko St & Tompkins Ave',
    'timestamp': '2023-08-29T15:03:09.117000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321282,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66dcc30b-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': '947979cb744cc6d243b9062cc571556e',
    'latitude': 40.6894932,
    'longitude': -73.942061,
    'name': 'Greene Ave & Throop Ave',
    'timestamp': '2023-08-29T15:03:08.385000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321323,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66dcc37f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 8,
    'id': 'f5be38129a4cd9966cd6049ba85ce0bb',
    'latitude': 40.6883337,
    'longitude': -73.950916,
    'name': 'Greene Ave & Nostrand Ave',
    'timestamp': '2023-08-29T15:03:08.252000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321287,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66dcc0b2-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 12,
    'id': '458721d27442258852411cd8f597a71b',
    'latitude': 40.6900815,
    'longitude': -73.947915,
    'name': 'Marcy Ave & Lafayette Ave',
    'timestamp': '2023-08-29T15:03:07.786000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321233,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '66dcbf69-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': '0e50d4b2eb5fa3731d9184cd15d0e0df',
    'latitude': 40.6851532,
    'longitude': -73.94111,
    'name': 'Putnam Ave & Throop Ave',
    'timestamp': '2023-08-29T15:03:07.839000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321329,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66dd546c-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 13,
    'id': '367598244976bd4bbdde17a5e38eed48',
    'latitude': 40.698617,
    'longitude': -73.941342,
    'name': 'Park Ave & Marcus Garvey Blvd',
    'timestamp': '2023-08-29T15:03:08.294000Z'},
   {'empty_slots': 72,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321222,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 78,
     'uid': '66dd5407-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': '903ebac2c492c86e0ab8edca7a98f535',
    'latitude': 40.78414472,
    'longitude': -73.98362492,
    'name': 'Riverside Dr & W 78 St',
    'timestamp': '2023-08-29T15:03:08.148000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321311,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 51,
     'uid': '1b28836b-29fd-47a7-9a98-44cd792918fb'},
    'free_bikes': 45,
    'id': 'e5cd3531268a591274fc312b962c5541',
    'latitude': 40.71816969454208,
    'longitude': -73.95520135760307,
    'name': 'Driggs Ave & N 9 St',
    'timestamp': '2023-08-29T15:03:07.763000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321298,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'c36cfa58-29fe-4c0c-a14f-41c3463487fd'},
    'free_bikes': 20,
    'id': '320da8be0aec18c09e577d71994c9fd5',
    'latitude': 40.753599202005596,
    'longitude': -73.93795609474182,
    'name': '40 Ave & Crescent St',
    'timestamp': '2023-08-29T15:03:08.020000Z'},
   {'empty_slots': 82,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321338,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 90,
     'uid': 'd9160982-2d9b-4f08-9469-a559a7b62809'},
    'free_bikes': 3,
    'id': '97364afba60065b63a7c332b65f3dea1',
    'latitude': 40.72966729392978,
    'longitude': -73.98067966103554,
    'name': 'E 13 St & Avenue A',
    'timestamp': '2023-08-29T15:03:09.311000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321272,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '20ff5447-eac3-43b7-820f-f6fa3a2e12a8'},
    'free_bikes': 6,
    'id': '1fd9fd817620666adc39b53b2d603159',
    'latitude': 40.7974772,
    'longitude': -73.9311847,
    'name': 'Pleasant Ave & E 120 St',
    'timestamp': '2023-08-29T15:03:08.670000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321266,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '0b613329-b8c8-4b8c-ad40-79952aa41157'},
    'free_bikes': 7,
    'id': 'c96274caf720de26fbabf851fa7dfc97',
    'latitude': 40.7923272,
    'longitude': -73.9383,
    'name': '1 Ave & E 110 St',
    'timestamp': '2023-08-29T15:03:08.485000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321260,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': 'bf317efc-13f1-42be-8243-373a29354033'},
    'free_bikes': 19,
    'id': 'f91f198ec2933aa744d7bb79afe346f8',
    'latitude': 40.797911,
    'longitude': -73.9423,
    'name': 'E 115 St & Lexington Ave',
    'timestamp': '2023-08-29T15:03:08.479000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 25,
     'has_ebikes': True,
     'last_updated': 1693321293,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 78,
     'uid': '66db3997-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 60,
    'id': '70647d470dfad18e770464d485ea1124',
    'latitude': 40.7546011026,
    'longitude': -73.971878855,
    'name': 'E 48 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:07.882000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321280,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '1e83ffdc-8e72-45c0-8210-4f37e60505c9'},
    'free_bikes': 15,
    'id': 'b0bb2cbe5196725e0445efc70c2c2bab',
    'latitude': 40.75186951421875,
    'longitude': -73.93349289894103,
    'name': '31 St & Northern Blvd',
    'timestamp': '2023-08-29T15:03:08.956000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321330,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 37,
     'uid': '93e2e1a5-49c5-41f8-a6bf-b399b6a5140d'},
    'free_bikes': 19,
    'id': '7448843186d5f3149d39dd7b7015238c',
    'latitude': 40.72307749068673,
    'longitude': -73.98583620786667,
    'name': 'E 2 St & Avenue A',
    'timestamp': '2023-08-29T15:03:07.916000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321291,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66dd2786-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 25,
    'id': '93a0dfd06b4213296acfd49005c9083a',
    'latitude': 40.75052534,
    'longitude': -73.94594845,
    'name': '21 St & 43 Ave',
    'timestamp': '2023-08-29T15:03:08.909000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321305,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 40,
     'uid': '66dd2811-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 30,
    'id': '4e63af50d0dcb7da6e6a5ecd5de86957',
    'latitude': 40.75110165,
    'longitude': -73.94073717,
    'name': 'Queens Plaza North & Crescent St',
    'timestamp': '2023-08-29T15:03:08.952000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321225,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 79,
     'uid': '66dd243c-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 70,
    'id': '3e75e3732fe336a1f7a49eace1cb2169',
    'latitude': 40.744363287066875,
    'longitude': -73.9558732509613,
    'name': '48 Ave & 5 St',
    'timestamp': '2023-08-29T15:03:09.076000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321309,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66dd23a9-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 19,
    'id': '34712fa09110c542692b275075d35392',
    'latitude': 40.74524768,
    'longitude': -73.94733276,
    'name': 'Jackson Ave & 46 Rd',
    'timestamp': '2023-08-29T15:03:09.277000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321301,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 34,
     'uid': '66dd266a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 25,
    'id': '1aa265e83be7c1c1b7a4f8e2902c9208',
    'latitude': 40.74718234,
    'longitude': -73.9432635,
    'name': '44 Dr & Jackson Ave',
    'timestamp': '2023-08-29T15:03:08.128000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321251,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 43,
     'uid': '66dd2556-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 22,
    'id': 'f51eb799d2313812f1302f7414686d3c',
    'latitude': 40.74731,
    'longitude': -73.95451,
    'name': '46 Ave & 5 St',
    'timestamp': '2023-08-29T15:03:07.851000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321318,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66dd25e0-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': '69ee650a920ad5c80fe62b7f99f23861',
    'latitude': 40.74708586,
    'longitude': -73.94977234,
    'name': '45 Rd & 11 St',
    'timestamp': '2023-08-29T15:03:09.134000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321324,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 65,
     'uid': '66dc8d1d-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 38,
    'id': '928df8ae2bc6511e1316c7def3d695a0',
    'latitude': 40.74444921,
    'longitude': -73.98303529,
    'name': 'E 30 St & Park Ave S',
    'timestamp': '2023-08-29T15:03:07.879000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321307,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'cc758f1a-8b28-4ff5-bc75-fbe62c453378'},
    'free_bikes': 5,
    'id': 'c8d759c644f644aaee460a771469bec4',
    'latitude': 40.7713937,
    'longitude': -73.9077436,
    'name': 'Steinway St & 23 Ave',
    'timestamp': '2023-08-29T15:03:08.380000Z'},
   {'empty_slots': 23,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66dc8c90-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': '0444c7c8a330c1068c998053b9ad5ce6',
    'latitude': 40.736502,
    'longitude': -73.97809472,
    'name': 'E 23 St & 1 Ave',
    'timestamp': '2023-08-29T15:03:09.350000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321290,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '14f928c6-9a51-40a2-b7e6-a74e8b351dbf'},
    'free_bikes': 4,
    'id': 'a6a9bb9a61be9e8cfb6013168fe2b250',
    'latitude': 40.8107922,
    'longitude': -73.9430681,
    'name': 'Lenox Ave & W 130 St',
    'timestamp': '2023-08-29T15:03:09.026000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321261,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 32,
     'uid': '66de4f30-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 13,
    'id': 'd55d104a5d4f576d1048c9e184f6e090',
    'latitude': 40.6902375,
    'longitude': -73.99203074,
    'name': 'Court St & State St',
    'timestamp': '2023-08-29T15:03:08.334000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321280,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66de5095-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 7,
    'id': '7f7cdcc54c854a2ccda05bf9c06b45c3',
    'latitude': 40.6704836,
    'longitude': -73.98208968,
    'name': '5 St & 6 Ave',
    'timestamp': '2023-08-29T15:03:08.636000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321237,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66de5005-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 16,
    'id': '8e4bda8f01fe262c2747a562489c8527',
    'latitude': 40.6704922,
    'longitude': -73.98541675,
    'name': '7 St & 5 Ave',
    'timestamp': '2023-08-29T15:03:08.418000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321255,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 45,
     'uid': '66db2a71-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 29,
    'id': 'd898e4ff836e27a0859a506d6b13d3a4',
    'latitude': 40.73172428,
    'longitude': -74.00674436,
    'name': 'Barrow St & Hudson St',
    'timestamp': '2023-08-29T15:03:09.237000Z'},
   {'empty_slots': 29,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321249,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 38,
     'uid': '66ddf310-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 7,
    'id': '7833417deedb5c94be0ced228355c5b2',
    'latitude': 40.6831164,
    'longitude': -73.99785267,
    'name': 'Clinton St & Union St',
    'timestamp': '2023-08-29T15:03:08.070000Z'},
   {'empty_slots': 22,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321295,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '66dbf6d2-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 7,
    'id': '4f373fd7a239ab91d4ce812f4c3947b7',
    'latitude': 40.68753406,
    'longitude': -73.97265183,
    'name': 'Cumberland St & Lafayette Ave',
    'timestamp': '2023-08-29T15:03:08.961000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 14,
     'has_ebikes': True,
     'last_updated': 1693321297,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 37,
     'uid': '66dbf73d-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 31,
    'id': '8d29fc93242d0bf145cb74dd6963c4a6',
    'latitude': 40.71291224,
    'longitude': -74.01020234,
    'name': 'Barclay St & Church St',
    'timestamp': '2023-08-29T15:03:08.951000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321338,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 45,
     'uid': '66dbf4ac-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 9,
    'id': 'c31fc21e73da66db0f7973ba7f493749',
    'latitude': 40.72228087,
    'longitude': -73.97668709,
    'name': 'E 6 St & Avenue D',
    'timestamp': '2023-08-29T15:03:08.866000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321250,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': '66dbf518-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 25,
    'id': '12aa7924b713843d73c4432e4e35fa39',
    'latitude': 40.7158155,
    'longitude': -73.99422366,
    'name': 'Forsyth St & Canal St',
    'timestamp': '2023-08-29T15:03:08.969000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321311,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '66de5773-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 14,
    'id': 'c47dcad90866037695052ca4c586f20b',
    'latitude': 40.6853761,
    'longitude': -73.98302136,
    'name': 'Pacific St & Nevins St',
    'timestamp': '2023-08-29T15:03:08.508000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321336,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 37,
     'uid': '66dc0bbd-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': 'e65acf5e01b607c578cae4f0a607e354',
    'latitude': 40.70224,
    'longitude': -73.982578,
    'name': 'Front St & Gold St',
    'timestamp': '2023-08-29T15:03:08.227000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 18,
     'has_ebikes': True,
     'last_updated': 1693321259,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 49,
     'uid': '66db79a3-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 42,
    'id': 'e0e1349d37c7847fb7a9d989b497117e',
    'latitude': 40.711066,
    'longitude': -74.009447,
    'name': 'Fulton St & Broadway',
    'timestamp': '2023-08-29T15:03:08.811000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321310,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 55,
     'uid': '66db74a5-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 49,
    'id': '2bbf2b22bcf7e21185a069f24e8e1444',
    'latitude': 40.69610226,
    'longitude': -73.96751037,
    'name': 'Washington Ave & Park Ave',
    'timestamp': '2023-08-29T15:03:07.952000Z'},
   {'empty_slots': 37,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321276,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 49,
     'uid': '66db72f1-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 9,
    'id': 'b4e7ad7574adbfb9ae6f6303c3e51ab7',
    'latitude': 40.722055,
    'longitude': -73.989111,
    'name': 'Allen St & Stanton St',
    'timestamp': '2023-08-29T15:03:08.397000Z'},
   {'empty_slots': 34,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321237,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 59,
     'uid': '66db728c-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 17,
    'id': 'a422db3d02bdb9ce4208318f5e16c17b',
    'latitude': 40.7172274,
    'longitude': -73.98802084,
    'name': 'Norfolk St & Broome St',
    'timestamp': '2023-08-29T15:03:07.811000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321244,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 43,
     'uid': '66db75cc-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 39,
    'id': '316d13596152e5b43055a7896384c763',
    'latitude': 40.70355377,
    'longitude': -74.00670227,
    'name': 'South St & Gouverneur Ln',
    'timestamp': '2023-08-29T15:03:08.959000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321239,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 26,
     'uid': '66dddc98-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 5,
    'id': '852a7d09ade16f3d44d873c0de5dcec8',
    'latitude': 40.71458403535893,
    'longitude': -74.04281705617905,
    'name': 'Marin Light Rail',
    'timestamp': '2023-08-29T15:03:08.507000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321286,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 14,
     'uid': '66dddd28-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 3,
    'id': 'd7d6126642891ff9eb0a9cdf130ffcd1',
    'latitude': 40.71435836870427,
    'longitude': -74.06661093235016,
    'name': 'Communipaw & Berry Lane',
    'timestamp': '2023-08-29T15:03:09.305000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321263,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 14,
     'uid': '66dddc08-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 8,
    'id': '4ee52f18978222aa2d7cea3f26beb431',
    'latitude': 40.71835519823214,
    'longitude': -74.03891444206238,
    'name': 'Columbus Drive',
    'timestamp': '2023-08-29T15:03:08.414000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321323,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 14,
     'uid': '66ddda59-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': '94e681f1f00389434269b49f410ec7de',
    'latitude': 40.72333158646436,
    'longitude': -74.04595255851744,
    'name': 'Jersey & 3rd',
    'timestamp': '2023-08-29T15:03:09.101000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321229,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '66dddae7-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 14,
    'id': 'cd857a888055cf10269922242d4e2d23',
    'latitude': 40.721650724879986,
    'longitude': -74.04288411140442,
    'name': 'Manila & 1st',
    'timestamp': '2023-08-29T15:03:08.851000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693312935,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 0,
     'returning': 0,
     'slots': 14,
     'uid': '66ddd93e-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': '720b0ea544d681c69cd5caef2c0f246f',
    'latitude': 40.72528910781132,
    'longitude': -74.04557168483734,
    'name': 'Jersey & 6th St',
    'timestamp': '2023-08-29T15:03:08.654000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321220,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 14,
     'uid': '66ddddb4-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': 'ebb71b9b3f2e8b9dfdd8e12e5c7c2f6d',
    'latitude': 40.72568548362901,
    'longitude': -74.04879033565521,
    'name': 'Monmouth and 6th',
    'timestamp': '2023-08-29T15:03:09.268000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321299,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '66ddde40-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 3,
    'id': 'b18e9ea315e1d5f6847ed907a7e50563',
    'latitude': 40.721630142638354,
    'longitude': -74.04996782541275,
    'name': 'Dixon Mills',
    'timestamp': '2023-08-29T15:03:07.783000Z'},
   {'empty_slots': 25,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321327,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': 'dd351a72-4241-4275-843d-0fffa8a1f414'},
    'free_bikes': 0,
    'id': 'ec1021250c1094c74d7393c99f94f68a',
    'latitude': 40.672695,
    'longitude': -73.954131,
    'name': 'Sterling Pl & Bedford Ave',
    'timestamp': '2023-08-29T15:03:08.108000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 12,
     'has_ebikes': True,
     'last_updated': 1693321267,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 57,
     'uid': '2527619f-ef89-425c-bf3b-60cc0ec519bf'},
    'free_bikes': 52,
    'id': 'd26f145d372fcd2daf416bb05124f13c',
    'latitude': 40.742753828659026,
    'longitude': -74.00747358798981,
    'name': 'W 15 St & 10 Ave',
    'timestamp': '2023-08-29T15:03:08.192000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321298,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '91ca68bd-5ac1-470b-a26d-1ec98ea9cca4'},
    'free_bikes': 14,
    'id': '2fce2923c521a450c30d625a258fac98',
    'latitude': 40.76108,
    'longitude': -73.930562,
    'name': 'Crescent St & 34 Ave',
    'timestamp': '2023-08-29T15:03:08.487000Z'},
   {'empty_slots': 22,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321309,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '69f84045-48f9-4c6c-90d3-0503e5ed39e9'},
    'free_bikes': 0,
    'id': '1710d4a64034eadd21a17e2067ba1b38',
    'latitude': 40.6769694,
    'longitude': -73.96579,
    'name': 'Prospect Pl & Underhill Ave',
    'timestamp': '2023-08-29T15:03:08.430000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321262,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '0fa27bd7-b182-4e7a-b5bb-90f4249cb368'},
    'free_bikes': 16,
    'id': 'a44c13e0e8fba7b26df8ab766fe8f74d',
    'latitude': 40.7628138,
    'longitude': -73.9342862,
    'name': '34 Ave & 21 St',
    'timestamp': '2023-08-29T15:03:07.982000Z'},
   {'empty_slots': 23,
    'extra': {'ebikes': 7,
     'has_ebikes': True,
     'last_updated': 1693321303,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 43,
     'uid': 'dd482585-3028-453f-a98d-55019db9b26c'},
    'free_bikes': 18,
    'id': 'a999dd9a65258568ccf72f79cf50f419',
    'latitude': 40.65708866668485,
    'longitude': -74.00870203971863,
    'name': '2 Ave & 36 St',
    'timestamp': '2023-08-29T15:03:07.806000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321337,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': 'd5788cfa-817e-4b65-b43f-edda222a3c3c'},
    'free_bikes': 5,
    'id': '3246546348593a5e5e8136f92e9ee03a',
    'latitude': 40.7580583,
    'longitude': -73.9242751,
    'name': '35 St & 34 Ave',
    'timestamp': '2023-08-29T15:03:09.216000Z'},
   {'empty_slots': 22,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321328,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '548cb08c-4ec1-46d9-8978-1a8d3bf42454'},
    'free_bikes': 8,
    'id': '33fbbd9b8c4f2005e223ed90615a408e',
    'latitude': 40.756913,
    'longitude': -73.921631,
    'name': '34 Ave & 38 St',
    'timestamp': '2023-08-29T15:03:07.724000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321323,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 41,
     'uid': '32c60668-a192-4d06-aa7c-6d6f7aed6b45'},
    'free_bikes': 36,
    'id': '6e978bee8d0b2454e202673edab02f99',
    'latitude': 40.7671863,
    'longitude': -73.9373554,
    'name': 'Vernon Blvd & 10 St',
    'timestamp': '2023-08-29T15:03:08.659000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321241,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 76,
     'uid': '66dbcf18-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': 'a6295b3b3150ca31d0c3dbf6ca88d66f',
    'latitude': 40.73224119,
    'longitude': -74.00026394,
    'name': 'Washington Pl & 6 Ave',
    'timestamp': '2023-08-29T15:03:07.943000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321332,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66dbcc49-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 12,
    'id': '27b07edae5f892220631741cc764d4a7',
    'latitude': 40.68900443,
    'longitude': -73.96023854,
    'name': 'Lafayette Ave & Classon Ave',
    'timestamp': '2023-08-29T15:03:08.685000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321277,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 51,
     'uid': '66de602e-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 38,
    'id': 'ea60272f1959b101ebe9904d8bdc83e8',
    'latitude': 40.6792788,
    'longitude': -73.98154004,
    'name': 'Douglass St & 4 Ave',
    'timestamp': '2023-08-29T15:03:07.800000Z'},
   {'empty_slots': 24,
    'extra': {'ebikes': 7,
     'has_ebikes': True,
     'last_updated': 1693321267,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 57,
     'uid': '66dbcb2f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 30,
    'id': 'cfa81a8cba5cef3b0c2fc22f74d02419',
    'latitude': 40.75172632,
    'longitude': -73.98753523,
    'name': 'Broadway & W 37 St',
    'timestamp': '2023-08-29T15:03:07.766000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321309,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 57,
     'uid': '66dbca0f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 42,
    'id': '3dc872964211b3a02545ca7035b2af1d',
    'latitude': 40.70717936,
    'longitude': -74.00887308,
    'name': 'William St & Pine St',
    'timestamp': '2023-08-29T15:03:08.865000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321278,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66de0c43-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 16,
    'id': '1e8f020788dd35412e708692bb4dfde7',
    'latitude': 40.681990442707026,
    'longitude': -73.99079024791718,
    'name': 'Degraw St & Hoyt St',
    'timestamp': '2023-08-29T15:03:07.978000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321302,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 45,
     'uid': '66ddef96-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 27,
    'id': '9a6e732a82cd264a76f3c79635f419c8',
    'latitude': 40.7839636,
    'longitude': -73.9471673,
    'name': '2 Ave & E 96 St',
    'timestamp': '2023-08-29T15:03:08.963000Z'},
   {'empty_slots': 24,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321335,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 82,
     'uid': '66dbe848-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 55,
    'id': '902236f7c08be690cda3a4e4a48ea005',
    'latitude': 40.71494807,
    'longitude': -74.00234482,
    'name': 'Centre St & Worth St',
    'timestamp': '2023-08-29T15:03:08.626000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 9,
     'has_ebikes': True,
     'last_updated': 1693321289,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 57,
     'uid': '66dbe8d6-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 41,
    'id': '9ee0a62ece9660a7df6b131987482526',
    'latitude': 40.71273266,
    'longitude': -74.0046073,
    'name': 'Centre St & Chambers St',
    'timestamp': '2023-08-29T15:03:08.185000Z'},
   {'empty_slots': 38,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321320,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 51,
     'uid': '66dbe96d-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 9,
    'id': 'e8aa1fee9ba544731b242c7322fe9551',
    'latitude': 40.749717753,
    'longitude': -74.002950346,
    'name': 'W 26 St & 10 Ave',
    'timestamp': '2023-08-29T15:03:09.081000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321246,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': '66dded7a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 7,
    'id': 'f009a246a1f45c52eaa72e0f35b89090',
    'latitude': 40.6663181,
    'longitude': -73.9854617,
    'name': '6 Ave & 12 St',
    'timestamp': '2023-08-29T15:03:08.650000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321334,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66dded11-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 23,
    'id': '1149c5beaeddd94339fe4d3ed7a55d2b',
    'latitude': 40.7817212,
    'longitude': -73.94594,
    'name': '1 Ave & E 94 St',
    'timestamp': '2023-08-29T15:03:08.727000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321296,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66ddee56-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 11,
    'id': '3a7d5139a9ddf20d1b0cb2d212a750ce',
    'latitude': 40.6847514,
    'longitude': -73.99917254,
    'name': 'Henry St & Degraw St',
    'timestamp': '2023-08-29T15:03:09.104000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321321,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '66ddef2d-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 10,
    'id': '3922379771bcee233aba6ec9f678cfd2',
    'latitude': 40.6686273,
    'longitude': -73.98700053,
    'name': '10 St & 5 Ave',
    'timestamp': '2023-08-29T15:03:08.371000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321275,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '66ddeffd-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 10,
    'id': '8e627581e0e60a938a49d11e381e9268',
    'latitude': 40.666287,
    'longitude': -73.98895053,
    'name': '14 St & 5 Ave',
    'timestamp': '2023-08-29T15:03:08.730000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321299,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '66dd3cb4-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 32,
    'id': '07059ec6916545496bfd61cbec35ef14',
    'latitude': 40.75325964,
    'longitude': -73.94335788,
    'name': '21 St & Queens Plaza North',
    'timestamp': '2023-08-29T15:03:08.107000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321257,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '4753c1ba-a86e-431e-94fb-06403cdee4d7'},
    'free_bikes': 22,
    'id': '68c50a9801f9242440803b6554ba3761',
    'latitude': 40.7449067,
    'longitude': -73.9534573,
    'name': 'Vernon Blvd & 47 Rd',
    'timestamp': '2023-08-29T15:03:08.697000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321287,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 15,
     'uid': '914e3e7c-87da-4f52-aa03-5449c6361fa2'},
    'free_bikes': 4,
    'id': '8350288432f1e6c3a1a1e425a84ffa86',
    'latitude': 40.7703743,
    'longitude': -73.9286078,
    'name': '30 Ave & 21 St',
    'timestamp': '2023-08-29T15:03:08.565000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321314,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': 'c3d5f47f-cfc3-4c1f-86bb-bcf770d2949b'},
    'free_bikes': 12,
    'id': '4ce078ea237cf8bd7c0c9bff6bed3423',
    'latitude': 40.745038,
    'longitude': -73.957539,
    'name': 'Center Blvd & 48 Ave',
    'timestamp': '2023-08-29T15:03:08.154000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321332,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'fe93b3ae-1d86-4ee9-9eb6-9e11808966aa'},
    'free_bikes': 6,
    'id': 'e68bd408bba2486a42bc33a42b4ad56b',
    'latitude': 40.768692,
    'longitude': -73.9249574,
    'name': 'Crescent St & 30 Ave',
    'timestamp': '2023-08-29T15:03:08.714000Z'},
   {'empty_slots': 23,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321253,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '08bf2fe0-219d-48cd-87c5-6163b3a2eafd'},
    'free_bikes': 1,
    'id': '31204ec136d07f7cc89f5be88a266213',
    'latitude': 40.7656251,
    'longitude': -73.9136695,
    'name': 'Steinway St & 28 Ave',
    'timestamp': '2023-08-29T15:03:08.914000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321239,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '3575749f-123a-4a80-870d-7ca7c7f9c8a9'},
    'free_bikes': 7,
    'id': '751a921c50096046b6ae86b02e5fe14c',
    'latitude': 40.7671,
    'longitude': -73.9169858,
    'name': '28 Ave & 35 St',
    'timestamp': '2023-08-29T15:03:08.276000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321231,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '72796825-88b1-43a0-bb6d-2b41d337b1fc'},
    'free_bikes': 29,
    'id': 'ab1dffd4d35e54e71933173187a69957',
    'latitude': 40.7485,
    'longitude': -73.941275,
    'name': '27 St & Hunter St',
    'timestamp': '2023-08-29T15:03:08.115000Z'},
   {'empty_slots': 22,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321332,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': 'd56a8542-048a-4aca-ac7f-f27a9e6c908b'},
    'free_bikes': 4,
    'id': '36727c1f2fef796db977c7212dee40eb',
    'latitude': 40.7713615,
    'longitude': -73.9246145,
    'name': 'Newtown Ave & 23 St',
    'timestamp': '2023-08-29T15:03:08.199000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321294,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'a35d03cf-bd72-4da4-a4ac-bd25b3f8dce3'},
    'free_bikes': 9,
    'id': '03e019e9196565fff548088c8662200e',
    'latitude': 40.69064807082943,
    'longitude': -73.95746178925037,
    'name': 'DeKalb Ave & Franklin Ave',
    'timestamp': '2023-08-29T15:03:08.604000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321242,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'ab6aadd8-fa45-43aa-abea-c8e01ec5a0c8'},
    'free_bikes': 18,
    'id': 'f566f1604a110e77162f79ff2189256f',
    'latitude': 40.710681,
    'longitude': -73.93372,
    'name': 'Stagg St & Morgan Ave',
    'timestamp': '2023-08-29T15:03:07.890000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321289,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '9a52fbc1-d87a-4a65-941d-12fd55dbcdde'},
    'free_bikes': 21,
    'id': '5d2facf67e9fdcfad0cb250e42c2bbc4',
    'latitude': 40.704508,
    'longitude': -73.9351,
    'name': 'White St & Moore St',
    'timestamp': '2023-08-29T15:03:08.542000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321262,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '66ddeca9-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 13,
    'id': '24b7779e1a1da7a58eb229ece1ddff8e',
    'latitude': 40.68763155,
    'longitude': -74.0016256,
    'name': 'Columbia St & Kane St',
    'timestamp': '2023-08-29T15:03:08.210000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321299,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66db43b5-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': 'fd182aba25e81ba1adfe4fe1eaf32525',
    'latitude': 40.68940747,
    'longitude': -73.96885458,
    'name': 'DeKalb Ave & Vanderbilt Ave',
    'timestamp': '2023-08-29T15:03:08.368000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321222,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 55,
     'uid': '66db4417-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 48,
    'id': '06e1188664fdade16905bd96fa594334',
    'latitude': 40.70122128,
    'longitude': -74.01234218,
    'name': 'South St & Whitehall St',
    'timestamp': '2023-08-29T15:03:08.007000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321234,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '66db41bf-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': 'c6c424dfa383afd46161ca9204beff3b',
    'latitude': 40.73226398,
    'longitude': -73.99852205,
    'name': 'MacDougal St & Washington Sq',
    'timestamp': '2023-08-29T15:03:08.033000Z'},
   {'empty_slots': 51,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 55,
     'uid': '66dd4de9-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': '8128189d0fd53b0aabca9b8c742e97e8',
    'latitude': 40.77966809007312,
    'longitude': -73.98093044757842,
    'name': 'Amsterdam Ave & W 73 St',
    'timestamp': '2023-08-29T15:03:07.949000Z'},
   {'empty_slots': 50,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321265,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 56,
     'uid': '66dd4c5f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 9,
    'id': 'ff2f088627090e550307de251e788b80',
    'latitude': 40.7770575,
    'longitude': -73.97898475,
    'name': 'Columbus Ave & W 72 St',
    'timestamp': '2023-08-29T15:03:08.226000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321330,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66db4158-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 23,
    'id': '954fd419087ea9e0b272fae48c946fc8',
    'latitude': 40.72317958,
    'longitude': -73.99480012,
    'name': 'Mott St & Prince St',
    'timestamp': '2023-08-29T15:03:07.977000Z'},
   {'empty_slots': 40,
    'extra': {'ebikes': 9,
     'has_ebikes': True,
     'last_updated': 1693321335,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 79,
     'uid': '66db4351-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 38,
    'id': '4cbfaa21aaba97a7316891820ab33f65',
    'latitude': 40.71939226,
    'longitude': -74.00247214,
    'name': 'Lispenard St & Broadway',
    'timestamp': '2023-08-29T15:03:07.880000Z'},
   {'empty_slots': 29,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321277,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 47,
     'uid': '66db4282-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 15,
    'id': 'fc4aa829fb9fd8fc1674c29d8ab374b3',
    'latitude': 40.73532427,
    'longitude': -73.99800419,
    'name': 'W 11 St & 6 Ave',
    'timestamp': '2023-08-29T15:03:07.931000Z'},
   {'empty_slots': 38,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321316,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 59,
     'uid': '66dd4b2b-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 20,
    'id': '190584424bf3fd3e1a33ebc7b6b86095',
    'latitude': 40.7801839724239,
    'longitude': -73.97728532552719,
    'name': 'W 76 St & Columbus Ave',
    'timestamp': '2023-08-29T15:03:08.198000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321318,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '66de2199-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 20,
    'id': 'b1b27b23c3eefe90e781026f7819d5ad',
    'latitude': 40.6728155,
    'longitude': -73.98352355,
    'name': '5 Ave & 3 St',
    'timestamp': '2023-08-29T15:03:09.102000Z'},
   {'empty_slots': 23,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321295,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': '66de2201-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 6,
    'id': '44b4c228dbb24fd32a7e1060943db7db',
    'latitude': 40.7724607,
    'longitude': -73.9468208,
    'name': 'E 82 St & East End Ave',
    'timestamp': '2023-08-29T15:03:09.026000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321300,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66de1fe7-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 12,
    'id': '13b16fc397c36417677de56e7c498a73',
    'latitude': 40.6751622,
    'longitude': -73.9814832,
    'name': 'Carroll St & 5 Ave',
    'timestamp': '2023-08-29T15:03:07.924000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321270,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66de205d-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 3,
    'id': '677ee665169954ec141a7272b6b6a166',
    'latitude': 40.6703837,
    'longitude': -73.97839676,
    'name': '3 St & 7 Ave',
    'timestamp': '2023-08-29T15:03:08.922000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '66de20c8-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': '5efd2e03ec8c2c6852a08b241e374f61',
    'latitude': 40.8021174,
    'longitude': -73.9681805305,
    'name': 'West End Ave & W 107 St',
    'timestamp': '2023-08-29T15:03:08.188000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 17,
     'has_ebikes': True,
     'last_updated': 1693321264,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66de2131-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 31,
    'id': '5d23057ab3b6b9e9790a1de195d639a6',
    'latitude': 40.7922553,
    'longitude': -73.95249933,
    'name': '5 Ave & E 103 St',
    'timestamp': '2023-08-29T15:03:08.191000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 8,
     'has_ebikes': True,
     'last_updated': 1693321270,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '66de1f7f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 31,
    'id': 'ae1bdd20f83eb7da803704a29dc044b5',
    'latitude': 40.7904828,
    'longitude': -73.95033068,
    'name': 'E 102 St & Park Ave',
    'timestamp': '2023-08-29T15:03:08.194000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 12,
     'has_ebikes': True,
     'last_updated': 1693321338,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 78,
     'uid': '66dc78c4-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 53,
    'id': '8d1406d6a6ba6e73bf1b2ceb41fc49e9',
    'latitude': 40.74901271,
    'longitude': -73.98848395,
    'name': '6 Ave & W 33 St',
    'timestamp': '2023-08-29T15:03:08.753000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 25,
     'has_ebikes': True,
     'last_updated': 1693321258,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 78,
     'uid': '66dc75ec-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 72,
    'id': '0e204689b2d8b2eeb8a655b316e693c6',
    'latitude': 40.76228826,
    'longitude': -73.98336183,
    'name': 'Broadway & W 51 St',
    'timestamp': '2023-08-29T15:03:07.877000Z'},
   {'empty_slots': 108,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321328,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 123,
     'uid': '66dc7659-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': 'eaa1bf5aec2885ff78ce02e4c02547c9',
    'latitude': 40.744219,
    'longitude': -73.97121214,
    'name': 'FDR Drive & E 35 St',
    'timestamp': '2023-08-29T15:03:08.960000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 10,
     'has_ebikes': True,
     'last_updated': 1693321275,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 51,
     'uid': '66dc2995-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 30,
    'id': '8abb3edb6f70e034992bcf0d6e462b50',
    'latitude': 40.74395411,
    'longitude': -73.99144871,
    'name': 'W 25 St & 6 Ave',
    'timestamp': '2023-08-29T15:03:08.110000Z'},
   {'empty_slots': 23,
    'extra': {'ebikes': 11,
     'has_ebikes': True,
     'last_updated': 1693321270,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 102,
     'uid': '66db32fb-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 72,
    'id': 'a8f1b617368964ed2279c87ba55a5aa5',
    'latitude': 40.75323098,
    'longitude': -73.97032517,
    'name': 'E 47 St & 2 Ave',
    'timestamp': '2023-08-29T15:03:07.835000Z'},
   {'empty_slots': 26,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321314,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 55,
     'uid': 'e36b5913-8e46-4c2a-b9be-73bdf8ee548b'},
    'free_bikes': 19,
    'id': '9143d01d7f45d28d74829ababf34390c',
    'latitude': 40.7687620293096,
    'longitude': -73.95840793848038,
    'name': '2 Ave & E 72 St',
    'timestamp': '2023-08-29T15:03:08.126000Z'},
   {'empty_slots': 31,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321280,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 47,
     'uid': 'ab5585c8-c2cf-4bab-96cf-d02eced4f6e3'},
    'free_bikes': 14,
    'id': '6174d47f914c0a14fd92a1e50f754ebb',
    'latitude': 40.799041392882984,
    'longitude': -73.96649479866028,
    'name': 'W 104 St & Amsterdam Ave',
    'timestamp': '2023-08-29T15:03:07.973000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321295,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': 'a59f4f11-5d52-43a2-8a32-ae71137a6af8'},
    'free_bikes': 5,
    'id': '16bb066f9162599f02694ac3f85c0d67',
    'latitude': 40.71517767732029,
    'longitude': -74.03768330812454,
    'name': 'Grand St',
    'timestamp': '2023-08-29T15:03:08Z'},
   {'empty_slots': 38,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321332,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 46,
     'uid': '66dd4841-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 7,
    'id': '30c84a4a1fedd0477fa9af1744edccd4',
    'latitude': 40.77314236,
    'longitude': -73.95856158,
    'name': 'E 77 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:07.820000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321334,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 87,
     'uid': '66dc9223-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 79,
    'id': 'bfa2452a7af65bca716a9f5cb98307a4',
    'latitude': 40.739445,
    'longitude': -73.976806,
    'name': 'E 27 St & 1 Ave',
    'timestamp': '2023-08-29T15:03:08.893000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321293,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': 'bfea6c5b-2e1a-42c5-8199-2ded6042d57b'},
    'free_bikes': 25,
    'id': '3a3736819921a35d0cede9ca2d2177e4',
    'latitude': 40.8125511,
    'longitude': -73.9492286,
    'name': 'Frederick Douglass Blvd & W 129 St',
    'timestamp': '2023-08-29T15:03:08.538000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321243,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '9e99abca-c679-4788-9a4e-39066660bd6a'},
    'free_bikes': 1,
    'id': 'f24e6dc015d0cf4366ec438777f3a125',
    'latitude': 40.7787185,
    'longitude': -73.9145645,
    'name': 'Crescent St & Ditmars Blvd',
    'timestamp': '2023-08-29T15:03:09.125000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321294,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 34,
     'uid': 'dd8627c8-4190-4a30-8758-e77a7b010437'},
    'free_bikes': 27,
    'id': 'bb6f04a6011f167df66a6562278f776c',
    'latitude': 40.8114323,
    'longitude': -73.9518776,
    'name': 'St. Nicholas Ave & W 126 St',
    'timestamp': '2023-08-29T15:03:08.216000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321308,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '0f6fd186-656a-41b3-ba4a-456d22da177c'},
    'free_bikes': 17,
    'id': '27a5821f18d045c2df14a21a0a649aef',
    'latitude': 40.805159,
    'longitude': -73.954692,
    'name': 'Frederick Douglass Blvd & W 117 St',
    'timestamp': '2023-08-29T15:03:08.253000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 30,
     'has_ebikes': True,
     'last_updated': 1693321318,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 43,
     'uid': '8e631be4-1e0c-4627-a261-18f0003d0ba2'},
    'free_bikes': 38,
    'id': '49c2cfebcf344b6df92739fab35f098f',
    'latitude': 40.8082,
    'longitude': -73.9641,
    'name': 'W 116 St & Broadway',
    'timestamp': '2023-08-29T15:03:07.866000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 26,
     'has_ebikes': True,
     'last_updated': 1693321312,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 43,
     'uid': '7efcb97f-6c8f-4445-86a9-3f758a822f17'},
    'free_bikes': 32,
    'id': '98bd85a891bb604d3f06d38dfc3637f6',
    'latitude': 40.8067581,
    'longitude': -73.9607082,
    'name': 'W 116 St & Amsterdam Ave',
    'timestamp': '2023-08-29T15:03:07.788000Z'},
   {'empty_slots': 35,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321309,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 45,
     'uid': '4d79bdb9-7c35-4d35-9f6e-3c1b849c453a'},
    'free_bikes': 5,
    'id': '5e1983d15479e458c8c515bc6520aedb',
    'latitude': 40.802692,
    'longitude': -73.96295,
    'name': 'W 110 St & Amsterdam Ave',
    'timestamp': '2023-08-29T15:03:08.832000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321283,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 36,
     'uid': '0e003543-3656-448f-8a93-029d265f2e26'},
    'free_bikes': 9,
    'id': 'd1bc13fee0432641ebcc5e29f81e20f3',
    'latitude': 40.7987859,
    'longitude': -73.9523,
    'name': 'Lenox Ave & W 111 St',
    'timestamp': '2023-08-29T15:03:08.841000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 10,
     'has_ebikes': True,
     'last_updated': 1693321286,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 14,
     'uid': '66dd58f2-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 14,
    'id': '9557c45cfe5f2b8e9ed1bbb799407a12',
    'latitude': 40.7141454,
    'longitude': -74.0335519,
    'name': 'Paulus Hook',
    'timestamp': '2023-08-29T15:03:09.172000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321234,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '66dd5960-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 17,
    'id': '34cfd104ee44ca3dc900629a7c2349ce',
    'latitude': 40.7177325,
    'longitude': -74.043845,
    'name': 'City Hall',
    'timestamp': '2023-08-29T15:03:07.925000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 7,
     'has_ebikes': True,
     'last_updated': 1693321321,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '66dd5a42-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 7,
    'id': 'c84504dbefaca0ed39e8f0d29a7ee360',
    'latitude': 40.7211236,
    'longitude': -74.03805095,
    'name': 'Warren St',
    'timestamp': '2023-08-29T15:03:09.015000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321293,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '66dd056e-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 13,
    'id': 'e3c3507f71a83636213f6db71ed6196b',
    'latitude': 40.7169811,
    'longitude': -73.94485918,
    'name': 'Graham Ave & Withers St',
    'timestamp': '2023-08-29T15:03:08.722000Z'},
   {'empty_slots': 67,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321336,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 78,
     'uid': '66dc176f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 10,
    'id': 'aa51f178f636cc6e855d1743bc473681',
    'latitude': 40.7262807,
    'longitude': -73.98978041,
    'name': 'E 4 St & 2 Ave',
    'timestamp': '2023-08-29T15:03:08.774000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321299,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '74a1dc19-f894-4246-99f1-476a92452995'},
    'free_bikes': 12,
    'id': '0f2448fc366771b90e727bb51a52fcf5',
    'latitude': 40.6686744,
    'longitude': -73.9618148,
    'name': 'Carroll St & Washington Ave',
    'timestamp': '2023-08-29T15:03:07.954000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321280,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': 'd9bc0b3e-1af8-4cb6-a082-8ef1245ef329'},
    'free_bikes': 19,
    'id': 'a6284a38e5eb20898a1bf2d344979818',
    'latitude': 40.8013066,
    'longitude': -73.9398167,
    'name': 'Lexington Ave & E 120 St',
    'timestamp': '2023-08-29T15:03:09.066000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321283,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '292ad4f3-9fb0-44ec-9e61-613c711f73c1'},
    'free_bikes': 0,
    'id': '0d7fe405cb77b3e2c671c6256cd47ef8',
    'latitude': 40.6791944,
    'longitude': -73.9587903,
    'name': 'Pacific St & Classon Ave',
    'timestamp': '2023-08-29T15:03:09.009000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321323,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 41,
     'uid': 'bc5235a5-7f10-4a27-806e-9c25fa700959'},
    'free_bikes': 35,
    'id': '1719462637fb7aef8e2f767f70ad0d0c',
    'latitude': 40.8143256,
    'longitude': -73.9590255,
    'name': 'Broadway & Moylan Pl',
    'timestamp': '2023-08-29T15:03:09.097000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '23539f3b-fb83-4f34-b8b8-9f1f37b5e646'},
    'free_bikes': 29,
    'id': '08af190e87c3a151fb80c6110b42d470',
    'latitude': 40.81,
    'longitude': -73.9551508,
    'name': 'Morningside Ave & W 123 St',
    'timestamp': '2023-08-29T15:03:08.117000Z'},
   {'empty_slots': 32,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321298,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 51,
     'uid': '66dd3f33-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 17,
    'id': '23872102dc152c782b8eb21d74b505d8',
    'latitude': 40.76312584,
    'longitude': -73.96526895,
    'name': '3 Ave & E 62 St',
    'timestamp': '2023-08-29T15:03:07.803000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321320,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 14,
     'uid': '66dd9183-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': '385618ca13d367c056ba4b376a85ae5b',
    'latitude': 40.7236589,
    'longitude': -74.0641943,
    'name': 'Baldwin at Montgomery',
    'timestamp': '2023-08-29T15:03:08.251000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321251,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66dd8bd9-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 23,
    'id': '924c571dded5dd56bcacca64f621c966',
    'latitude': 40.743,
    'longitude': -73.93561,
    'name': '47 Ave & 31 St',
    'timestamp': '2023-08-29T15:03:09.201000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321279,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '66dd40dd-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 17,
    'id': 'd93b4c67d7689eb23b2bc0ad6b53f7d2',
    'latitude': 40.77282817,
    'longitude': -73.96685276,
    'name': '5 Ave & E 72 St',
    'timestamp': '2023-08-29T15:03:09.239000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 43,
     'uid': '66dbc745-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 19,
    'id': 'bc1319b1d95ef9e86d3bf0734c4c6170',
    'latitude': 40.71602118,
    'longitude': -73.99974372,
    'name': 'Bayard St & Baxter St',
    'timestamp': '2023-08-29T15:03:07.817000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321281,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 16,
     'uid': '66dbc6ae-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 34,
    'id': '71166ca10620ead0519fc2c02470b9aa',
    'latitude': 40.69363137,
    'longitude': -73.96223558,
    'name': 'Emerson Pl & Myrtle Ave',
    'timestamp': '2023-08-29T15:03:08.484000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321319,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66dbc60f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 3,
    'id': '009750d7dc4dec3f0fc06547e41ba3a8',
    'latitude': 40.68539567,
    'longitude': -73.97431458,
    'name': 'S Portland Ave & Hanson Pl',
    'timestamp': '2023-08-29T15:03:08.661000Z'},
   {'empty_slots': 39,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321316,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 69,
     'uid': '66dbc420-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 27,
    'id': '337518644c49baaccf74a42d3e1ce0b7',
    'latitude': 40.71559509,
    'longitude': -73.9870295,
    'name': 'Clinton St & Grand St',
    'timestamp': '2023-08-29T15:03:09.358000Z'},
   {'empty_slots': 58,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321302,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 74,
     'uid': '66dbc8f5-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 13,
    'id': 'b1174251eded1f916a7f507ead116fc5',
    'latitude': 40.73291553,
    'longitude': -74.00711384,
    'name': 'Christopher St & Greenwich St',
    'timestamp': '2023-08-29T15:03:07.862000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321312,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 37,
     'uid': '66db3687-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 23,
    'id': '9a89c50d230293995f62e01e96079ab5',
    'latitude': 40.70037867,
    'longitude': -73.99548059,
    'name': 'Columbia Heights & Cranberry St',
    'timestamp': '2023-08-29T15:03:08.790000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321327,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 60,
     'uid': '66db3606-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 40,
    'id': 'bf4e6b16eab4099fc230cc529ae57c63',
    'latitude': 40.74334935,
    'longitude': -74.00681753,
    'name': 'W 16 St & The High Line',
    'timestamp': '2023-08-29T15:03:08.201000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321334,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': 'f15ccc6e-5a7c-46e7-b505-0bfc9cae3d83'},
    'free_bikes': 19,
    'id': 'ce0c8f186d0e53f3d808a83178032d57',
    'latitude': 40.814394437915816,
    'longitude': -73.95324736833572,
    'name': 'W 129 St & Convent Ave',
    'timestamp': '2023-08-29T15:03:08.146000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321279,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'f3b359e2-7983-4aaf-b6b0-e3b7d30816a4'},
    'free_bikes': 19,
    'id': '3c6011af7e931695b712af27b99603cc',
    'latitude': 40.702997,
    'longitude': -73.92997,
    'name': 'George St & Wilson Ave',
    'timestamp': '2023-08-29T15:03:09.276000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321273,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '66dcbefb-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': 'bc41ba851a1022db37e479b603e523a8',
    'latitude': 40.68488,
    'longitude': -73.96304,
    'name': 'Cambridge Pl & Gates Ave',
    'timestamp': '2023-08-29T15:03:08.943000Z'},
   {'empty_slots': 23,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321337,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 59,
     'uid': '66de077f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 31,
    'id': '84142b715e9baed1e9fd906355599cd6',
    'latitude': 40.7981856,
    'longitude': -73.9605909006,
    'name': 'W 106 St & Central Park West',
    'timestamp': '2023-08-29T15:03:08.927000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321283,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '66de08c9-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 18,
    'id': '0ed61602506b53c189e24130f4c512fd',
    'latitude': 40.67434,
    'longitude': -74.00194698,
    'name': 'Clinton St & Centre St',
    'timestamp': '2023-08-29T15:03:09.155000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321337,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66de0933-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 18,
    'id': '92044b4dd19a8490f5993eccb19079ec',
    'latitude': 40.7877214,
    'longitude': -73.94728331,
    'name': '3 Ave & E 100 St',
    'timestamp': '2023-08-29T15:03:07.777000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321284,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '66dcb9f7-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 14,
    'id': 'a6c8e3397cd3c058c11ef1dda5380361',
    'latitude': 40.67890679,
    'longitude': -73.94142771,
    'name': 'Kingston Ave & Herkimer St',
    'timestamp': '2023-08-29T15:03:07.779000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321330,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66de0a0a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 22,
    'id': '495a889770e8f25d4b232ec7e260bc2d',
    'latitude': 40.6829151,
    'longitude': -73.99318208,
    'name': 'Degraw St & Smith St',
    'timestamp': '2023-08-29T15:03:07.832000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66dcbac5-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 5,
    'id': '6d56d6028c19aec5f5db9756670c4e82',
    'latitude': 40.6814598,
    'longitude': -73.934903,
    'name': 'Lewis Ave & Decatur St',
    'timestamp': '2023-08-29T15:03:09.197000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321300,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66dcba5e-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 16,
    'id': '4b8006ed1946622e1a5807dfe5006856',
    'latitude': 40.6794268,
    'longitude': -73.9298911,
    'name': 'Fulton St & Utica Ave',
    'timestamp': '2023-08-29T15:03:08.168000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321233,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66dcbb2c-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 10,
    'id': '936e40e5c8a1ed40d4f530a8331b0f7a',
    'latitude': 40.6800105,
    'longitude': -73.938475,
    'name': 'Albany Ave & Fulton St',
    'timestamp': '2023-08-29T15:03:08.435000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321327,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '66dcbdc2-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': '99d475ea66b8b08b44bfcf5c30b288c8',
    'latitude': 40.6823687,
    'longitude': -73.944118,
    'name': 'Halsey St & Tompkins Ave',
    'timestamp': '2023-08-29T15:03:07.959000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321292,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66db63f4-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': '733f4db0daa75a17abc0545ee2f88799',
    'latitude': 40.6845683,
    'longitude': -73.95881081,
    'name': 'Monroe St & Classon Ave',
    'timestamp': '2023-08-29T15:03:09.219000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321290,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '138094a0-cd7d-4014-9b21-4fb2afd3980e'},
    'free_bikes': 15,
    'id': '6aaca47bf366f7c52e8881cb65be3f49',
    'latitude': 40.804372,
    'longitude': -73.951475,
    'name': 'Adam Clayton Powell Blvd & W 118 St',
    'timestamp': '2023-08-29T15:03:08.065000Z'},
   {'empty_slots': 63,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321285,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 114,
     'uid': '66db6387-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 48,
    'id': '024003b114b28f42e4126d957d0fb865',
    'latitude': 40.73454567,
    'longitude': -73.99074142,
    'name': 'Broadway & E 14 St',
    'timestamp': '2023-08-29T15:03:09.352000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321242,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'e612122d-e0fd-4ebf-8d51-0f48f9d1b580'},
    'free_bikes': 22,
    'id': 'd6dd46b2bb3470d434b0c8255499ca0c',
    'latitude': 40.705614,
    'longitude': -73.92153,
    'name': 'Willoughby Ave & Wyckoff Ave',
    'timestamp': '2023-08-29T15:03:08.121000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321329,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '21361381-fd4a-44a4-bfa7-61f075192ce9'},
    'free_bikes': 6,
    'id': '140543361558b3996ebafc1496b79d1a',
    'latitude': 40.697842,
    'longitude': -73.926241,
    'name': 'Cedar St & Myrtle Ave',
    'timestamp': '2023-08-29T15:03:07.987000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': 'bdcbd89b-9ae0-461b-aa1d-7db7ead07400'},
    'free_bikes': 16,
    'id': '438969f3716267e538c234a9bb7b9b8a',
    'latitude': 40.677027,
    'longitude': -73.9865,
    'name': '3 Ave & Carroll St',
    'timestamp': '2023-08-29T15:03:09.032000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321301,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '9b721468-3b28-429d-9e13-580cdf00a6a4'},
    'free_bikes': 27,
    'id': '322bf18052c06f4c32aafffb445f1219',
    'latitude': 40.707165,
    'longitude': -73.923711,
    'name': 'Wyckoff Av & Jefferson St',
    'timestamp': '2023-08-29T15:03:08.241000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321324,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '56e18295-f760-4bf3-8aa3-5a1e4ebf606f'},
    'free_bikes': 13,
    'id': 'f491c510da9a01ae4a95232b014fed5d',
    'latitude': 40.705517,
    'longitude': -73.93936,
    'name': 'Bushwick Ave & McKibbin St',
    'timestamp': '2023-08-29T15:03:08.290000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321255,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'e35c42c6-8b73-4528-b08d-c94b75624b40'},
    'free_bikes': 1,
    'id': '25a9af3bc9b512e4c7c10783f5a86f69',
    'latitude': 40.709897,
    'longitude': -73.94008,
    'name': 'Bushwick Ave & Stagg St',
    'timestamp': '2023-08-29T15:03:08.847000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321262,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'de6f4206-3aa9-4cb9-aae0-8547d2cd6854'},
    'free_bikes': 20,
    'id': '68c2b5f6704c825aba6e0dff8519c841',
    'latitude': 40.707174,
    'longitude': -73.93581,
    'name': 'White St & Johnson Ave',
    'timestamp': '2023-08-29T15:03:09.133000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321228,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 14,
     'uid': '6107e75a-2493-4e3d-a3e0-d4886d3416e5'},
    'free_bikes': 4,
    'id': 'ea577512364ea89046d6b5337f5e658d',
    'latitude': 40.71942,
    'longitude': -74.05099,
    'name': 'Montgomery St',
    'timestamp': '2023-08-29T15:03:08.884000Z'},
   {'empty_slots': 27,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321218,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 41,
     'uid': '66dd3fc3-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 10,
    'id': '95dcb5e099c2f8186c615f33bb9647bb',
    'latitude': 40.77112927,
    'longitude': -73.95772297,
    'name': 'E 75 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:08.312000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321277,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '66db4549-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': 'c52672bc4a6cdf5b446425966312ecab',
    'latitude': 40.6917823,
    'longitude': -73.9737299,
    'name': 'Washington Park',
    'timestamp': '2023-08-29T15:03:08.460000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321324,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 41,
     'uid': '66db44e5-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 18,
    'id': '5d4eac09b951da10eb38d9b38d50aeb7',
    'latitude': 40.69474881,
    'longitude': -73.98362464,
    'name': 'Johnson St & Gold St',
    'timestamp': '2023-08-29T15:03:08.828000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 20,
     'has_ebikes': True,
     'last_updated': 1693321278,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 49,
     'uid': '66db447a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 42,
    'id': '9b842edd915ea5ba2356debf55c16565',
    'latitude': 40.70365182,
    'longitude': -74.01167797,
    'name': 'Broad St & Bridge St',
    'timestamp': '2023-08-29T15:03:09.158000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 8,
     'has_ebikes': True,
     'last_updated': 1693321335,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 78,
     'uid': '66db473c-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 53,
    'id': '553100c2aece072c174ee62dded01cf3',
    'latitude': 40.75097711,
    'longitude': -73.98765428,
    'name': 'Broadway & W 36 St',
    'timestamp': '2023-08-29T15:03:07.847000Z'},
   {'empty_slots': 37,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321318,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 47,
     'uid': '66db4671-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 10,
    'id': '88baf784aeeca189b3e6db060603a440',
    'latitude': 40.72229346,
    'longitude': -73.99147535,
    'name': 'Stanton St & Chrystie St',
    'timestamp': '2023-08-29T15:03:08.319000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321242,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 26,
     'uid': '43f3d3c7-46b0-4812-879d-15afe8804c5f'},
    'free_bikes': 22,
    'id': 'c09e50558b620375b68a6e5d8c3822f1',
    'latitude': 40.76315481910373,
    'longitude': -73.93985509872437,
    'name': '35 Ave & 10 St',
    'timestamp': '2023-08-29T15:03:07.730000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 36,
     'has_ebikes': True,
     'last_updated': 1693321334,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 109,
     'uid': 'daefc84c-1b16-4220-8e1f-10ea4866fdc7'},
    'free_bikes': 77,
    'id': 'f8fa1dbcc5f1539cba71fefc650ae103',
    'latitude': 40.74286877312112,
    'longitude': -73.98918628692627,
    'name': 'Broadway & W 25 St',
    'timestamp': '2023-08-29T15:03:09.120000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 11,
     'has_ebikes': True,
     'last_updated': 1693321299,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': 'dd8b2f53-8b94-4082-9576-994a4962f9d5'},
    'free_bikes': 15,
    'id': 'e4672652b99033ad9d6020ee08ce7ead',
    'latitude': 40.73367,
    'longitude': -74.0625,
    'name': 'Journal Square',
    'timestamp': '2023-08-29T15:03:08.447000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 38,
     'uid': '66dc89ae-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 26,
    'id': 'cf5ebf70e0920b8dc890dc6e015f3d52',
    'latitude': 40.74144387,
    'longitude': -73.97536082,
    'name': '1 Ave & E 30 St',
    'timestamp': '2023-08-29T15:03:08.898000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321256,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 43,
     'uid': '66dc8768-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 18,
    'id': '84bc89e7baa8992bb2455bab121e5666',
    'latitude': 40.710451,
    'longitude': -73.960876,
    'name': 'S 5 Pl & S 5 St',
    'timestamp': '2023-08-29T15:03:08.492000Z'},
   {'empty_slots': 37,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321284,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 66,
     'uid': '66dc86d9-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 26,
    'id': 'd011df899229420210406a4c7382ae43',
    'latitude': 40.71893904,
    'longitude': -73.99266288,
    'name': 'Forsyth St & Broome St',
    'timestamp': '2023-08-29T15:03:08.119000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321334,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '66dc864c-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 7,
    'id': 'f8e3c1bda1173342a3bd738e6356c194',
    'latitude': 40.77149671054441,
    'longitude': -73.99046033620834,
    'name': '11 Ave & W 59 St',
    'timestamp': '2023-08-29T15:03:09.146000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321297,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'f6143531-4a16-4aac-9b55-573ef7ef162e'},
    'free_bikes': 4,
    'id': 'a03f1915d9663980a23e084a7beedc01',
    'latitude': 40.7569332,
    'longitude': -73.9262231,
    'name': '34 St & 35 Ave',
    'timestamp': '2023-08-29T15:03:09.164000Z'},
   {'empty_slots': 30,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321280,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 55,
     'uid': '66dc8b6a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': 'e16e3209a97b72c45e0923875e2a0905',
    'latitude': 40.71534825,
    'longitude': -73.96024116,
    'name': 'Metropolitan Ave & Bedford Ave',
    'timestamp': '2023-08-29T15:03:09.087000Z'},
   {'empty_slots': 39,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321337,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 41,
     'uid': '66dd4d70-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': '65f4f7625a8a8a0c0954c6c446f2ed7a',
    'latitude': 40.78057799010334,
    'longitude': -73.98562431335449,
    'name': 'Riverside Dr & W 72 St',
    'timestamp': '2023-08-29T15:03:09.147000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321324,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '49d2cd03-f508-483f-a7c9-7fd450e5e6db'},
    'free_bikes': 15,
    'id': '59dad6f01fb003cb0e6dc94a53cf2c71',
    'latitude': 40.7576314,
    'longitude': -73.9391224,
    'name': '21 St & 38 Ave',
    'timestamp': '2023-08-29T15:03:09.166000Z'},
   {'empty_slots': 45,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321222,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 51,
     'uid': '66dc0cc7-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 3,
    'id': '61b7013e9bec1a33774e207f2b3e146b',
    'latitude': 40.68764484,
    'longitude': -73.96968902,
    'name': 'Clermont Ave & Lafayette Ave',
    'timestamp': '2023-08-29T15:03:08.007000Z'},
   {'empty_slots': 106,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321304,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 117,
     'uid': '66dc0dab-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 8,
    'id': '54bab4ec7780995954a8ef770d5c68cd',
    'latitude': 40.770513,
    'longitude': -73.988038,
    'name': 'W 59 St & 10 Ave',
    'timestamp': '2023-08-29T15:03:08.438000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 8,
     'has_ebikes': True,
     'last_updated': 1693321337,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 69,
     'uid': '66dc0f1b-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 60,
    'id': '1cf7e0ac388370af14b146948d8c520d',
    'latitude': 40.701907,
    'longitude': -74.013942,
    'name': 'Bus Slip & State St',
    'timestamp': '2023-08-29T15:03:08.425000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 7,
     'has_ebikes': True,
     'last_updated': 1693321284,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 115,
     'uid': '66dc0e99-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 110,
    'id': '59dc3a58b475898d4fc71e12e77682fa',
    'latitude': 40.71754834,
    'longitude': -74.01322069,
    'name': 'West St & Chambers St',
    'timestamp': '2023-08-29T15:03:09.035000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321265,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 48,
     'uid': '66db7152-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 36,
    'id': '822036fd56ec20279c7eb8c3e1d0a225',
    'latitude': 40.71307916,
    'longitude': -73.99851193,
    'name': 'St James Pl & Oliver St',
    'timestamp': '2023-08-29T15:03:08.004000Z'},
   {'empty_slots': 35,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 43,
     'uid': '66dd52c8-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': '6b30b3eb363292d29ea6c3a60d22a748',
    'latitude': 40.77748046,
    'longitude': -73.98288594,
    'name': 'W 70 St & Amsterdam Ave',
    'timestamp': '2023-08-29T15:03:08.810000Z'},
   {'empty_slots': 55,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321287,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 85,
     'uid': '66db6aae-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 27,
    'id': '0ba48fdfd84cd4b871bfd83c406d9d25',
    'latitude': 40.72217444,
    'longitude': -73.98368779,
    'name': 'E 2 St & Avenue B',
    'timestamp': '2023-08-29T15:03:09.361000Z'},
   {'empty_slots': 41,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321280,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 55,
     'uid': '66db6cd4-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 11,
    'id': '083971b0b85af53ac352c8491706b8d4',
    'latitude': 40.72082834,
    'longitude': -73.97793172,
    'name': 'Avenue D & E 3 St',
    'timestamp': '2023-08-29T15:03:08.695000Z'},
   {'empty_slots': 32,
    'extra': {'ebikes': 9,
     'has_ebikes': True,
     'last_updated': 1693321289,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 67,
     'uid': '66db6d40-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 32,
    'id': 'd71d6e21ef945a6d86a80f3055e8f9d6',
    'latitude': 40.72362738,
    'longitude': -73.99949601,
    'name': 'Mercer St & Spring St',
    'timestamp': '2023-08-29T15:03:07.787000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321324,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 45,
     'uid': '66db6f2e-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 25,
    'id': 'fdf85ee78d2b08da8702caf317743a25',
    'latitude': 40.71427487,
    'longitude': -73.98990025,
    'name': 'Canal St & Rutgers St',
    'timestamp': '2023-08-29T15:03:08.095000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321280,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 87,
     'uid': '66ddd545-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 83,
    'id': 'c03e29a91278134e8e4a369bbe8ad790',
    'latitude': 40.72951496224949,
    'longitude': -73.99075269699097,
    'name': 'Cooper Square & Astor Pl',
    'timestamp': '2023-08-29T15:03:08.931000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321297,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 14,
     'uid': '66ddd78e-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': 'f130c0465cb97f328451476e33dd2ee0',
    'latitude': 40.7124188237569,
    'longitude': -74.03852552175522,
    'name': 'Morris Canal',
    'timestamp': '2023-08-29T15:03:08.114000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321335,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 14,
     'uid': '66ddd8a8-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': '25dd47e4d0e1afb1998d7f4af9927bb7',
    'latitude': 40.72601172964625,
    'longitude': -74.05038893222809,
    'name': 'Brunswick & 6th',
    'timestamp': '2023-08-29T15:03:08.724000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321256,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 14,
     'uid': '66ddd81a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': 'b41b2fbef248257985d2e69d3cd81925',
    'latitude': 40.71346382669195,
    'longitude': -74.06285852193832,
    'name': 'Lafayette Park',
    'timestamp': '2023-08-29T15:03:09.214000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321316,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '897e8739-ee1d-4b2e-b151-ad7e64e87697'},
    'free_bikes': 23,
    'id': 'd3be06c43e62705ef9de535c1734b8e2',
    'latitude': 40.8011939,
    'longitude': -73.9500739,
    'name': 'Lenox Ave & W 115 St',
    'timestamp': '2023-08-29T15:03:08.937000Z'},
   {'empty_slots': 40,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 79,
     'uid': '647a2a80-9630-41b0-9b91-1f464b0bf3cc'},
    'free_bikes': 30,
    'id': '3bc88c1c5458d3a613b727bb44313c3e',
    'latitude': 40.735367055605394,
    'longitude': -73.98797392845154,
    'name': 'E 16 St & Irving Pl',
    'timestamp': '2023-08-29T15:03:08.434000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 18,
     'has_ebikes': True,
     'last_updated': 1693321241,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 49,
     'uid': '66dea894-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 48,
    'id': '40b57b825e77a7fd2821dfe266acb802',
    'latitude': 40.714851505262516,
    'longitude': -74.01122331619263,
    'name': 'Murray St & Greenwich St',
    'timestamp': '2023-08-29T15:03:08.868000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321319,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': 'b976906e-81c4-44c5-a160-e17815c0d47b'},
    'free_bikes': 20,
    'id': 'd8515357672a4247a53fc8df455bbe4a',
    'latitude': 40.7989445,
    'longitude': -73.944846,
    'name': 'E 115 St & Madison Ave',
    'timestamp': '2023-08-29T15:03:07.858000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321325,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': 'd3f51f51-7e51-4c75-8600-d76916608707'},
    'free_bikes': 16,
    'id': '31a2774ba8fa0bd689edc7927b9f35d0',
    'latitude': 40.8014866,
    'longitude': -73.9442507,
    'name': 'E 118 St & Madison Ave',
    'timestamp': '2023-08-29T15:03:08.260000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321297,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': 'c05cd2e2-74e8-4526-a62b-d631e005fdd8'},
    'free_bikes': 25,
    'id': '7c93b03fd9d5f0fa1ce93f210c710fa4',
    'latitude': 40.7954121,
    'longitude': -73.9441232,
    'name': 'Lexington Ave & E 111 St',
    'timestamp': '2023-08-29T15:03:08.124000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321304,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': 'bacfe3c2-7946-45ed-91f9-f5b91791de75'},
    'free_bikes': 22,
    'id': '7eb38734b5e35fe8b9202889f8dcca96',
    'latitude': 40.80295,
    'longitude': -73.942954,
    'name': 'Madison Ave & E 120 St',
    'timestamp': '2023-08-29T15:03:08.686000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321280,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '16a4effc-282e-4053-b47b-31f734d50c08'},
    'free_bikes': 10,
    'id': '645bde44689ff52aad7ae3aa01c905d4',
    'latitude': 40.8029263,
    'longitude': -73.9379,
    'name': 'E 123 St & Lexington Ave',
    'timestamp': '2023-08-29T15:03:07.908000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321312,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '5f63411c-91ce-4788-a567-d388cc812a15'},
    'free_bikes': 15,
    'id': 'a76ab19c4509311cc751980108132140',
    'latitude': 40.805726,
    'longitude': -73.936322,
    'name': 'Lexington Ave & E 127 St',
    'timestamp': '2023-08-29T15:03:08.453000Z'},
   {'empty_slots': 26,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321279,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 36,
     'uid': '66880044-5411-4143-af39-eaa0a0fd0528'},
    'free_bikes': 5,
    'id': '6dd3be1c42d2801224d36eed03539007',
    'latitude': 40.8045555,
    'longitude': -73.9396861,
    'name': 'Park Ave & E 124 St',
    'timestamp': '2023-08-29T15:03:08.550000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321222,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '9bd28b11-cf11-4938-abb2-dfa5ec800e32'},
    'free_bikes': 21,
    'id': 'ec45725fb8cac55c40d277208369a68e',
    'latitude': 40.7668,
    'longitude': -73.9347774,
    'name': 'Broadway & 12 St',
    'timestamp': '2023-08-29T15:03:08.080000Z'},
   {'empty_slots': 28,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321318,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66de17f7-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': '089ca57ed3306a566f8fc5f789db8bda',
    'latitude': 40.7973721,
    'longitude': -73.97041192,
    'name': 'W 100 St & Broadway',
    'timestamp': '2023-08-29T15:03:08.467000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321274,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': 'b55f9b55-7fa7-4f0f-9732-78cbe07452e1'},
    'free_bikes': 19,
    'id': '946c9d2aa5511ee0a629011d55a7f8bd',
    'latitude': 40.8078316,
    'longitude': -73.949373,
    'name': 'Adam Clayton Powell Blvd & W 123 St',
    'timestamp': '2023-08-29T15:03:07.901000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321220,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '66de18d7-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 14,
    'id': 'c7e0b34860cbbe5f2c5e7a80fd7e4a46',
    'latitude': 40.67267243410948,
    'longitude': -74.0087952464819,
    'name': 'Sigourney St & Columbia St',
    'timestamp': '2023-08-29T15:03:07.918000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321262,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '66dd8043-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 5,
    'id': '538d22aa4498316f2b17bbe1c9ca1a7c',
    'latitude': 40.742677141,
    'longitude': -74.051788633,
    'name': 'Pershing Field',
    'timestamp': '2023-08-29T15:03:07.828000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321296,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '66dd80ac-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 10,
    'id': '561310c0bf4440df571218dbb4108f18',
    'latitude': 40.72152515,
    'longitude': -74.046304543,
    'name': 'Newark Ave',
    'timestamp': '2023-08-29T15:03:08.449000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321233,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '66dd836d-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': '18a15b65fad3b6966dfde11af4228b2d',
    'latitude': 40.734785818,
    'longitude': -74.050443636,
    'name': 'Christ Hospital',
    'timestamp': '2023-08-29T15:03:08.413000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321328,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '66dd83fc-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 5,
    'id': '8c272f8b59fc8e531c1c0b4881e54141',
    'latitude': 40.71848892,
    'longitude': -74.047726625,
    'name': 'Van Vorst Park',
    'timestamp': '2023-08-29T15:03:08.111000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321302,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66de1b5b-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 7,
    'id': '813720e50f9eb5f6e76d92902e29bc25',
    'latitude': 40.6711978,
    'longitude': -73.97484126,
    'name': 'Garfield Pl & 8 Ave',
    'timestamp': '2023-08-29T15:03:08.617000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321301,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '66db269c-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 13,
    'id': '86dd1eaeed1d32999c175aeb9ac6c972',
    'latitude': 40.71911552,
    'longitude': -74.00666661,
    'name': 'Franklin St & W Broadway',
    'timestamp': '2023-08-29T15:03:09.197000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321325,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '0e5be726-2452-42a0-9be8-ea85c8408e4c'},
    'free_bikes': 2,
    'id': '5b7043b7eec9b2ad7dc6f73c57874270',
    'latitude': 40.763154,
    'longitude': -73.920827,
    'name': '31 Ave & 34 St',
    'timestamp': '2023-08-29T15:03:08.894000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321334,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'd7904cd0-4b1b-47d0-8103-937bcf5ff845'},
    'free_bikes': 8,
    'id': '6f2c155b62077a2eaffe707650aa88c2',
    'latitude': 40.7682,
    'longitude': -73.9322662,
    'name': '31 Ave & 14 St',
    'timestamp': '2023-08-29T15:03:07.794000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 7,
     'has_ebikes': True,
     'last_updated': 1693321301,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '9e0b3452-ef6d-4e94-8c05-7bef199cdb74'},
    'free_bikes': 19,
    'id': '7d24d6c9fdd1d18f81a3b337b8976c0b',
    'latitude': 40.74252,
    'longitude': -73.948852,
    'name': '49 Ave & 21 St',
    'timestamp': '2023-08-29T15:03:08.372000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321280,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'a6287af0-9a9e-4708-b61f-8e758be4b914'},
    'free_bikes': 4,
    'id': '39c384bdac9b1870ad93844ab94c894a',
    'latitude': 40.7658346,
    'longitude': -73.9265474,
    'name': '31 Ave & Crescent St',
    'timestamp': '2023-08-29T15:03:09.052000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321299,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '4d4a3e7b-1005-4bfd-8680-340a20cacbee'},
    'free_bikes': 17,
    'id': '841c6f919dd98ef44d64b8626be51cae',
    'latitude': 40.7692475,
    'longitude': -73.9354504,
    'name': 'Vernon Blvd & 31 Ave',
    'timestamp': '2023-08-29T15:03:08.732000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321265,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '40eaa69a-d3ab-48fc-b395-b5bdc6a1aa85'},
    'free_bikes': 19,
    'id': '7575aa915fff164db3a86c7c01bf9e03',
    'latitude': 40.7423737,
    'longitude': -73.9566,
    'name': '5 St & 51 Ave',
    'timestamp': '2023-08-29T15:03:08.400000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321272,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66dce567-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 2,
    'id': '3c32d88754f29058719ce6e807497cf7',
    'latitude': 40.70510918,
    'longitude': -73.94407279,
    'name': 'McKibbin St & Manhattan Ave',
    'timestamp': '2023-08-29T15:03:08.206000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321327,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66dce5c9-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 9,
    'id': '6e2f1d7f281609f393a9334e3c98e391',
    'latitude': 40.70538077,
    'longitude': -73.94976519,
    'name': 'Boerum St & Broadway',
    'timestamp': '2023-08-29T15:03:09.087000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321300,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '66dce660-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 10,
    'id': '707500d1124ef5654f939818c9324f9c',
    'latitude': 40.70583339,
    'longitude': -73.94644578,
    'name': 'Leonard St & Boerum St',
    'timestamp': '2023-08-29T15:03:08.488000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321296,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '20f3a578-4dfa-45ca-a917-b394d77ee08e'},
    'free_bikes': 16,
    'id': '48142d92a4bb21ac71a1de0cbe29e105',
    'latitude': 40.698568,
    'longitude': -73.918877,
    'name': 'Greene Av & Myrtle Av',
    'timestamp': '2023-08-29T15:03:08.651000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321275,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 42,
     'uid': '66dce8db-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': 'a1ad1ac3be7f33a2cc2f64ca6201d296',
    'latitude': 40.70767788,
    'longitude': -73.94016171,
    'name': 'Montrose Ave & Bushwick Ave',
    'timestamp': '2023-08-29T15:03:07.852000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321326,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '66dce9b5-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 16,
    'id': '8c6dcdad08fc4ef2bc8c98f99a7593f4',
    'latitude': 40.70708701,
    'longitude': -73.95796783,
    'name': 'Division Ave & Marcy Ave',
    'timestamp': '2023-08-29T15:03:09.091000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321280,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 36,
     'uid': '66dcec6b-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 14,
    'id': '24fde84fb18af98c2f08d47bc0a412da',
    'latitude': 40.70870368,
    'longitude': -73.9448625,
    'name': 'Scholes St & Manhattan Ave',
    'timestamp': '2023-08-29T15:03:07.927000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321320,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '66dcecfa-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 12,
    'id': '883a8eddceac5b79d18964a2c93b4299',
    'latitude': 40.70877084,
    'longitude': -73.95095259,
    'name': 'Stagg St & Union Ave',
    'timestamp': '2023-08-29T15:03:08.935000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321262,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66dced76-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 12,
    'id': '1b6b7fb7ad25edb493df384b604f554e',
    'latitude': 40.70924826276157,
    'longitude': -73.96063148975372,
    'name': 'Broadway & Roebling St',
    'timestamp': '2023-08-29T15:03:08.623000Z'},
   {'empty_slots': 27,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321279,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '66dd4f31-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 5,
    'id': 'e51e99a23d48a9c4a09186086ae142b1',
    'latitude': 40.78499979,
    'longitude': -73.97283406,
    'name': 'W 84 St & Columbus Ave',
    'timestamp': '2023-08-29T15:03:07.833000Z'},
   {'empty_slots': 66,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321315,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 79,
     'uid': '66dd51e6-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 10,
    'id': '2d224ee6cf5206906fb1dcbf4a2f9341',
    'latitude': 40.777507027547976,
    'longitude': -73.98888587951659,
    'name': 'Riverside Blvd & W 67 St',
    'timestamp': '2023-08-29T15:03:08.625000Z'},
   {'empty_slots': 62,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321315,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 84,
     'uid': '66dc36c3-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 18,
    'id': '70e976015d643dec7d92aa5ade89ffc3',
    'latitude': 40.74345335,
    'longitude': -74.00004031,
    'name': 'W 20 St & 8 Ave',
    'timestamp': '2023-08-29T15:03:08.325000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321325,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66de2771-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 17,
    'id': '6b4a63f8d6e26d135537605542d2452b',
    'latitude': 40.6786115,
    'longitude': -73.99037292,
    'name': 'Carroll St & Bond St',
    'timestamp': '2023-08-29T15:03:09.163000Z'},
   {'empty_slots': 24,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321305,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 48,
     'uid': '66de2707-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': '5b8507879041ff08ee115e08fd0d8f86',
    'latitude': 40.76471851944339,
    'longitude': -73.96222069859505,
    'name': 'E 65 St & 2 Ave',
    'timestamp': '2023-08-29T15:03:07.991000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321335,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 36,
     'uid': '66de2625-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 29,
    'id': '97fa5a66185c2ec7bd1ce1ddcd55a511',
    'latitude': 40.799484,
    'longitude': -73.955613,
    'name': 'Central Park North & Adam Clayton Powell Blvd',
    'timestamp': '2023-08-29T15:03:09.168000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321319,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 79,
     'uid': '66de25bd-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 70,
    'id': '54a68a59d99ec74a45a0304fd8f09a6b',
    'latitude': 40.6750705,
    'longitude': -73.98775226,
    'name': '3 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:08.412000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 7,
     'has_ebikes': True,
     'last_updated': 1693321287,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '1d32e684-602b-46b6-8c96-ab47b57a03f3'},
    'free_bikes': 11,
    'id': '851267ffa8105207e15235cda592e7aa',
    'latitude': 40.678045,
    'longitude': -73.962408,
    'name': 'Grand Ave & Bergen St',
    'timestamp': '2023-08-29T15:03:08.061000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321312,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '66db2fd0-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 22,
    'id': '0fa2cacd8c38d7cb17a1a3cb329ddb79',
    'latitude': 40.722103786686034,
    'longitude': -73.99724900722504,
    'name': 'Cleveland Pl & Spring St',
    'timestamp': '2023-08-29T15:03:08.587000Z'},
   {'empty_slots': 60,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321272,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 84,
     'uid': '66db2f4c-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 22,
    'id': '18250bce34620be3145146225e0c6af8',
    'latitude': 40.7208736,
    'longitude': -73.98085795,
    'name': 'E 2 St & Avenue C',
    'timestamp': '2023-08-29T15:03:07.881000Z'},
   {'empty_slots': 25,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321278,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '47bcbcc1-9241-4e65-99f1-07c15543be1b'},
    'free_bikes': 6,
    'id': '41de4c42e53f2e2dae4994f433538043',
    'latitude': 40.68186,
    'longitude': -73.959432,
    'name': 'Fulton St & Irving Pl',
    'timestamp': '2023-08-29T15:03:08.145000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321327,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66db316a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 12,
    'id': '23b19ea92ffa9dbd88eafef6a0e17ac5',
    'latitude': 40.69089272,
    'longitude': -73.99612349,
    'name': 'Henry St & Atlantic Ave',
    'timestamp': '2023-08-29T15:03:07.876000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321281,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '66ddebce-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 19,
    'id': '874e3857f3d80394ca08517e44b2e5ed',
    'latitude': 40.7859201,
    'longitude': -73.94860294,
    'name': 'E 97 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:08.693000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 8,
     'has_ebikes': True,
     'last_updated': 1693321277,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66ddea99-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 11,
    'id': '8ea1a7fbe7d3a690babcf1c8f68de17a',
    'latitude': 40.6662078,
    'longitude': -73.98199886,
    'name': '10 St & 7 Ave',
    'timestamp': '2023-08-29T15:03:08.949000Z'},
   {'empty_slots': 27,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321309,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 49,
     'uid': '9394fb49-583f-4426-8d2f-a2b0ffb584d2'},
    'free_bikes': 15,
    'id': 'a8dee20d016ad4ee4c77c06885012ebc',
    'latitude': 40.720747,
    'longitude': -73.986274,
    'name': 'Stanton St & Norfolk St',
    'timestamp': '2023-08-29T15:03:07.760000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321334,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66dde9af-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 5,
    'id': 'dedcafc1e87ea571b61903825182daf6',
    'latitude': 40.668127,
    'longitude': -73.98377641,
    'name': '6 Ave & 9 St',
    'timestamp': '2023-08-29T15:03:09.117000Z'},
   {'empty_slots': 27,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321297,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 46,
     'uid': '66dd1c7f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 20,
    'id': '019ba8bbabfd919a52719ed738b4b3f1',
    'latitude': 40.72557,
    'longitude': -73.94434,
    'name': 'Nassau Ave & Russell St',
    'timestamp': '2023-08-29T15:03:08.693000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321325,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '66dd1d0f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 14,
    'id': 'f2b816c01071e8567677767151ae17c1',
    'latitude': 40.72606,
    'longitude': -73.95621,
    'name': 'Banker St & Meserole Ave',
    'timestamp': '2023-08-29T15:03:08.195000Z'},
   {'empty_slots': 55,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321232,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 64,
     'uid': '66dc3ab9-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 5,
    'id': '324b7111c8f0114b7fe0e5bed4f56a2a',
    'latitude': 40.72110063,
    'longitude': -73.9919254,
    'name': 'Rivington St & Chrystie St',
    'timestamp': '2023-08-29T15:03:09.265000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321311,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 54,
     'uid': '66dd1ad8-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 45,
    'id': 'c1a71a685ac90231ac228e1c7a7bcb7d',
    'latitude': 40.724055,
    'longitude': -73.955736,
    'name': 'N 15 St & Wythe Ave',
    'timestamp': '2023-08-29T15:03:08.036000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321271,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '66dd6000-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 11,
    'id': '9c3c6869a6b193169d6927bca74182cf',
    'latitude': 40.7253399253558,
    'longitude': -74.06762212514877,
    'name': 'McGinley Square',
    'timestamp': '2023-08-29T15:03:08.857000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321258,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '66dd5f24-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 8,
    'id': 'cf11d2987b56423bca5f8dbacc1b2dfd',
    'latitude': 40.7112423,
    'longitude': -74.0557013,
    'name': 'Liberty Light Rail',
    'timestamp': '2023-08-29T15:03:08.438000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 8,
     'has_ebikes': True,
     'last_updated': 1693321315,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '66dd5e69-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 15,
    'id': '5fb450a30421027d1aa0578be6905b9f',
    'latitude': 40.7182113,
    'longitude': -74.0836394,
    'name': 'Union St',
    'timestamp': '2023-08-29T15:03:09.121000Z'},
   {'empty_slots': 53,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321242,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 69,
     'uid': '66dc51e9-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 11,
    'id': 'b49a8857cb598fc8b1d1f168f537ee64',
    'latitude': 40.75066386,
    'longitude': -74.00176802,
    'name': '10 Ave & W 28 St',
    'timestamp': '2023-08-29T15:03:08.922000Z'},
   {'empty_slots': 64,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321335,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 79,
     'uid': '66dc462a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 10,
    'id': 'a8e4f5927117033cc82f2d9342c65fb0',
    'latitude': 40.73935542,
    'longitude': -73.99931783,
    'name': 'W 15 St & 7 Ave',
    'timestamp': '2023-08-29T15:03:09.076000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321287,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66dc4599-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': 'd0db03806047aa9e8784b1efa8fcabb4',
    'latitude': 40.71260486,
    'longitude': -73.96264403,
    'name': 'S 3 St & Bedford Ave',
    'timestamp': '2023-08-29T15:03:08.411000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321286,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': 'd47c856e-8cda-4da0-b8eb-1ccf0e6ef7ab'},
    'free_bikes': 18,
    'id': 'e778cc46a14fd10472aaa5977915551b',
    'latitude': 40.698458,
    'longitude': -73.997178,
    'name': 'Brooklyn Bridge Park - Pier 2',
    'timestamp': '2023-08-29T15:03:07.802000Z'},
   {'empty_slots': 29,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321330,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66de71af-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': '70574df401e351180d95614207ad53a7',
    'latitude': 40.68506807308177,
    'longitude': -73.97790759801863,
    'name': 'Hanson Pl & Ashland Pl',
    'timestamp': '2023-08-29T15:03:09.326000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321338,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '17ba4945-b202-4667-965f-211d80622646'},
    'free_bikes': 4,
    'id': '2d7fb499888db0d85db6a5906ddf107a',
    'latitude': 40.69985,
    'longitude': -73.97141,
    'name': 'Dock 72 Way & Market St',
    'timestamp': '2023-08-29T15:03:09.273000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321296,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '66de63cd-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': 'b208a0cc0d98553ac4d98441bd0080a9',
    'latitude': 40.6859296,
    'longitude': -74.00242364,
    'name': 'Columbia St & Degraw St',
    'timestamp': '2023-08-29T15:03:08.407000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '66de6100-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 15,
    'id': '8a1d4b204452309a2c14557dca6784a5',
    'latitude': 40.6802133,
    'longitude': -73.98432695,
    'name': 'Douglass St & 3 Ave',
    'timestamp': '2023-08-29T15:03:07.893000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321331,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '66de6a0f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 18,
    'id': 'c4ba418543b9d557e5842aa20d0719dc',
    'latitude': 40.7892105,
    'longitude': -73.94370784,
    'name': '2 Ave & E 104 St',
    'timestamp': '2023-08-29T15:03:09.083000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321221,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66de677e-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 23,
    'id': 'd78d5b273bd184cb40f51c07e5e16368',
    'latitude': 40.791976,
    'longitude': -73.945993,
    'name': 'E 106 St & Lexington Ave',
    'timestamp': '2023-08-29T15:03:08.857000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321296,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 57,
     'uid': '66dc8eb1-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 35,
    'id': '9a3c74d24bb5a026189eb4b0424ba582',
    'latitude': 40.716887,
    'longitude': -73.963198,
    'name': 'Wythe Ave & Metropolitan Ave',
    'timestamp': '2023-08-29T15:03:09.340000Z'},
   {'empty_slots': 35,
    'extra': {'ebikes': 11,
     'has_ebikes': True,
     'last_updated': 1693321338,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 73,
     'uid': '66dc9068-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 33,
    'id': 'bf18fd8a51f0479877003db0b3f63e92',
    'latitude': 40.76590936,
    'longitude': -73.97634151,
    'name': 'Central Park S & 6 Ave',
    'timestamp': '2023-08-29T15:03:07.921000Z'},
   {'empty_slots': 59,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321336,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 71,
     'uid': '66dc3f08-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': '9b1d40dd738e6341ec5b72cd32835a97',
    'latitude': 40.75640548,
    'longitude': -73.9900262,
    'name': 'W 41 St & 8 Ave',
    'timestamp': '2023-08-29T15:03:08.800000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321314,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '78e93937-53d1-4c9b-99ad-0460f908ed2d'},
    'free_bikes': 5,
    'id': '926e84ac8a0bdcbd908efcd90ebea59c',
    'latitude': 40.69535693320225,
    'longitude': -73.99344027042389,
    'name': 'Pierrepont St & Monroe Pl',
    'timestamp': '2023-08-29T15:03:07.871000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321327,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '66dc9143-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 15,
    'id': 'aece94aba5628d18ff397efd44cd1b83',
    'latitude': 40.71117444,
    'longitude': -73.99682619,
    'name': 'Catherine St & Monroe St',
    'timestamp': '2023-08-29T15:03:08.824000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 14,
     'uid': '66dd6441-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 10,
    'id': 'ac5b196873c4e9c2c080b16800ab6938',
    'latitude': 40.7287448,
    'longitude': -74.0321082,
    'name': 'Newport Pkwy',
    'timestamp': '2023-08-29T15:03:09.180000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321241,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '66dd63de-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': '971835d129ea8951568e07707179d213',
    'latitude': 40.748715945380226,
    'longitude': -74.04044330120087,
    'name': 'Heights Elevator',
    'timestamp': '2023-08-29T15:03:08.802000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321238,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 50,
     'uid': '66dd2060-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': '5ab1be81691c82c2b1d13b0b17f6e601',
    'latitude': 40.73232194,
    'longitude': -73.9550858,
    'name': 'India St & Manhattan Ave',
    'timestamp': '2023-08-29T15:03:08.220000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321328,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '7f8cb36a-2bf4-4d57-afbd-331310f25355'},
    'free_bikes': 32,
    'id': '982705fafa8b33f9f04adef46002eced',
    'latitude': 40.813358,
    'longitude': -73.956461,
    'name': 'Amsterdam Ave & W 125 St',
    'timestamp': '2023-08-29T15:03:09.002000Z'},
   {'empty_slots': 25,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321324,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '2f580cf9-14e2-4300-ba22-f6d88d0312a5'},
    'free_bikes': 0,
    'id': '6d6db91d6f03b43f47cd31f938bd2978',
    'latitude': 40.665816,
    'longitude': -73.956934,
    'name': 'Bedford Ave & Montgomery St',
    'timestamp': '2023-08-29T15:03:08.558000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693289300,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 0,
     'returning': 0,
     'slots': 61,
     'uid': '66dc7a7d-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 44,
    'id': '726ff321bb6d84cfedb23b88348ccb0c',
    'latitude': 40.7454973,
    'longitude': -74.00197139,
    'name': '9 Ave & W 22 St',
    'timestamp': '2023-08-29T15:03:08.668000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321292,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': 'e4645d0d-8b76-4c46-b2b9-be25592e0659'},
    'free_bikes': 7,
    'id': '6764f539ed7a4a3b088607a23d2d4cc6',
    'latitude': 40.7577284,
    'longitude': -73.9166368,
    'name': '43 St & Broadway',
    'timestamp': '2023-08-29T15:03:09.090000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 19,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 60,
     'uid': '66db40ef-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 52,
    'id': 'dc49cf8ba087c4d478091d789e37f632',
    'latitude': 40.72456089,
    'longitude': -73.99565293,
    'name': 'Lafayette St & Jersey St',
    'timestamp': '2023-08-29T15:03:07.815000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 70,
     'uid': '66dc481a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': '7b66ac17087e125a981fa9b3e6add5b8',
    'latitude': 40.73223272,
    'longitude': -73.98889957,
    'name': 'E 12 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:08.543000Z'},
   {'empty_slots': 29,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321338,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '66dbcd6c-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 2,
    'id': 'c811299eb1b09fb7d3f0409a0a704214',
    'latitude': 40.693261,
    'longitude': -73.968896,
    'name': 'Clinton Ave & Myrtle Ave',
    'timestamp': '2023-08-29T15:03:08.578000Z'},
   {'empty_slots': 35,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321237,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 40,
     'uid': '0927e331-866f-4d99-99b4-04edde99117a'},
    'free_bikes': 3,
    'id': '90de5e4d1a85a839e644c5130c2a9997',
    'latitude': 40.7739825,
    'longitude': -73.9309134,
    'name': '27 Ave & 9 St',
    'timestamp': '2023-08-29T15:03:08.157000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 29,
     'has_ebikes': True,
     'last_updated': 1693321323,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 51,
     'uid': '66dc21d4-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 49,
    'id': '43422db459689ec0dd5ba2c123fccba1',
    'latitude': 40.7597108,
    'longitude': -73.97402311,
    'name': 'E 53 St & Madison Ave',
    'timestamp': '2023-08-29T15:03:07.935000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321320,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '285ad3c2-3ffe-45bb-8765-9c20a69641a6'},
    'free_bikes': 13,
    'id': '14c0be38f160b09b54e068da447653a0',
    'latitude': 40.77485,
    'longitude': -73.9342,
    'name': '27 Ave & 3 St',
    'timestamp': '2023-08-29T15:03:07.997000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321299,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '66de0861-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 5,
    'id': '8fca55f861cd1150b71d4ced1fd99ecc',
    'latitude': 40.7849032,
    'longitude': -73.950503,
    'name': 'E 95 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:09.021000Z'},
   {'empty_slots': 24,
    'extra': {'ebikes': 9,
     'has_ebikes': True,
     'last_updated': 1693321271,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 61,
     'uid': 'b30815c0-99b6-451b-be15-902992cb8abb'},
    'free_bikes': 35,
    'id': '2c194f6fc2097a08ffbf530ba7f7338c',
    'latitude': 40.734814,
    'longitude': -73.992085,
    'name': 'University Pl & E 14 St',
    'timestamp': '2023-08-29T15:03:08.980000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 9,
     'has_ebikes': True,
     'last_updated': 1693321265,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 41,
     'uid': 'a47f77a2-9008-4652-a4f1-b95eee723a1b'},
    'free_bikes': 32,
    'id': 'e12edc95bb599768fabe39f26c860a64',
    'latitude': 40.754691750226016,
    'longitude': -73.99740189313889,
    'name': 'W 35 St & Dyer Ave',
    'timestamp': '2023-08-29T15:03:09.230000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321267,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '18eccc71-66be-4e4c-8335-095a9bf0df94'},
    'free_bikes': 24,
    'id': '6738dc0fa0de1a50ea7a023a3c28895a',
    'latitude': 40.809495347779475,
    'longitude': -73.94776493310928,
    'name': 'Adam Clayton Powell Blvd & W 126 St',
    'timestamp': '2023-08-29T15:03:07.865000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321256,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66de1ea2-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': '8626877ac7e23beb17e3139467234e8e',
    'latitude': 40.6740886,
    'longitude': -73.9787282,
    'name': 'Carroll St & 6 Ave',
    'timestamp': '2023-08-29T15:03:07.823000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321327,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '66de12ff-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': '3c7bb5e149846496e9e48fe0358803b8',
    'latitude': 40.7997568,
    'longitude': -73.9621128676,
    'name': 'W 107 St & Columbus Ave',
    'timestamp': '2023-08-29T15:03:07.821000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321312,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': 'a3d72b5b-9587-4f33-9722-c01e20a9b358'},
    'free_bikes': 11,
    'id': 'b4b6c2f152fb4249dbcf77bde1539acd',
    'latitude': 40.69502,
    'longitude': -73.92825,
    'name': 'Bushwick Ave & Dekalb Ave',
    'timestamp': '2023-08-29T15:03:08.008000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 7,
     'has_ebikes': True,
     'last_updated': 1693321295,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '29b21bd8-2459-4727-b1f0-d73592db3321'},
    'free_bikes': 27,
    'id': '1345e945ccfe6fa245b13c204d4d2dcf',
    'latitude': 40.70099,
    'longitude': -73.93921,
    'name': 'Beaver St & Fayette St',
    'timestamp': '2023-08-29T15:03:08.979000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321287,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '0575e356-72f4-4251-8e15-574cf60bd190'},
    'free_bikes': 1,
    'id': 'c190723e40db4e9975304ba6a8423136',
    'latitude': 40.70076,
    'longitude': -73.93641,
    'name': 'Bushwick Ave & Forrest St',
    'timestamp': '2023-08-29T15:03:07.969000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321322,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '2c2cdc55-52a3-4140-b4d3-8409a98f130f'},
    'free_bikes': 14,
    'id': 'c956a70f3ed8b42898e4882b0de39a9c',
    'latitude': 40.70106,
    'longitude': -73.93318,
    'name': 'Evergreen Ave & Noll St',
    'timestamp': '2023-08-29T15:03:08.262000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321238,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': 'c3b255d8-b690-4825-b1e9-a1d1680e5542'},
    'free_bikes': 18,
    'id': '3955ea4606e81135f7975a51b0fa6912',
    'latitude': 40.73124,
    'longitude': -73.95161,
    'name': 'Kent St & McGuinness Blvd',
    'timestamp': '2023-08-29T15:03:08.216000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321299,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '467e1de6-73a6-480f-9e83-fd1b03b71047'},
    'free_bikes': 14,
    'id': '5da353e46035ba3654f54af8f2fe4d40',
    'latitude': 40.716657,
    'longitude': -73.93637,
    'name': 'Morgan Ave & Maspeth Ave',
    'timestamp': '2023-08-29T15:03:08.929000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321337,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': 'faf021ad-9de5-44bd-b7f5-48127e8d5fea'},
    'free_bikes': 8,
    'id': '78880a5550c3d6235dbef7ccaec74073',
    'latitude': 40.71429,
    'longitude': -73.93323,
    'name': 'Metropolitan Ave & Vandervoort Ave',
    'timestamp': '2023-08-29T15:03:08.732000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 40,
     'uid': '606c7384-75e9-4988-858a-07b88b3a9413'},
    'free_bikes': 36,
    'id': '16531217785cebb9c9fc0a169b98f41b',
    'latitude': 40.72984,
    'longitude': -73.94839,
    'name': 'Calyer St & Jewel St',
    'timestamp': '2023-08-29T15:03:09.017000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321297,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '3c5a8531-4eec-4695-b4f8-8a1158890e78'},
    'free_bikes': 7,
    'id': '832bea3175d9d41c33795a52a1e74647',
    'latitude': 40.71773,
    'longitude': -73.94051,
    'name': 'Withers St & Kingsland Ave',
    'timestamp': '2023-08-29T15:03:07.788000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321306,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': 'cac843c2-8b21-47bb-a3b9-712f95d7f7aa'},
    'free_bikes': 17,
    'id': '0243a8e61a86e32894867c42ebd883e6',
    'latitude': 40.70686,
    'longitude': -73.92851,
    'name': 'Harrison Pl & Porter Ave',
    'timestamp': '2023-08-29T15:03:09.204000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321283,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '74feba30-26a5-4949-b3a0-d6e13ba1a20c'},
    'free_bikes': 5,
    'id': 'e5a29af3b9346d4415f00946adafbd18',
    'latitude': 40.72158,
    'longitude': -73.94546,
    'name': 'Engert Ave & McGuinness Blvd',
    'timestamp': '2023-08-29T15:03:08.885000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321330,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '5ffde991-1125-443e-bc97-6827b2b9c97b'},
    'free_bikes': 14,
    'id': 'b5c4ad1cbac234b67785a1ab920eb044',
    'latitude': 40.70907,
    'longitude': -73.92157,
    'name': 'Jefferson St & Cypress Ave',
    'timestamp': '2023-08-29T15:03:08.327000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321336,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '625711ba-3b5d-46a7-a8f9-7f4eb17ec1be'},
    'free_bikes': 5,
    'id': '5af807984575b67985bd22363163ce9e',
    'latitude': 40.8006721,
    'longitude': -73.9349,
    'name': '2 Ave & E 122 St',
    'timestamp': '2023-08-29T15:03:08.992000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321313,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': 'a958a8af-a0cc-4bca-9114-93c74ce3c693'},
    'free_bikes': 3,
    'id': '075cb64ad38a768d35a946e0677711ee',
    'latitude': 40.71882,
    'longitude': -73.93948,
    'name': 'Frost St & Debevoise Ave',
    'timestamp': '2023-08-29T15:03:08.097000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321307,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '6c3b486e-603c-4158-91ac-adc06ac01535'},
    'free_bikes': 6,
    'id': '745d9941bfa35e63423c490e8f28a558',
    'latitude': 40.69943,
    'longitude': -73.91337,
    'name': 'Myrtle Ave & Linden St',
    'timestamp': '2023-08-29T15:03:07.944000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321306,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'b1f67e5c-7c26-4bf3-a90e-1500a3160d60'},
    'free_bikes': 7,
    'id': 'd8e4277a5b4faf9fe259c98196c57f08',
    'latitude': 40.69905,
    'longitude': -73.91516,
    'name': 'Myrtle Ave & Grove St',
    'timestamp': '2023-08-29T15:03:08.989000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321335,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '6ca15d94-897a-4c81-ab47-366829afb7c4'},
    'free_bikes': 3,
    'id': '53ec070643f5cddb105c712b2fa65f13',
    'latitude': 40.69811,
    'longitude': -73.90904,
    'name': 'Putnam Ave & Wyckoff Ave',
    'timestamp': '2023-08-29T15:03:08.984000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321286,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 0,
     'returning': 0,
     'slots': 29,
     'uid': '66de65a4-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': '9b0d034b69bb85e6e92e0bc81afd4e1a',
    'latitude': 40.6610633719006,
    'longitude': -73.97945255041122,
    'name': 'West Drive & Prospect Park West',
    'timestamp': '2023-08-29T15:03:08.819000Z'},
   {'empty_slots': 22,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321336,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': '18b19467-28ac-4496-b3e4-f6028b1c5105'},
    'free_bikes': 5,
    'id': '6b7ec19312601525ed314a5b61a56ca3',
    'latitude': 40.69545,
    'longitude': -73.91164,
    'name': 'Putnam Ave & Knickerbocker Ave',
    'timestamp': '2023-08-29T15:03:08.003000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321248,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 26,
     'uid': 'f401cd5f-cb41-41f8-a857-4a4dfe778f94'},
    'free_bikes': 18,
    'id': '3221463e83d66f3d1819362a9684f70f',
    'latitude': 40.70166,
    'longitude': -73.92754,
    'name': 'Wilson Ave & Troutman St',
    'timestamp': '2023-08-29T15:03:09.135000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321262,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 17,
     'uid': 'cd4b8e12-b2c7-479b-900d-59cf7d8c4276'},
    'free_bikes': 17,
    'id': 'f44617115ed7859dd13175873d9f2ef2',
    'latitude': 40.70869,
    'longitude': -73.92587,
    'name': 'Stewart Ave & Johnson Ave',
    'timestamp': '2023-08-29T15:03:07.811000Z'},
   {'empty_slots': 25,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321238,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 32,
     'uid': '7603028c-8b04-4918-8a25-a087ce57aea4'},
    'free_bikes': 6,
    'id': '58f9506fecf4934c33a72d88e543e7da',
    'latitude': 40.69544,
    'longitude': -73.93223,
    'name': 'Suydam St & Broadway',
    'timestamp': '2023-08-29T15:03:07.945000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321319,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': 'f6cf3ecc-b3ad-4291-8c24-277f28f64ba1'},
    'free_bikes': 18,
    'id': '42d9f597d252f889438ec2c9fd63722c',
    'latitude': 40.703545,
    'longitude': -73.917775,
    'name': 'Wyckoff Av & Stanhope St',
    'timestamp': '2023-08-29T15:03:08.039000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321233,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '201edb67-d071-4b67-bafd-131e5c273e9f'},
    'free_bikes': 8,
    'id': 'd8b64bdc251e0d9501d5cd52f5f89e00',
    'latitude': 40.71401,
    'longitude': -73.92793,
    'name': 'Metropolitan Ave & Stewart Ave',
    'timestamp': '2023-08-29T15:03:09.113000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321320,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': 'ee70b21e-4a95-4bdf-802c-50f83a76971d'},
    'free_bikes': 15,
    'id': '486ceb4d4947975e838e0813bccb79a0',
    'latitude': 40.69671,
    'longitude': -73.92807,
    'name': 'Cedar St & Evergreen Ave',
    'timestamp': '2023-08-29T15:03:08.944000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321318,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '45e8c326-b12d-4be6-b040-bb6de9986d25'},
    'free_bikes': 13,
    'id': 'bff5b0d573e519482ccbe006b0c01889',
    'latitude': 40.70108,
    'longitude': -73.9179,
    'name': 'Irving Ave & Harman St',
    'timestamp': '2023-08-29T15:03:09.297000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321219,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': 'db02e1ea-acc1-4f45-8e3c-d37468b0b5a6'},
    'free_bikes': 1,
    'id': '07e727282a35ccfd7571bd841c3aafbc',
    'latitude': 40.70113,
    'longitude': -73.91422,
    'name': 'Menahan St & Wyckoff Ave',
    'timestamp': '2023-08-29T15:03:07.840000Z'},
   {'empty_slots': 24,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321231,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 41,
     'uid': '632b140c-65de-4f50-9cc2-c001ae011aea'},
    'free_bikes': 12,
    'id': '7189cc9b22b198e98e1a764bd1ae52be',
    'latitude': 40.755293,
    'longitude': -73.967641,
    'name': 'E 51 St & 2 Ave',
    'timestamp': '2023-08-29T15:03:07.857000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321274,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '66dd650d-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 7,
    'id': '521119b127f5d59223834d3e1492390f',
    'latitude': 40.737711,
    'longitude': -74.066921,
    'name': 'Dey St',
    'timestamp': '2023-08-29T15:03:07.789000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321278,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '807e9f5a-49b6-4b7e-847b-4a60cff330ed'},
    'free_bikes': 6,
    'id': '984ecf4c65024611cb39a1d36462ded5',
    'latitude': 40.69714,
    'longitude': -73.91566,
    'name': 'Linden St & Knickerbocker Ave',
    'timestamp': '2023-08-29T15:03:07.767000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321292,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '77463580-6421-403d-b170-f2660c216175'},
    'free_bikes': 17,
    'id': '4ede1bf348abc507c516fae5eea8794c',
    'latitude': 40.69543,
    'longitude': -73.9196,
    'name': 'Menahan St & Central Ave',
    'timestamp': '2023-08-29T15:03:08.929000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321304,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '372c592e-09d8-400c-9595-2aa3510f39b0'},
    'free_bikes': 8,
    'id': '15d8188f7411df3c726ebb9cc5227d9c',
    'latitude': 40.69676,
    'longitude': -73.92302,
    'name': 'Central Ave & Himrod St',
    'timestamp': '2023-08-29T15:03:08.401000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321283,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '457ea5d7-d643-4028-87db-46dee0b81555'},
    'free_bikes': 7,
    'id': '763391f79cc86bc62782448b65dbdc60',
    'latitude': 40.72577,
    'longitude': -73.94173,
    'name': 'Kingsland Ave & Nassau Ave',
    'timestamp': '2023-08-29T15:03:08.423000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321226,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': 'b35ba3c0-d3e8-4b1a-b63b-73a7bb518c9e'},
    'free_bikes': 8,
    'id': '18c71bbba7ba08fc15e7d99064a53619',
    'latitude': 40.698,
    'longitude': -73.9127,
    'name': 'Irving Ave & Palmetto St',
    'timestamp': '2023-08-29T15:03:08.999000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321326,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '5f0aa684-a1c5-4119-827f-7860f1cd4ccd'},
    'free_bikes': 4,
    'id': '7cddd2f662d2678a9362fc5cde5911fe',
    'latitude': 40.69356,
    'longitude': -73.92524,
    'name': 'Bushwick Ave & Harman St',
    'timestamp': '2023-08-29T15:03:08.780000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321299,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': 'd5ca6311-7471-480f-9c79-38baaafe34ba'},
    'free_bikes': 9,
    'id': '3b3fff63f52fde6cb7865911b744ceb7',
    'latitude': 40.69329,
    'longitude': -73.92852,
    'name': 'Broadway & Kosciuszko St',
    'timestamp': '2023-08-29T15:03:07.836000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321330,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '9b7e3b8b-97ef-4038-820c-7cd1c1a34fc7'},
    'free_bikes': 25,
    'id': 'fe2a26e3b83b8f78257e86a61a0319bb',
    'latitude': 40.796879,
    'longitude': -73.937261,
    'name': 'E 116 St & 2 Ave',
    'timestamp': '2023-08-29T15:03:08.274000Z'},
   {'empty_slots': 29,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321336,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66dd455e-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': 'bb24afbebd5d2bef22459dd3f7222574',
    'latitude': 40.77801203,
    'longitude': -73.95407149,
    'name': 'E 85 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:08.621000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321287,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '4cfd4097-0aee-4f11-9aea-55f99397bf33'},
    'free_bikes': 7,
    'id': 'b5ff383e304fe0ef6022e0e3279bcb5d',
    'latitude': 40.69467,
    'longitude': -73.90663,
    'name': 'Irving Ave & Halsey St',
    'timestamp': '2023-08-29T15:03:08.359000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321316,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '3134bce7-0bb9-4a45-9c87-60a8cb681d72'},
    'free_bikes': 5,
    'id': 'd7ff9ddcb3a6e60ebc30a9b496c0f0b2',
    'latitude': 40.69296,
    'longitude': -73.91605,
    'name': 'Central Ave & Woodbine St',
    'timestamp': '2023-08-29T15:03:08.561000Z'},
   {'empty_slots': 26,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321326,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': '74723006-b32f-4590-8cc7-f15eec3808fe'},
    'free_bikes': 2,
    'id': 'dd78df6830d7425d95f485bcb28e4c15',
    'latitude': 40.69146,
    'longitude': -73.92146,
    'name': 'Bushwick Ave & Linden St',
    'timestamp': '2023-08-29T15:03:08.914000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321329,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '2576805f-9732-4c74-8f1d-57715e8cdfa2'},
    'free_bikes': 12,
    'id': 'dd6c9e7ddf47dceedcfa3ae900c35247',
    'latitude': 40.68929,
    'longitude': -73.90951,
    'name': 'Central Ave & Covert St',
    'timestamp': '2023-08-29T15:03:09.242000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '3c8847a6-c12a-40fd-9b22-4582ac1a0d9d'},
    'free_bikes': 6,
    'id': '8b09a12b4acd8ea899ad55328fd44d3e',
    'latitude': 40.6882,
    'longitude': -73.90798,
    'name': 'Central Ave & Decatur St',
    'timestamp': '2023-08-29T15:03:09.153000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321292,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': 'd473f31f-68f2-4777-a364-ed127db04345'},
    'free_bikes': 5,
    'id': '881cb266a3992ff4a2c687e42bca1ef1',
    'latitude': 40.68458,
    'longitude': -73.90925,
    'name': 'Moffat St & Bushwick',
    'timestamp': '2023-08-29T15:03:08.209000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321238,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '5f968a1b-ee60-43a0-ad25-05211e09e436'},
    'free_bikes': 5,
    'id': 'f01591acb276fa1bab2327cf6e09733d',
    'latitude': 40.68652,
    'longitude': -73.91321,
    'name': 'Eldert St & Bushwick Ave',
    'timestamp': '2023-08-29T15:03:07.734000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321303,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': 'fd081854-3f37-420a-9785-ea63c09c12ad'},
    'free_bikes': 6,
    'id': '1b36479642e1022ce87b3eafafc73308',
    'latitude': 40.68565,
    'longitude': -73.91564,
    'name': 'Halsey St & Broadway',
    'timestamp': '2023-08-29T15:03:08.370000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321289,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': 'ad57266c-34da-43da-8b48-2ba856002fbf'},
    'free_bikes': 25,
    'id': 'dbac722ca285560c5105c463201b3ce9',
    'latitude': 40.69047,
    'longitude': -73.923511,
    'name': 'Grove St & Broadway',
    'timestamp': '2023-08-29T15:03:08.196000Z'},
   {'empty_slots': 30,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321325,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66dde208-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 9,
    'id': '21f0628c68c7e9d446102de114170bfa',
    'latitude': 40.7806284,
    'longitude': -73.9521667,
    'name': 'E 89 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:08.892000Z'},
   {'empty_slots': 27,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321267,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '66dde3b1-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 8,
    'id': '42dda0d9c27369af876666c8f866b190',
    'latitude': 40.7779453,
    'longitude': -73.946041,
    'name': 'E 89 St & York Ave',
    'timestamp': '2023-08-29T15:03:09.302000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321312,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'c0f952d9-538e-4836-b936-fa97123cbf13'},
    'free_bikes': 2,
    'id': '0db3cce1244e0624b5ca0053d0ad38eb',
    'latitude': 40.693,
    'longitude': -73.90824,
    'name': 'Knickerbocker Ave & Halsey St',
    'timestamp': '2023-08-29T15:03:07.799000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321303,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': 'bcb08532-f0d5-4c0e-ad8a-4ddacc204791'},
    'free_bikes': 4,
    'id': 'c53677190b144fbb78ea14dc77f737fa',
    'latitude': 40.69122,
    'longitude': -73.91693,
    'name': 'Madison St & Evergreen Ave',
    'timestamp': '2023-08-29T15:03:07.962000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321326,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '61f2ffd4-159a-42b3-a4d9-3fdfc3349074'},
    'free_bikes': 10,
    'id': '050b9e525a1ea63ab14bc33488311fc2',
    'latitude': 40.68858,
    'longitude': -73.91227,
    'name': 'Halsey St & Evergreen Ave',
    'timestamp': '2023-08-29T15:03:08.849000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321269,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '679dcf08-d88c-4d1b-b81d-fe9f4aabbff7'},
    'free_bikes': 3,
    'id': '7d5ea4fce2ab4cbf34dd4c7f33815401',
    'latitude': 40.68822,
    'longitude': -73.91966,
    'name': 'Broadway & Madison St',
    'timestamp': '2023-08-29T15:03:08.416000Z'},
   {'empty_slots': 50,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321238,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 75,
     'uid': '09dfc0e3-a448-477c-bb3c-9467dc51ef8d'},
    'free_bikes': 21,
    'id': '0b2e8a54d4273ba716b2256fa7213a6a',
    'latitude': 40.738046142482766,
    'longitude': -73.99642959237099,
    'name': 'W 15 St & 6 Ave',
    'timestamp': '2023-08-29T15:03:07.916000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321263,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 65,
     'uid': 'e8df73bd-5d3d-47c9-b04d-bcec4db5540f'},
    'free_bikes': 45,
    'id': 'af27aebf6963cb5b2a4227a43cfd5712',
    'latitude': 40.70838,
    'longitude': -74.00495,
    'name': 'Cliff St & Fulton St',
    'timestamp': '2023-08-29T15:03:07.808000Z'},
   {'empty_slots': 23,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 32,
     'uid': '78aabb95-6195-4aa7-ab0d-5748eeb26bd1'},
    'free_bikes': 9,
    'id': '1f71ad485ee2e86926689fd8c4016451',
    'latitude': 40.68906,
    'longitude': -73.90506,
    'name': 'Wilson Ave & Moffat St',
    'timestamp': '2023-08-29T15:03:08.762000Z'},
   {'empty_slots': 30,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '9341ee1c-d456-4858-a451-70cbbd73d084'},
    'free_bikes': 0,
    'id': 'dc3b63e328ee66837cb5cf8753e380bb',
    'latitude': 40.68281,
    'longitude': -73.90623,
    'name': 'Bushwick Ave & Furman Ave',
    'timestamp': '2023-08-29T15:03:09.217000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 25,
     'has_ebikes': True,
     'last_updated': 1693321296,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '6fd61eee-d0ef-4580-9704-bd06b82bcb61'},
    'free_bikes': 32,
    'id': 'ae5a91525ce119431f170f5b00ccfc8d',
    'latitude': 40.761573,
    'longitude': -73.972628,
    'name': 'E 56 St & Madison Ave',
    'timestamp': '2023-08-29T15:03:08.049000Z'},
   {'empty_slots': 32,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321264,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 36,
     'uid': '66dc76cd-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': '404c9692a80cc6d252bf26fb3bea6967',
    'latitude': 40.714211,
    'longitude': -73.981095,
    'name': 'Henry St & Grand St',
    'timestamp': '2023-08-29T15:03:09.208000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321304,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'ef6216aa-d3c8-46bb-8c6b-b62f8ba51b16'},
    'free_bikes': 5,
    'id': 'd045809b64fa7c19f36f58646f0c06df',
    'latitude': 40.6786,
    'longitude': -73.90369,
    'name': 'Van Sinderen Ave & Truxton St',
    'timestamp': '2023-08-29T15:03:07.965000Z'},
   {'empty_slots': 23,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321298,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': '7dcc5a03-5997-4250-9207-fa8b6f027c86'},
    'free_bikes': 5,
    'id': '303a2bc78544b638b59997e6eadf89b8',
    'latitude': 40.67945,
    'longitude': -73.90474,
    'name': 'Somers St & Broadway',
    'timestamp': '2023-08-29T15:03:09.111000Z'},
   {'empty_slots': 27,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321284,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': 'ace80a8c-6196-484e-8dd0-061e3c90389b'},
    'free_bikes': 2,
    'id': '678da6832c78fef7d065ecc507dc2b31',
    'latitude': 40.68139,
    'longitude': -73.90756,
    'name': 'Broadway & Furman Ave',
    'timestamp': '2023-08-29T15:03:08.458000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321251,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '59e3766c-0629-4ff1-a1d9-bc0514a55487'},
    'free_bikes': 8,
    'id': 'a2edeb611fa10e38da57a31076320ba9',
    'latitude': 40.68319988172761,
    'longitude': -73.91166642308235,
    'name': 'Rockaway Ave & Bainbridge St',
    'timestamp': '2023-08-29T15:03:08.629000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321255,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '79399e32-a6c6-4732-8ad4-9f9140a86b21'},
    'free_bikes': 6,
    'id': 'b68c744b2e58fd81abcc95dcab0bde15',
    'latitude': 40.743366080270214,
    'longitude': -73.95960688591003,
    'name': 'Center Blvd & 51 Ave',
    'timestamp': '2023-08-29T15:03:08.386000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321265,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'a6a132f9-89bf-42a4-afe6-1ca449b7f570'},
    'free_bikes': 4,
    'id': '7d74e16361e172fe307157ae66c8fcc8',
    'latitude': 40.69812,
    'longitude': -73.90271,
    'name': 'Cypress Ave & George St',
    'timestamp': '2023-08-29T15:03:09.064000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321283,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 15,
     'uid': '141ba25c-f4ea-4cec-ae7e-022401e23087'},
    'free_bikes': 5,
    'id': '2b36cfec7641fc0d3dab899ad2b06b67',
    'latitude': 40.69517,
    'longitude': -73.90311,
    'name': 'Norman St & Wyckoff Ave',
    'timestamp': '2023-08-29T15:03:07.752000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321284,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '9d23b0e9-a478-407c-a0e0-0aff1b0398fc'},
    'free_bikes': 7,
    'id': '342b15dc717d353c439da2c40eec7798',
    'latitude': 40.69922,
    'longitude': -73.89795,
    'name': 'Forest Ave & Summerfield St',
    'timestamp': '2023-08-29T15:03:07.885000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321281,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 16,
     'uid': 'e9b3a725-6963-4151-8f7f-9beeb51fa20f'},
    'free_bikes': 2,
    'id': 'b6ee6304909745cc378ed04acddccaa1',
    'latitude': 40.70461,
    'longitude': -73.91054,
    'name': 'Menahan St & Seneca Ave',
    'timestamp': '2023-08-29T15:03:08.478000Z'},
   {'empty_slots': 24,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321316,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '87091002-cc25-452a-b5d9-f8d0c3fce422'},
    'free_bikes': 1,
    'id': 'eec0080fe5e49b9436901239bd95c47d',
    'latitude': 40.701573408737914,
    'longitude': -73.90876293182373,
    'name': 'Cypress Ave & Palmetto St',
    'timestamp': '2023-08-29T15:03:08.197000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321255,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'ad41e353-033e-484f-8d76-78014e11e9d7'},
    'free_bikes': 12,
    'id': '2e19e061cb761499b1d2d478133d7c81',
    'latitude': 40.75473,
    'longitude': -73.93367,
    'name': '38 Ave & 29 St',
    'timestamp': '2023-08-29T15:03:08.393000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321324,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': 'bd30f2a1-38ec-474d-9e36-07f688e87427'},
    'free_bikes': 3,
    'id': 'f997501d09606eee9adfaac02f9f7e1c',
    'latitude': 40.72084,
    'longitude': -73.94844,
    'name': 'Manhattan Av & Leonard St',
    'timestamp': '2023-08-29T15:03:08.754000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321289,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '344064f8-e82f-40fb-b235-aff506b77ae5'},
    'free_bikes': 8,
    'id': 'c1a59b29442f8eb95720516e66235374',
    'latitude': 40.72226,
    'longitude': -73.93889,
    'name': 'Morgan Ave & Lombardy St',
    'timestamp': '2023-08-29T15:03:08.170000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321310,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 17,
     'uid': '74e104fb-1ddc-4f3e-a60b-220b6c4f300b'},
    'free_bikes': 2,
    'id': '4de999ad82b546a7273bc8900e48b58e',
    'latitude': 40.70068,
    'longitude': -73.90742,
    'name': 'Madison St & Cypress Ave',
    'timestamp': '2023-08-29T15:03:08.206000Z'},
   {'empty_slots': 43,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321290,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 46,
     'uid': '66dd4423-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': 'f6fb5895e87a62550256a761a95a05af',
    'latitude': 40.77677702,
    'longitude': -73.9590097,
    'name': 'E 81 St & Park Ave',
    'timestamp': '2023-08-29T15:03:08.441000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321308,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 15,
     'uid': '24f431ca-c2a5-46be-966b-b8d4c3e4b346'},
    'free_bikes': 0,
    'id': 'd2eaf2281ec4cfde2a49c176dca2fa3b',
    'latitude': 40.6988,
    'longitude': -73.9007,
    'name': 'Stephen St & Seneca Ave',
    'timestamp': '2023-08-29T15:03:08.679000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321254,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '26cae473-0e59-4af7-bad5-bb6fec85c8bc'},
    'free_bikes': 6,
    'id': 'c76fbfaae3ae1e2270308866177631e1',
    'latitude': 40.70183,
    'longitude': -73.90625,
    'name': 'Madison St & Seneca Ave',
    'timestamp': '2023-08-29T15:03:08.297000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321282,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '8f3a6711-fd05-4ce1-acf8-9d72b4a1bf97'},
    'free_bikes': 5,
    'id': '4afcc8285381fb09276fd4ca3e58307c',
    'latitude': 40.70553,
    'longitude': -73.9096,
    'name': 'Menahan St & Onderdonk Ave',
    'timestamp': '2023-08-29T15:03:08.147000Z'},
   {'empty_slots': 31,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321227,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 38,
     'uid': '66dde103-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 3,
    'id': '31a578c93cf9a71a794044432a221ba2',
    'latitude': 40.781410700190015,
    'longitude': -73.95595908164978,
    'name': 'E 88 St & Park Ave',
    'timestamp': '2023-08-29T15:03:08.739000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321329,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 17,
     'uid': '837b7db3-55c6-4595-a497-834972631752'},
    'free_bikes': 1,
    'id': 'b866fd12963441fdd7d7175f4f0ecb06',
    'latitude': 40.70998,
    'longitude': -73.91116,
    'name': 'Stanhope St & Fairview Ave',
    'timestamp': '2023-08-29T15:03:08.846000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321269,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'd89dc10f-9be3-45a5-9c3c-06c04c963436'},
    'free_bikes': 8,
    'id': '290d3c85c1aa897bc947febf53fffc37',
    'latitude': 40.71246,
    'longitude': -73.91873,
    'name': 'Flushing Ave & Woodward Ave',
    'timestamp': '2023-08-29T15:03:07.807000Z'},
   {'empty_slots': 23,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321319,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': 'ee1ba75f-baf5-4852-929c-8b7ad310f55a'},
    'free_bikes': 3,
    'id': 'c69e73a7bd17d12afedfcf507b8fc70d',
    'latitude': 40.7098,
    'longitude': -73.91727,
    'name': 'Willoughby Ave & Onderdonk Ave',
    'timestamp': '2023-08-29T15:03:08.058000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321258,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '1318e05a-2506-43c6-b49d-4c1f7f69a267'},
    'free_bikes': 3,
    'id': '8a85954c694fd5999d3385c743dcb667',
    'latitude': 40.6972,
    'longitude': -73.90674,
    'name': 'Hancock St & Wyckoff Ave',
    'timestamp': '2023-08-29T15:03:07.889000Z'},
   {'empty_slots': 23,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321217,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '9092515e-eef6-478f-910f-1cd19d06bebb'},
    'free_bikes': 11,
    'id': '60c78e8678b981de603fddf94311bf9f',
    'latitude': 40.68663,
    'longitude': -73.9168,
    'name': 'Broadway & Hancock St',
    'timestamp': '2023-08-29T15:03:08.734000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321307,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '272c0389-5e4a-41a9-ad6c-2dccdfa55af9'},
    'free_bikes': 5,
    'id': 'c243e589552a56fde45f17904245e943',
    'latitude': 40.70555,
    'longitude': -73.90245,
    'name': 'Madison St & Forest Ave',
    'timestamp': '2023-08-29T15:03:07.994000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321326,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '55a4dc76-d839-4e06-9bf4-2f343391343c'},
    'free_bikes': 3,
    'id': 'b1b6dafb46758c95e85037ddb30c4787',
    'latitude': 40.70793,
    'longitude': -73.91092,
    'name': 'Woodward Ave & Harman St',
    'timestamp': '2023-08-29T15:03:08.900000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321327,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 17,
     'uid': '75352ab4-8a31-4926-8b59-048a9e506452'},
    'free_bikes': 6,
    'id': '30c563f875333f1f9cec03a903e7d05b',
    'latitude': 40.70112,
    'longitude': -73.93039,
    'name': 'Central Ave & Melrose St',
    'timestamp': '2023-08-29T15:03:08.911000Z'},
   {'empty_slots': 35,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321264,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66dc73b0-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': '74fb47e0c3525704829daaf79450aa45',
    'latitude': 40.76269882,
    'longitude': -73.99301222,
    'name': 'W 47 St & 10 Ave',
    'timestamp': '2023-08-29T15:03:07.988000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321300,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '760ebaea-f7c7-45ad-aa3b-395d97adcf8f'},
    'free_bikes': 13,
    'id': '32ecd29cd5b871bd91c856645ff210d3',
    'latitude': 40.802535,
    'longitude': -73.9532423,
    'name': 'Adam Clayton Powell Blvd & W 115 St',
    'timestamp': '2023-08-29T15:03:09.089000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321263,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '16836c76-c412-4ec3-bac8-3c6a5a3d9745'},
    'free_bikes': 6,
    'id': 'e198b8a426b9f182dfe88774eb901acf',
    'latitude': 40.70408,
    'longitude': -73.90408,
    'name': 'Madison St & Woodward Ave',
    'timestamp': '2023-08-29T15:03:09.184000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321235,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '1abd4668-ed6b-4930-8177-17239ae75a9e'},
    'free_bikes': 3,
    'id': '67e262eda73516c33021103ce6ee1f15',
    'latitude': 40.70694,
    'longitude': -73.90632,
    'name': 'Fairview Ave & Linden St',
    'timestamp': '2023-08-29T15:03:08.318000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321301,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 17,
     'uid': '30985a9c-afe4-4b98-a72c-2c72bb35603e'},
    'free_bikes': 2,
    'id': '1d18a33174ffc0f971a5ced5d65173c5',
    'latitude': 40.709697,
    'longitude': -73.907856,
    'name': 'Greene Ave & Grandview Ave',
    'timestamp': '2023-08-29T15:03:07.915000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321319,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 17,
     'uid': 'be8e6f1c-e8b5-40bd-896d-423052ba3bbc'},
    'free_bikes': 3,
    'id': 'b652cc4639ba4ac12b23a522b7d76a63',
    'latitude': 40.70863,
    'longitude': -73.91497,
    'name': 'Onderdonk Ave & Dekalb Ave',
    'timestamp': '2023-08-29T15:03:08.444000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 25,
     'has_ebikes': True,
     'last_updated': 1693321239,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 55,
     'uid': '2c366f4b-8319-41bf-ab8e-2fba3a952feb'},
    'free_bikes': 42,
    'id': '09b3ea43ea90132ea2bcba9fee826fae',
    'latitude': 40.75492,
    'longitude': -73.98455,
    'name': 'W 42 St & 6 Ave',
    'timestamp': '2023-08-29T15:03:08.563000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 11,
     'has_ebikes': True,
     'last_updated': 1693321305,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 50,
     'uid': 'af72781c-fe0b-4b73-a7df-201f9780ea9c'},
    'free_bikes': 46,
    'id': '6964e6ac85b7f9767894bf9750f6ba2d',
    'latitude': 40.726378,
    'longitude': -74.000472,
    'name': 'W Broadway & W Houston St',
    'timestamp': '2023-08-29T15:03:08.217000Z'},
   {'empty_slots': 22,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321276,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'a7c09fde-76e8-4a56-b61d-8ca940432efd'},
    'free_bikes': 0,
    'id': '301a351d4541b6c63db792d578fabe7d',
    'latitude': 40.69969,
    'longitude': -73.9022,
    'name': 'Centre St & Seneca Ave',
    'timestamp': '2023-08-29T15:03:07.848000Z'},
   {'empty_slots': 26,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321292,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': '66dc4334-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 3,
    'id': '2f52b7e112e6b53c4efc3f0327f27a87',
    'latitude': 40.76669671,
    'longitude': -73.99061728,
    'name': 'W 53 St & 10 Ave',
    'timestamp': '2023-08-29T15:03:08.514000Z'},
   {'empty_slots': 38,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321329,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 44,
     'uid': '66dc0e24-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 2,
    'id': 'f60de9806878cb16bd951cac600a4b47',
    'latitude': 40.76584941,
    'longitude': -73.98690506,
    'name': 'W 54 St & 9 Ave',
    'timestamp': '2023-08-29T15:03:09.053000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321338,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '0f45bcf6-7028-4584-a51e-4129847dbebc'},
    'free_bikes': 27,
    'id': '67020fb2089f278f309413afe8fbe779',
    'latitude': 40.732647,
    'longitude': -73.99011,
    'name': '4 Ave & E 12 St',
    'timestamp': '2023-08-29T15:03:09.330000Z'},
   {'empty_slots': 29,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321316,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '8ea09819-cd88-4732-b047-c0549f0b370f'},
    'free_bikes': 1,
    'id': 'cf7c14fd2412babdb31d78aa1d2bce97',
    'latitude': 40.719383,
    'longitude': -73.991479,
    'name': 'Delancey St & Eldridge St',
    'timestamp': '2023-08-29T15:03:07.741000Z'},
   {'empty_slots': 30,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321304,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 49,
     'uid': 'e625e677-d175-4902-9764-d92716d86fd5'},
    'free_bikes': 17,
    'id': '4cbab804ec283e42e7dba4b828974346',
    'latitude': 40.714193,
    'longitude': -73.996732,
    'name': 'Division St & Bowery',
    'timestamp': '2023-08-29T15:03:07.834000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321228,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66dc252e-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 3,
    'id': 'c0793e6899adb49d814262e260567289',
    'latitude': 40.71285887,
    'longitude': -73.96590294,
    'name': 'S 4 St & Wythe Ave',
    'timestamp': '2023-08-29T15:03:08.590000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '582cd775-0178-47f5-b707-6d5869f077ba'},
    'free_bikes': 16,
    'id': 'b9aa21463944fa7cff78f632b429d24f',
    'latitude': 40.69178,
    'longitude': -73.97877,
    'name': 'Willoughby St & Ashland Pl',
    'timestamp': '2023-08-29T15:03:08.729000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321235,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '8dfff4bd-0f3c-43af-bc55-a63850f66c6b'},
    'free_bikes': 17,
    'id': '75893f554f4b758792ed01b9649d10f7',
    'latitude': 40.699569,
    'longitude': -73.979827,
    'name': 'Sands St Gate',
    'timestamp': '2023-08-29T15:03:08.679000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321289,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': 'eab2749b-2f79-4797-a0a6-0579b27e6929'},
    'free_bikes': 32,
    'id': 'bb15b2aed3271ec69b6134dd3d355a31',
    'latitude': 40.818299,
    'longitude': -73.960405,
    'name': '12 Ave & W 125 St',
    'timestamp': '2023-08-29T15:03:09.251000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321288,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 42,
     'uid': '66dba0ba-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 19,
    'id': 'aea47cc4942c5b3137f63e2af874dbaf',
    'latitude': 40.71739973,
    'longitude': -73.98016555,
    'name': 'Columbia St & Rivington St',
    'timestamp': '2023-08-29T15:03:07.791000Z'},
   {'empty_slots': 25,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321226,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': 'b7df61c0-8ead-46cb-9d6e-a6a3011ffb71'},
    'free_bikes': 2,
    'id': '700ab1280403594412c894a20bedcb23',
    'latitude': 40.7611488,
    'longitude': -73.9170071,
    'name': '31 Ave & Steinway St',
    'timestamp': '2023-08-29T15:03:08.079000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321315,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'cb81edec-e79d-4cb2-b494-18aa18b27ad5'},
    'free_bikes': 16,
    'id': '2b9fb463884fe3f7eed2d00a664c0585',
    'latitude': 40.752474,
    'longitude': -73.939991,
    'name': '24 St & 41 Ave',
    'timestamp': '2023-08-29T15:03:08.021000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321288,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 56,
     'uid': 'e51c8b72-460f-41c2-a5ca-de85d3f46a30'},
    'free_bikes': 54,
    'id': '52fb074c814326cc663be03c19d2f95d',
    'latitude': 40.752694,
    'longitude': -74.002353,
    'name': 'W 30 St & 10 Ave',
    'timestamp': '2023-08-29T15:03:07.946000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321283,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '66de6346-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 31,
    'id': '6fd81aa6010a5f3b426f7953c39b3d1a',
    'latitude': 40.6843549,
    'longitude': -73.98901629,
    'name': 'Hoyt St & Warren St',
    'timestamp': '2023-08-29T15:03:07.963000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321287,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 51,
     'uid': '66dd4051-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 31,
    'id': '97b12d80c9ee17ad52a653cc0e57c5c1',
    'latitude': 40.766368,
    'longitude': -73.971518,
    'name': '5 Ave & E 63 St',
    'timestamp': '2023-08-29T15:03:08.564000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321334,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 58,
     'uid': '66db2db5-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 55,
    'id': '9fb7ddbf2bc23aacc066478cc7a23484',
    'latitude': 40.69839895,
    'longitude': -73.98068914,
    'name': 'Nassau St & Navy St',
    'timestamp': '2023-08-29T15:03:09.168000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 48,
     'uid': '3b530cff-dd26-4cfd-b570-a85fd53354fe'},
    'free_bikes': 42,
    'id': '2dad45a670990f8a7c2b71f3c96ab1dd',
    'latitude': 40.711444,
    'longitude': -74.014847,
    'name': 'West St & Liberty St',
    'timestamp': '2023-08-29T15:03:08.625000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321259,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '97bcf094-ad77-4743-9c94-832c7300c090'},
    'free_bikes': 10,
    'id': 'b3e44987e035133008966ca283c70214',
    'latitude': 40.805631,
    'longitude': -73.934077,
    'name': 'E 128 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:07.827000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321269,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': 'bb07a569-cc74-439e-b424-916c0304f136'},
    'free_bikes': 14,
    'id': 'fefaf0e5e8545318b3cd5e35af2ead6c',
    'latitude': 40.802554,
    'longitude': -73.933509,
    'name': '2 Ave & E 125 St',
    'timestamp': '2023-08-29T15:03:08.323000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321231,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': 'd5cb6e67-addb-46d4-93e7-832371736d45'},
    'free_bikes': 26,
    'id': 'ffdca64c32febb7cf8462c1bee53cd54',
    'latitude': 40.81734,
    'longitude': -73.922962,
    'name': 'E 149 St & Morris Ave',
    'timestamp': '2023-08-29T15:03:08.653000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321324,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 17,
     'uid': '26568d39-db49-4354-a5c1-c81a3c856285'},
    'free_bikes': 10,
    'id': 'b42034a8598d01c97d2fcc957369fe8f',
    'latitude': 40.808484,
    'longitude': -73.928803,
    'name': 'Lincoln Ave & E 134 St',
    'timestamp': '2023-08-29T15:03:07.976000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321245,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'de97a7d0-fbb3-4c13-ba6a-2bbd441751fe'},
    'free_bikes': 0,
    'id': 'eb32e90cceb6ab7dfaaa5617ecafcc1b',
    'latitude': 40.805701,
    'longitude': -73.925177,
    'name': 'Willis Ave & Bruckner Blvd',
    'timestamp': '2023-08-29T15:03:08.613000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321257,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': 'ecb2eebe-67c0-43b8-baae-71abb1a0ec6a'},
    'free_bikes': 23,
    'id': '8f88c0ffb5a6fe8a0b361e578390f055',
    'latitude': 40.813619,
    'longitude': -73.939336,
    'name': 'W 135 St & Lenox Terrace Pl',
    'timestamp': '2023-08-29T15:03:08.843000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321299,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '023127f2-a6e0-4fae-ba34-178acccb993e'},
    'free_bikes': 13,
    'id': '4a3bcb2d54c12a4b08b6a06382f80263',
    'latitude': 40.812191,
    'longitude': -73.937838,
    'name': '5 Ave & E 135 St',
    'timestamp': '2023-08-29T15:03:08.144000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321245,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '38975061-0d90-43a3-87c1-8905b374d5d9'},
    'free_bikes': 17,
    'id': 'fce143cad9247a960d1bbe2660592a73',
    'latitude': 40.806414,
    'longitude': -73.936085,
    'name': 'Lexington Ave & E 128 St',
    'timestamp': '2023-08-29T15:03:08.635000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321322,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 26,
     'uid': '11a8d465-b4eb-466b-a6ca-055f73994231'},
    'free_bikes': 10,
    'id': '200e431d4c17b03e57566009d3243ee2',
    'latitude': 40.810893,
    'longitude': -73.927311,
    'name': 'Lincoln Ave & E 138 St',
    'timestamp': '2023-08-29T15:03:08.999000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321297,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '1ec7ef9f-ab60-4a64-821d-883ba547273a'},
    'free_bikes': 2,
    'id': 'ad2075c2c33090fafd71673079fe6237',
    'latitude': 40.810224,
    'longitude': -73.937195,
    'name': 'E 132 St & Madison Ave',
    'timestamp': '2023-08-29T15:03:08.512000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321272,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': 'dad39e68-53f5-47c2-87e2-b1cc0e34f90f'},
    'free_bikes': 4,
    'id': 'ddf039ed9a59628165cec3eca45decfd',
    'latitude': 40.81014,
    'longitude': -73.93973,
    'name': '5 Ave & W 131 St',
    'timestamp': '2023-08-29T15:03:08.285000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321294,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': 'b79bb851-130f-473d-83fc-f602aa0a4ca9'},
    'free_bikes': 20,
    'id': '84376db911464280ef575e4bee152655',
    'latitude': 40.812346,
    'longitude': -73.946168,
    'name': 'Adam Clayton Powell Blvd & W 130 St',
    'timestamp': '2023-08-29T15:03:07.873000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321325,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'ebae0b66-e463-4ded-9b7a-43c0aca9b37a'},
    'free_bikes': 12,
    'id': '0b7d520dd16bc42d1e64934e0e404947',
    'latitude': 40.814469,
    'longitude': -73.924963,
    'name': 'Morris Ave & E 142 St',
    'timestamp': '2023-08-29T15:03:08.244000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321321,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '324e55da-fec0-43a2-b622-27774381ab7f'},
    'free_bikes': 14,
    'id': '5a917a4791371303bca4e138f7be7620',
    'latitude': 40.816355,
    'longitude': -73.954295,
    'name': 'Amsterdam Ave & W 131 St',
    'timestamp': '2023-08-29T15:03:08.796000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321318,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '5fdf435f-6080-4b1d-966c-3b9d08450c4d'},
    'free_bikes': 11,
    'id': 'f6d9c5dce190761d5d510d2050f0e633',
    'latitude': 40.81093,
    'longitude': -73.921606,
    'name': 'Willis Ave & E 141 St',
    'timestamp': '2023-08-29T15:03:08.764000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321311,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': 'e780c290-0c52-4ab1-9719-a581be789df3'},
    'free_bikes': 3,
    'id': '8364b18e732765b3b1ff33e6dc940f27',
    'latitude': 40.808384,
    'longitude': -73.923604,
    'name': 'Willis Ave & E 137 St',
    'timestamp': '2023-08-29T15:03:08.116000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 27,
     'has_ebikes': True,
     'last_updated': 1693321338,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 57,
     'uid': '66dbcdfc-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 54,
    'id': 'ad585a32dc386834a7aa729363e8bcbe',
    'latitude': 40.75828065,
    'longitude': -73.97069431,
    'name': 'E 53 St & Lexington Ave',
    'timestamp': '2023-08-29T15:03:07.858000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321302,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': 'a4d041fd-c5fa-4f52-800c-25d7a661a875'},
    'free_bikes': 10,
    'id': '79b8f77472adc29b6061a7f2f8fea92a',
    'latitude': 40.81449,
    'longitude': -73.936153,
    'name': 'E 138 St & 5 Av',
    'timestamp': '2023-08-29T15:03:08.945000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 12,
     'has_ebikes': True,
     'last_updated': 1693321316,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '44fa161f-eb62-459b-b53e-da83788cfa2a'},
    'free_bikes': 19,
    'id': 'eb638f8f522d9999cf780f7dbee927b7',
    'latitude': 40.818215,
    'longitude': -73.950988,
    'name': 'Convent Ave & W 135 St',
    'timestamp': '2023-08-29T15:03:08.329000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321279,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '7f6674c4-5568-4766-b172-0385348ae184'},
    'free_bikes': 7,
    'id': '2465efe575b2e0769a8ad1c35322d0ed',
    'latitude': 40.819746,
    'longitude': -73.951819,
    'name': 'Amsterdam Ave & W 136 St',
    'timestamp': '2023-08-29T15:03:08.743000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321267,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '8b1222da-612f-4482-ab34-9467c4ed28e3'},
    'free_bikes': 21,
    'id': '116993e4fa97455eca2b79c1c86d5ca0',
    'latitude': 40.805089,
    'longitude': -73.918889,
    'name': "E 135 St & St Ann's Ave",
    'timestamp': '2023-08-29T15:03:08.234000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321286,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 17,
     'uid': 'cb9840a3-4ae2-420d-865c-9ac45e2f5485'},
    'free_bikes': 15,
    'id': '2cf62c3c30274a04de606c93f4526637',
    'latitude': 40.803399,
    'longitude': -73.919763,
    'name': "St. Ann's Av & Bruckner Blvd",
    'timestamp': '2023-08-29T15:03:08.895000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321231,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'b371c432-b682-412f-9b85-8df84ce7a9f3'},
    'free_bikes': 12,
    'id': '9ffb41a32c6f8b0d0aa5cd9d9c47b366',
    'latitude': 40.818477,
    'longitude': -73.947568,
    'name': 'St Nicholas Ave & W 137 St',
    'timestamp': '2023-08-29T15:03:08.465000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 16,
     'uid': 'd7632897-a6eb-4f8f-9ab2-c66426620fbf'},
    'free_bikes': 15,
    'id': '0f09d855883607e709f84506b68b801f',
    'latitude': 40.800425,
    'longitude': -73.911034,
    'name': 'E 134 St & Walnut Ave',
    'timestamp': '2023-08-29T15:03:08.475000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321244,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'a7a175ff-8ffb-477c-a40b-6d47ce92305d'},
    'free_bikes': 16,
    'id': '4fed6f5de2e2990c7185ffc5b3d052af',
    'latitude': 40.800933,
    'longitude': -73.913863,
    'name': 'Willow Ave & E 133 St',
    'timestamp': '2023-08-29T15:03:09.350000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321223,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '38bb1218-0a9e-41d9-b2ef-25c8626dac29'},
    'free_bikes': 16,
    'id': 'b00507358ec59a22b26cb9cb58211b12',
    'latitude': 40.813224,
    'longitude': -73.930605,
    'name': 'E 138 St & Grand Concourse',
    'timestamp': '2023-08-29T15:03:09.156000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321242,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': 'de449a58-0edf-4d36-91b4-4b313576e945'},
    'free_bikes': 12,
    'id': 'ff740e13f44126eac725dd9fafbd24de',
    'latitude': 40.804168,
    'longitude': -73.911545,
    'name': 'E 138 St & Willow Ave',
    'timestamp': '2023-08-29T15:03:08.312000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321322,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '3eb10c63-ea4c-4161-b07d-a29034f7367a'},
    'free_bikes': 15,
    'id': 'e74e478766a794d9c8a30aa56c9a718a',
    'latitude': 40.809619,
    'longitude': -73.917875,
    'name': 'Brook Ave & E 141 St',
    'timestamp': '2023-08-29T15:03:08.383000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321243,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '581bc4fe-cf14-4767-8377-6fa156ff8a29'},
    'free_bikes': 18,
    'id': 'be1aac9d5063710c670bbce97cdedd66',
    'latitude': 40.820036,
    'longitude': -73.921411,
    'name': 'Morris Ave & E 153 St',
    'timestamp': '2023-08-29T15:03:09.114000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321310,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '7c42f9fc-d280-4841-ad96-e3cc53ee3759'},
    'free_bikes': 22,
    'id': '633f8d4351503abb87f7116a209cc11b',
    'latitude': 40.812299,
    'longitude': -73.92037,
    'name': 'Willis Ave & E 143 St',
    'timestamp': '2023-08-29T15:03:09.065000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321293,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 17,
     'uid': '8f672aa7-08a1-4fe2-a471-06f219c0eb1b'},
    'free_bikes': 16,
    'id': 'ddaa3c355e62eef39bd6c2e72f3a0b0b',
    'latitude': 40.801657,
    'longitude': -73.909513,
    'name': 'Walnut Ave & E 136 St',
    'timestamp': '2023-08-29T15:03:07.896000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321225,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'c8197f4b-02b0-4cc3-96af-df5fec27a279'},
    'free_bikes': 14,
    'id': '2843a01a7675bc5aa7aeea25fd244494',
    'latitude': 40.808891,
    'longitude': -73.91081,
    'name': "St Mary's St & Jackson Ave",
    'timestamp': '2023-08-29T15:03:08.588000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321336,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'f47e1ce9-ff3f-49e9-9a2f-aa5be45d70da'},
    'free_bikes': 17,
    'id': 'b0803dea97b16a61cf0f15e2ddf8a11e',
    'latitude': 40.811112,
    'longitude': -73.914932,
    'name': "St. Ann's Ave & E 144 St",
    'timestamp': '2023-08-29T15:03:08.369000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321322,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '98ebf9c6-1d94-4e21-9007-c623875fdb5e'},
    'free_bikes': 16,
    'id': '8e1c7a8ee3b3e126ed4a56212eab0039',
    'latitude': 40.811675,
    'longitude': -73.917037,
    'name': 'E 144 St & Brook Ave',
    'timestamp': '2023-08-29T15:03:08.051000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321260,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': 'c229f0ca-bdd1-4aa0-8906-a3e809e12889'},
    'free_bikes': 16,
    'id': '50168be9d88dd7bc70f663d907ed2af5',
    'latitude': 40.825125,
    'longitude': -73.941616,
    'name': 'Bradhurst Ave & W 148 St',
    'timestamp': '2023-08-29T15:03:09.034000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': 'fe65853e-b20a-4250-9677-2aa177283b72'},
    'free_bikes': 17,
    'id': 'd385cbcfe129012b044e6f537d5328b3',
    'latitude': 40.819783,
    'longitude': -73.936521,
    'name': 'Lenox Ave & W 144 St',
    'timestamp': '2023-08-29T15:03:09.092000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321328,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '01a1343d-9c7b-4a83-8a5a-a600187f19c4'},
    'free_bikes': 10,
    'id': '09cc7470fa28fd255aa8222f416422f4',
    'latitude': 40.823168,
    'longitude': -73.955857,
    'name': 'Riverside Dr & W 138 St',
    'timestamp': '2023-08-29T15:03:08.225000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321293,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '1d8e51b0-8131-4c1f-93fb-f04952c157c0'},
    'free_bikes': 15,
    'id': '5e8f1264c6e46afb48d3ca6b857a0d34',
    'latitude': 40.826969,
    'longitude': -73.949738,
    'name': 'W 146 St & Broadway',
    'timestamp': '2023-08-29T15:03:08.547000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321253,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': 'bb0ce308-e5d9-48c7-9f4b-cf0120f2c39a'},
    'free_bikes': 2,
    'id': '6da563b677620790a55b1dc055a984aa',
    'latitude': 40.825244,
    'longitude': -73.947257,
    'name': 'W 145 St & Amsterdam Ave',
    'timestamp': '2023-08-29T15:03:08.594000Z'},
   {'empty_slots': 28,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321323,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': 'ccaadb70-6c87-4ccc-9914-a3167bd1bc0e'},
    'free_bikes': 4,
    'id': 'c169a04cafe00cf9e7074a4e43b11dae',
    'latitude': 40.827305,
    'longitude': -73.951989,
    'name': 'Riverside Dr & W 145 St',
    'timestamp': '2023-08-29T15:03:08.301000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 10,
     'has_ebikes': True,
     'last_updated': 1693321313,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '3db799ba-b574-4e5f-95e5-c767bec2acb6'},
    'free_bikes': 27,
    'id': '03f969f57a417050a6590ccb1770694a',
    'latitude': 40.816827,
    'longitude': -73.917338,
    'name': 'Melrose Ave & E 150 St',
    'timestamp': '2023-08-29T15:03:09.099000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321293,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'ccfa8b82-07a7-4a08-88fc-be261c30a4ca'},
    'free_bikes': 5,
    'id': '78efcf2f1972563f71b5a27e3cc2e3e8',
    'latitude': 40.813135,
    'longitude': -73.909235,
    'name': 'E 149 St & Jackson Ave',
    'timestamp': '2023-08-29T15:03:08.219000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321248,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'e71d152c-c2df-4d3e-a9af-139f2529bac6'},
    'free_bikes': 10,
    'id': '015f8c90cb9c0e8ebb1f11e4aeeaaa87',
    'latitude': 40.814046,
    'longitude': -73.91186,
    'name': 'E 149 St & Eagle Ave',
    'timestamp': '2023-08-29T15:03:08.656000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321250,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '66dd1f44-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 14,
    'id': 'cc470ce59c53d9fe0ed5d275396e5f7c',
    'latitude': 40.73026,
    'longitude': -73.95394,
    'name': 'Greenpoint Ave & Manhattan Ave',
    'timestamp': '2023-08-29T15:03:08.365000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321304,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 54,
     'uid': '66dc8bfd-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 36,
    'id': '22534ad1ebf1745b032691604f0d08fa',
    'latitude': 40.74311555376486,
    'longitude': -73.98215353488922,
    'name': 'Lexington Ave & E 29 St',
    'timestamp': '2023-08-29T15:03:07.940000Z'},
   {'empty_slots': 41,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321285,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 80,
     'uid': '454b4a83-d0b1-42a2-8163-261e2a9d6ab9'},
    'free_bikes': 36,
    'id': 'b2da7dc686ff209a4e9e067067ab6537',
    'latitude': 40.741459,
    'longitude': -73.983293,
    'name': 'Lexington Ave & E 26 St',
    'timestamp': '2023-08-29T15:03:08.770000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321259,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '648e09b6-95c2-40d3-9dac-a43f22eccf38'},
    'free_bikes': 19,
    'id': 'b3eaf11b7cc0a60501fbf8d5eace7e33',
    'latitude': 40.816234,
    'longitude': -73.948222,
    'name': 'St Nicholas Ave & W 134 St',
    'timestamp': '2023-08-29T15:03:08.048000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321314,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '4780d9d1-b886-4e72-9d18-cb152f73e10a'},
    'free_bikes': 13,
    'id': '78355a529f94d36a85377d4683c0df08',
    'latitude': 40.815484,
    'longitude': -73.935856,
    'name': '5 Av & W 139 St',
    'timestamp': '2023-08-29T15:03:08.073000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321289,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '22ab59a8-0af4-4101-9350-a7af88e37c2e'},
    'free_bikes': 16,
    'id': '815a2f73a587407d9324ef48d3cd20ea',
    'latitude': 40.820003,
    'longitude': -73.959089,
    'name': 'W 133 St & 12 Ave',
    'timestamp': '2023-08-29T15:03:08.033000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321246,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '10c13fe2-34cb-4aff-bea1-4f5ce877769b'},
    'free_bikes': 2,
    'id': '263fab7270b32e5ed0ac663539d3ad23',
    'latitude': 40.812735,
    'longitude': -73.923697,
    'name': 'E 142 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:08.461000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321263,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '96a0b676-e966-4d96-b04b-ceb8149cedcd'},
    'free_bikes': 3,
    'id': '2609c3404d385d5c2b90bdf0b145335c',
    'latitude': 40.805559,
    'longitude': -73.914718,
    'name': 'E 138 St & Cypress Ave',
    'timestamp': '2023-08-29T15:03:09.165000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693314385,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 0,
     'returning': 0,
     'slots': 51,
     'uid': '66db3273-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 38,
    'id': 'c348f60fb7fcb0de3b6ce4301d81d78d',
    'latitude': 40.72917025,
    'longitude': -73.99810231,
    'name': 'LaGuardia Pl & W 3 St',
    'timestamp': '2023-08-29T15:03:08.607000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321266,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 66,
     'uid': 'bde94a25-6089-4490-af3a-8cc5702230b8'},
    'free_bikes': 62,
    'id': 'c2d8afdab7f3fadb52f4b6ac758d000a',
    'latitude': 40.72494672359416,
    'longitude': -74.00165855884552,
    'name': 'W Broadway & Spring St',
    'timestamp': '2023-08-29T15:03:07.749000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321275,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66dcbbfe-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 2,
    'id': '9fe8696b7ddddc8cbbf4d1c1865c2aa3',
    'latitude': 40.682601,
    'longitude': -73.938037,
    'name': 'Marcus Garvey Blvd & Macon St',
    'timestamp': '2023-08-29T15:03:07.929000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321336,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': 'b7d7543b-74ac-4a48-a3c4-412f9ffbc727'},
    'free_bikes': 19,
    'id': 'b32f389015b6433063f2639767b4a1c5',
    'latitude': 40.81296,
    'longitude': -73.941878,
    'name': 'Lenox Ave & W 133 St',
    'timestamp': '2023-08-29T15:03:09.238000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321325,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '01839a78-f228-4706-8f7f-147b857492f2'},
    'free_bikes': 15,
    'id': 'da2cdd958b98bd2f6c72434f2234156b',
    'latitude': 40.813539,
    'longitude': -73.94521,
    'name': 'Adam Clayton Powell Blvd & W 132 St',
    'timestamp': '2023-08-29T15:03:09.194000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321336,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '7f1b4c40-d9fa-4182-be0e-a993655cfb6f'},
    'free_bikes': 14,
    'id': '1bd576a8d550916dfad74070510c3b96',
    'latitude': 40.807408,
    'longitude': -73.91924,
    'name': 'Brook Ave & E 138 St',
    'timestamp': '2023-08-29T15:03:09.140000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321322,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '9ac5758f-0419-4e28-8387-6bcd28db17fa'},
    'free_bikes': 9,
    'id': '44e383f50158723fe506e227d565eeba',
    'latitude': 40.808633,
    'longitude': -73.916124,
    'name': "E 141 St & St Ann's Ave",
    'timestamp': '2023-08-29T15:03:07.762000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321293,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'd8673258-9513-4ed2-86bf-bef62e7e4e30'},
    'free_bikes': 1,
    'id': '7cb8eee14a9ac82b366c7b714891cad0',
    'latitude': 40.806896,
    'longitude': -73.911837,
    'name': 'E 141 St & Jackson Ave',
    'timestamp': '2023-08-29T15:03:08.048000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321244,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'bc512527-7863-48d5-aea8-3de470abc1ee'},
    'free_bikes': 15,
    'id': '200ed42a72065f6c4a63052ddd590502',
    'latitude': 40.820681,
    'longitude': -73.945144,
    'name': 'Edgecombe Ave & W 141 St',
    'timestamp': '2023-08-29T15:03:08.456000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 9,
     'has_ebikes': True,
     'last_updated': 1693321292,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '2cd651e7-1e3a-4cd9-8fd1-a2416e032f6e'},
    'free_bikes': 15,
    'id': '4e375140a359ca5daf20a139c2664f74',
    'latitude': 40.821294,
    'longitude': -73.947868,
    'name': 'St. Nicholas Terrace & Convent Ave',
    'timestamp': '2023-08-29T15:03:08.821000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321315,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '4c03fa2d-89da-4f0b-8f19-c7de5edbe256'},
    'free_bikes': 10,
    'id': 'afff19d6092a6f1e335cd9a5d488fe93',
    'latitude': 40.814673,
    'longitude': -73.91839,
    'name': 'E 147 St & Bergen Ave',
    'timestamp': '2023-08-29T15:03:07.860000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321327,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '493e046c-5d62-4772-90c4-b6a9f4afcd39'},
    'free_bikes': 1,
    'id': 'a1e9b8cc62a5df9d6295b1dd3381ea6e',
    'latitude': 40.69757,
    'longitude': -73.93098,
    'name': 'Willoughby Ave & Myrtle Ave',
    'timestamp': '2023-08-29T15:03:08.677000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321275,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 36,
     'uid': '88bf1344-354f-4699-bdbd-1c2584fc41ee'},
    'free_bikes': 28,
    'id': '6c7145d62d0462602990f72b030d69a8',
    'latitude': 40.7639089,
    'longitude': -73.9477213,
    'name': 'Motorgate',
    'timestamp': '2023-08-29T15:03:08.045000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321323,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': 'b47e5ffd-4215-4476-a89b-ebe52111f763'},
    'free_bikes': 37,
    'id': '9c2aa78a9eca55f06a95733e8e2747e0',
    'latitude': 40.757284,
    'longitude': -73.9536,
    'name': 'Roosevelt Island Tramway',
    'timestamp': '2023-08-29T15:03:08.905000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321257,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 36,
     'uid': 'ad17bd9a-735b-4a11-8ad3-dc7800e342af'},
    'free_bikes': 34,
    'id': 'f5fa2836e9a311eb07c74683ae2c512b',
    'latitude': 40.75370225419114,
    'longitude': -73.95865201950072,
    'name': 'Southpoint Park',
    'timestamp': '2023-08-29T15:03:07.722000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321250,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '3134c2d4-b090-4eb8-ab44-6f9622098f72'},
    'free_bikes': 1,
    'id': '7ebb39be2af4f90b1c00009d49f66d57',
    'latitude': 40.827075,
    'longitude': -73.945909,
    'name': 'W 148 St & Amsterdam Ave',
    'timestamp': '2023-08-29T15:03:08.256000Z'},
   {'empty_slots': 23,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321299,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '0ddb965d-95ef-4ce3-bde6-81a56ac1fbd2'},
    'free_bikes': 4,
    'id': 'cc24286524fbdad49c3ead6edbbca987',
    'latitude': 40.823498,
    'longitude': -73.94386,
    'name': 'Edgecombe Ave & W 145 St',
    'timestamp': '2023-08-29T15:03:08.539000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321275,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '1b22c037-207d-454a-90aa-8f22d0a8a7e3'},
    'free_bikes': 6,
    'id': '4490604c44f9fe3cb7ea732ff851ff99',
    'latitude': 40.816124,
    'longitude': -73.908116,
    'name': 'Westchester Ave & Jackson Ave',
    'timestamp': '2023-08-29T15:03:08.253000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321241,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '002e6e9f-ced2-47b0-bc7e-ccf38c3b4b0f'},
    'free_bikes': 17,
    'id': '17d25e1ecd17cc1955e156c78553a6e6',
    'latitude': 40.814232,
    'longitude': -73.903927,
    'name': 'Prospect Ave & E 151 St',
    'timestamp': '2023-08-29T15:03:08.193000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321308,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '0e405c35-322f-4705-8ea7-769eb3fd028a'},
    'free_bikes': 11,
    'id': '352836708e693ffee8ae667f52a6721e',
    'latitude': 40.811314,
    'longitude': -73.907729,
    'name': 'Wales Ave & E 147 St',
    'timestamp': '2023-08-29T15:03:08.490000Z'},
   {'empty_slots': 49,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321325,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 54,
     'uid': '66dc8f1f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': '2766ff5568cb556364d5931872e95f0c',
    'latitude': 40.733812191966315,
    'longitude': -73.98054420948029,
    'name': '1 Ave & E 18 St',
    'timestamp': '2023-08-29T15:03:08.419000Z'},
   {'empty_slots': 50,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321336,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 54,
     'uid': '66dc7802-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 2,
    'id': '4f40ef6a1a6b8c35b6e0eb21e80fa2e5',
    'latitude': 40.73221853,
    'longitude': -73.98165557,
    'name': '1 Ave & E 16 St',
    'timestamp': '2023-08-29T15:03:08.816000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321307,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '298d4e45-c6d2-45f1-a07a-11606026a6e4'},
    'free_bikes': 16,
    'id': '4d79abca865ff678669b7ca55f7a23d3',
    'latitude': 40.82281,
    'longitude': -73.937413,
    'name': 'W 147 St & Adam Clayton Powell Blvd',
    'timestamp': '2023-08-29T15:03:07.746000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321334,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '26599393-b967-44a6-a998-cb72ca53cd9e'},
    'free_bikes': 16,
    'id': '4f0135b5afef405cfc359aad70c1713c',
    'latitude': 40.817555,
    'longitude': -73.957163,
    'name': 'Broadway & W 131 St',
    'timestamp': '2023-08-29T15:03:09.157000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321312,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '40914c6b-293d-49ac-b83a-d9d4af998aea'},
    'free_bikes': 17,
    'id': 'c03785a530715531a2d149441b1685ec',
    'latitude': 40.815887,
    'longitude': -73.911918,
    'name': "St Ann's Ave & Westchester Ave",
    'timestamp': '2023-08-29T15:03:08.833000Z'},
   {'empty_slots': 36,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321335,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '2f656bc4-7743-4326-8330-a22bd41d9d17'},
    'free_bikes': 3,
    'id': '2166865a86bb8d9317d5b80d3da5557a',
    'latitude': 40.77237,
    'longitude': -73.99005,
    'name': 'West End Ave & W 60 St',
    'timestamp': '2023-08-29T15:03:08.610000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321320,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '4d674595-187c-417c-a691-676c4446c9fc'},
    'free_bikes': 8,
    'id': '887b2f869d833a30b109fa06a851c490',
    'latitude': 40.807347437082,
    'longitude': -73.90809774398804,
    'name': 'Southern Blvd & E 142 St',
    'timestamp': '2023-08-29T15:03:08.556000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321276,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '65a1b09d-560d-46bf-8f5d-7f59471a587e'},
    'free_bikes': 13,
    'id': 'bc44c6dddf536ce229f56341cfa4fc51',
    'latitude': 40.81695971032464,
    'longitude': -73.9422959089279,
    'name': 'Adam Clayton Powell Blvd & W 138 St',
    'timestamp': '2023-08-29T15:03:07.727000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321324,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'a1112e04-bc50-4782-b3d6-bb5902c0e8db'},
    'free_bikes': 15,
    'id': '9464844530d8a3d2b0896d05934b9595',
    'latitude': 40.8190344,
    'longitude': -73.956156,
    'name': 'Broadway & W 133 St',
    'timestamp': '2023-08-29T15:03:09.109000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 21,
     'has_ebikes': True,
     'last_updated': 1693321328,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 43,
     'uid': '821b19c1-ab13-4482-9580-770288a377a7'},
    'free_bikes': 41,
    'id': 'aba78092b2557ebf2711c2422c8bfe1f',
    'latitude': 40.75863,
    'longitude': -73.97513,
    'name': 'Madison Av & E 51 St',
    'timestamp': '2023-08-29T15:03:07.910000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321324,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '1b962833-d769-418e-b1ef-5a183bb5eb1a'},
    'free_bikes': 11,
    'id': 'b7127025dcc121da9f50c33c77e3b8b6',
    'latitude': 40.825289,
    'longitude': -73.936232,
    'name': 'Adam Clayton Powell Blvd & W 151 St',
    'timestamp': '2023-08-29T15:03:08.473000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321295,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': 'b0bac4ef-bb57-4598-a433-75c281170d5b'},
    'free_bikes': 21,
    'id': '208e0370c23cb8eb58f54e74c7f620c3',
    'latitude': 40.821111,
    'longitude': -73.935971,
    'name': 'Lenox Ave & W 146 St',
    'timestamp': '2023-08-29T15:03:09.148000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321301,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'fe6f022b-7fdb-44fe-80bb-cbfc500959bf'},
    'free_bikes': 7,
    'id': '6058ae3608f93d02d578accaec8d3dc7',
    'latitude': 40.824013,
    'longitude': -73.954743,
    'name': 'W 140 St & Riverside Dr',
    'timestamp': '2023-08-29T15:03:09.152000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321289,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': 'b3a9057e-7ff6-4117-b96e-e71c173cf1e9'},
    'free_bikes': 10,
    'id': '8f81a0374645aedcaa6d258bab86b245',
    'latitude': 40.814383,
    'longitude': -73.915368,
    'name': 'Brook Ave & E 148 St',
    'timestamp': '2023-08-29T15:03:09.133000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321279,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': 'ab79da3d-f92a-42de-a76d-e05b5d7e724c'},
    'free_bikes': 1,
    'id': '0c1bc960d195981c61538f8b3f8f0e8e',
    'latitude': 40.831327,
    'longitude': -73.946665,
    'name': 'Broadway & W 153 St',
    'timestamp': '2023-08-29T15:03:08.957000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321325,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '4f814d78-5d8d-458b-877e-2ca449b865be'},
    'free_bikes': 3,
    'id': '57d9fc9f3f0653f7d033dc7552c22a74',
    'latitude': 40.829114,
    'longitude': -73.950426,
    'name': 'Riverside Dr & W 148 St',
    'timestamp': '2023-08-29T15:03:08.947000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321225,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '361dd964-db79-47dd-b044-eac88c735249'},
    'free_bikes': 5,
    'id': '6fc4673812e2a5824c3dbdba8648cabf',
    'latitude': 40.826881,
    'longitude': -73.941427,
    'name': 'Edgecombe Ave & W 150 St',
    'timestamp': '2023-08-29T15:03:07.735000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321302,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'a23a40c3-6da5-4b0f-bb6b-8bfc01ec2261'},
    'free_bikes': 14,
    'id': 'a6469932279f9109e72fb5f39387b9c6',
    'latitude': 40.82057,
    'longitude': -73.917579,
    'name': 'E 155 St & Courtlandt Ave',
    'timestamp': '2023-08-29T15:03:09.225000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 7,
     'has_ebikes': True,
     'last_updated': 1693321286,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'e0a9ed84-55f9-40f5-90fa-87db17d2f933'},
    'free_bikes': 18,
    'id': '7d31cb7ee879ab2d3fb85f469937a206',
    'latitude': 40.819609,
    'longitude': -73.916071,
    'name': 'Melrose Ave & E 154 St',
    'timestamp': '2023-08-29T15:03:08.268000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321259,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 26,
     'uid': '8f1fdf4b-ecca-4f03-b04c-e10fe596e2c7'},
    'free_bikes': 8,
    'id': 'c08cb7f45aee1b4ab4d8dd410b116ab7',
    'latitude': 40.827212,
    'longitude': -73.942722,
    'name': 'St Nicholas Ave & W 150 St',
    'timestamp': '2023-08-29T15:03:08.990000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321309,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'ee1d39c5-47c8-4527-9456-3719c50b7be5'},
    'free_bikes': 15,
    'id': 'b18df89bcbe5daae576244c034034e3f',
    'latitude': 40.817755,
    'longitude': -73.92965,
    'name': 'Gerard Ave & E 146 St',
    'timestamp': '2023-08-29T15:03:07.769000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321303,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '9635affa-8b18-42d5-84c4-7f67ad5ef9d0'},
    'free_bikes': 5,
    'id': '251744beb2e75bd71d698aa845d164d2',
    'latitude': 40.807466,
    'longitude': -73.927107,
    'name': 'Alexander Ave & E 134 St',
    'timestamp': '2023-08-29T15:03:08.782000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321308,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '85b77b8d-32b8-4049-a407-64319916e2c5'},
    'free_bikes': 13,
    'id': 'c2dde06cc629e5b3c7ffe188bc4a4738',
    'latitude': 40.829523,
    'longitude': -73.944279,
    'name': 'Amsterdam Ave & W 152 St',
    'timestamp': '2023-08-29T15:03:08.061000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321236,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '493850bd-125b-49f5-932b-bf999504fb06'},
    'free_bikes': 9,
    'id': 'd526f6f513f1d3f4b21699b24be0bbc2',
    'latitude': 40.82188,
    'longitude': -73.907521,
    'name': 'Cauldwell Ave & E 161 St',
    'timestamp': '2023-08-29T15:03:08.109000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321283,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'be435dfd-e859-487c-ae32-3d2b76d49a49'},
    'free_bikes': 15,
    'id': '1fb3d623c3186cec8a982d01bba5ffeb',
    'latitude': 40.819823,
    'longitude': -73.912411,
    'name': 'E 156 & Brook Ave',
    'timestamp': '2023-08-29T15:03:08.385000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321235,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '6f21be51-6fde-4cde-b1db-b102a5f67300'},
    'free_bikes': 15,
    'id': '69891153fb372c88c0f38840f296641a',
    'latitude': 40.820713,
    'longitude': -73.911759,
    'name': 'Brook Ave & E 157 St',
    'timestamp': '2023-08-29T15:03:07.904000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321255,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '676b7b4d-b1c0-4c97-8ac3-5fe665e51108'},
    'free_bikes': 3,
    'id': 'a0dfdc0153fb5a8043d617976bf821de',
    'latitude': 40.830476,
    'longitude': -73.939929,
    'name': 'Harlem River Dr & W 155 St',
    'timestamp': '2023-08-29T15:03:07.846000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321283,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66dcc8b3-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 7,
    'id': 'f835d16bb01c22974f01c5f991f2aaa9',
    'latitude': 40.69425403,
    'longitude': -73.94626915,
    'name': 'Willoughby Ave & Tompkins Ave',
    'timestamp': '2023-08-29T15:03:08.463000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321250,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': 'df243d7f-e6ae-435c-9895-aecbcff9cada'},
    'free_bikes': 15,
    'id': '689238a79db5c399d6d47f35d1f101e0',
    'latitude': 40.81899,
    'longitude': -73.90202,
    'name': 'Prospect Ave & Longwood Ave',
    'timestamp': '2023-08-29T15:03:08.189000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321279,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '54df610f-0e47-4958-98ca-37bb1b1c4dca'},
    'free_bikes': 5,
    'id': 'eab3fab61c2fe184388452b5444605b9',
    'latitude': 40.82831,
    'longitude': -73.942924,
    'name': 'Convent Ave & W 151 St',
    'timestamp': '2023-08-29T15:03:08.283000Z'},
   {'empty_slots': 57,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321322,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 59,
     'uid': '66de871c-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': 'b1172011d4194e5367dbe8a186c1b7db',
    'latitude': 40.79313480986663,
    'longitude': -73.97700369358063,
    'name': 'Riverside Dr & W 91 St',
    'timestamp': '2023-08-29T15:03:08.841000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321278,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '058ee86d-ce2a-4597-99f7-f78f082b33e3'},
    'free_bikes': 3,
    'id': '9969e525d7300c6f89a61c76cf939816',
    'latitude': 40.832314,
    'longitude': -73.94102,
    'name': 'St. Nicholas Ave & W 157 St',
    'timestamp': '2023-08-29T15:03:09.173000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321300,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '0183d7d4-9e11-4429-94db-666a31239871'},
    'free_bikes': 26,
    'id': 'ae5c78ea6721e3f382ae62a113d398c7',
    'latitude': 40.82923,
    'longitude': -73.936996,
    'name': 'W 155 St & Frederick Douglass Blvd',
    'timestamp': '2023-08-29T15:03:08.948000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321302,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '517409d3-a94a-4140-a6de-ff0de9221ed2'},
    'free_bikes': 5,
    'id': '51566dbd8690fc11d84dc3bcbbb8e5bf',
    'latitude': 40.817802,
    'longitude': -73.905203,
    'name': 'Westchester Ave & E 156 St',
    'timestamp': '2023-08-29T15:03:08.797000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321234,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': 'bc9c9006-3d40-400d-8b5c-17f56e6dfcee'},
    'free_bikes': 9,
    'id': 'ab01d973c0064b0da854c1c319f94bf6',
    'latitude': 40.83618,
    'longitude': -73.939789,
    'name': 'Amsterdam Ave & W 162 St',
    'timestamp': '2023-08-29T15:03:08.407000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321338,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 26,
     'uid': 'b83b2a73-af8e-4b82-b61e-aeaaf075fbe2'},
    'free_bikes': 3,
    'id': '704afa6435c783a945e9ba1ced51ef79',
    'latitude': 40.834468,
    'longitude': -73.939865,
    'name': 'W 160 St & St. Nicholas Ave',
    'timestamp': '2023-08-29T15:03:08.471000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321327,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '59af018a-2ee9-489a-b445-bb6fba9c1119'},
    'free_bikes': 3,
    'id': 'a6bd36bf42380d5e638614ab9ed4e1c8',
    'latitude': 40.839278,
    'longitude': -73.945446,
    'name': 'W 163 St & Riverside Dr',
    'timestamp': '2023-08-29T15:03:08.844000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321260,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': 'cda60c6d-80f3-41b7-8ece-fe997f6dafb5'},
    'free_bikes': 19,
    'id': '9386b43640322bafb8df7a34436bbade',
    'latitude': 40.820302,
    'longitude': -73.903944,
    'name': 'E 160 St & Tinton Ave',
    'timestamp': '2023-08-29T15:03:08.750000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321318,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '95a52ce4-3597-47d1-8d6f-427cb3b8ca6a'},
    'free_bikes': 7,
    'id': 'f8dda0067aa3c8f6e0a944f0ba3394ce',
    'latitude': 40.84004,
    'longitude': -73.942939,
    'name': 'W 165 St & Fort Washington Ave',
    'timestamp': '2023-08-29T15:03:08.462000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321320,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '912813fc-fde4-4430-8443-a4fa21477e7f'},
    'free_bikes': 9,
    'id': '5513a73dcdefd0b88bf95d19ba4f9f80',
    'latitude': 40.839137,
    'longitude': -73.941409,
    'name': 'Broadway & W 165 St',
    'timestamp': '2023-08-29T15:03:07.989000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321294,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '6b60bf55-3da4-439a-bde1-fc80be8623ba'},
    'free_bikes': 11,
    'id': '722f02f052097217388234e5f1b98104',
    'latitude': 40.84522,
    'longitude': -73.940493,
    'name': 'Fort Washington Ave & W 173 St',
    'timestamp': '2023-08-29T15:03:07.732000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321287,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '3c73cc9f-3c09-4ac4-a4ea-22b4f027bf23'},
    'free_bikes': 6,
    'id': 'e94a89a94e01b1551aab828d199d050f',
    'latitude': 40.842173,
    'longitude': -73.935111,
    'name': 'Amsterdam Ave & W 172 St',
    'timestamp': '2023-08-29T15:03:07.771000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 8,
     'has_ebikes': True,
     'last_updated': 1693321242,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'ce95fbdd-b7d2-46fc-910d-5c170e4b7610'},
    'free_bikes': 14,
    'id': 'e1aa84c60a4dd7d0f5387de289b781fe',
    'latitude': 40.830702,
    'longitude': -73.936371,
    'name': 'Frederick Douglass Blvd & Harlem River Dr',
    'timestamp': '2023-08-29T15:03:08.865000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321303,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '344b52b0-73a9-4fe3-9132-23d0502dc0ae'},
    'free_bikes': 7,
    'id': '231bb88e3c431557d9e297374e904b58',
    'latitude': 40.835775,
    'longitude': -73.9434,
    'name': 'Broadway & W 160 St',
    'timestamp': '2023-08-29T15:03:07.831000Z'},
   {'empty_slots': 31,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321310,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 38,
     'uid': '50575cba-95ac-4134-9da1-3eec8253afc4'},
    'free_bikes': 1,
    'id': '3071771712dbe4468e3c766a4d6d5273',
    'latitude': 40.78476,
    'longitude': -73.969862,
    'name': 'Central Park West & W 85 St',
    'timestamp': '2023-08-29T15:03:07.796000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321329,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '26217b73-7bb5-46e6-8094-1db05becd617'},
    'free_bikes': 10,
    'id': '68fcda3c239cc8c15b8fdce5896deee1',
    'latitude': 40.832081,
    'longitude': -73.942386,
    'name': 'Amsterdam Ave & W 156 St',
    'timestamp': '2023-08-29T15:03:09.164000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321258,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': 'd0b87aa7-7e19-40d2-8f7d-6a622e6ac391'},
    'free_bikes': 10,
    'id': 'be981361f27f544964784cf3e17be822',
    'latitude': 40.819241,
    'longitude': -73.941057,
    'name': 'Adam Clayton Powell Blvd & W 141 St',
    'timestamp': '2023-08-29T15:03:08.632000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321225,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '5adcaaaf-5386-441d-827c-8d65c4f4405e'},
    'free_bikes': 13,
    'id': '5d91a4502fa6e582b7ffd998f184c513',
    'latitude': 40.839443,
    'longitude': -73.937044,
    'name': 'Amsterdam Ave & W 167 St',
    'timestamp': '2023-08-29T15:03:08.876000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321222,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '18a2cbb6-91f2-4393-82fb-b40a8ba90f20'},
    'free_bikes': 16,
    'id': 'de9d1a142c9d8843ed7214b3e961aa98',
    'latitude': 40.844044,
    'longitude': -73.933651,
    'name': 'Amsterdam Ave & W 175 St',
    'timestamp': '2023-08-29T15:03:09.317000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321301,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '3bf69f3e-23f6-4abe-b5fe-dabe6b0ea066'},
    'free_bikes': 8,
    'id': 'a1f23edb96370a27313e114bb8bd69db',
    'latitude': 40.846052,
    'longitude': -73.937648,
    'name': 'Wadsworth Ave & W 175 St',
    'timestamp': '2023-08-29T15:03:08.303000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321295,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '61bc2467-aa8c-4386-ba9e-3f01120bd6b8'},
    'free_bikes': 5,
    'id': 'bd0737c8122b1219d2f595b9050d1c64',
    'latitude': 40.848282,
    'longitude': -73.941343,
    'name': 'Cabrini Blvd & W 177 St',
    'timestamp': '2023-08-29T15:03:08.606000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321293,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'ceb179f3-89c3-4c3e-8a0a-3415406a9463'},
    'free_bikes': 10,
    'id': '28cf18bbf722dcc6e0418e719d6c1312',
    'latitude': 40.847396,
    'longitude': -73.931205,
    'name': 'Amsterdam Ave & W 180 St',
    'timestamp': '2023-08-29T15:03:09.260000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321334,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '08b9c491-a589-4e75-996c-2455c26fb356'},
    'free_bikes': 5,
    'id': 'a7f2fc9277b0a1366bd3cc1c9e6230da',
    'latitude': 40.847305,
    'longitude': -73.933291,
    'name': 'Audobon Ave & W 179 St',
    'timestamp': '2023-08-29T15:03:07.879000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321323,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '774c5443-d463-42b3-bfc5-b0ab3c56fe35'},
    'free_bikes': 13,
    'id': 'fe476c6c9aac55195a4c31a99b8f9d89',
    'latitude': 40.848467,
    'longitude': -73.936064,
    'name': 'Wadsworth Ave & W 179 St',
    'timestamp': '2023-08-29T15:03:09.347000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321290,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '16280b32-7e5b-4a18-930b-212eac10faaa'},
    'free_bikes': 15,
    'id': '76e99ec8ae0548bd87f5cd0755963ea3',
    'latitude': 40.818212,
    'longitude': -73.955277,
    'name': 'Old Broadway & W 133 St',
    'timestamp': '2023-08-29T15:03:07.968000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'f6c33f22-d650-4935-a928-fb693a828b5f'},
    'free_bikes': 8,
    'id': '27d7174adbc6581cde33e86a4123ad56',
    'latitude': 40.830663,
    'longitude': -73.941323,
    'name': 'St. Nicholas Ave & W 155 St',
    'timestamp': '2023-08-29T15:03:08.552000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321291,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66dc0d3a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 8,
    'id': '9ef94b24c342975106d5f4488e12d4cb',
    'latitude': 40.69573398,
    'longitude': -73.97129668,
    'name': 'Clermont Ave & Park Ave',
    'timestamp': '2023-08-29T15:03:09.170000Z'},
   {'empty_slots': 45,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321299,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 48,
     'uid': 'a93cb1ec-fb37-4faf-a7e7-d1e5a9e9af95'},
    'free_bikes': 1,
    'id': '719f3011fba69cf7ea4d1bd2089aff8c',
    'latitude': 40.788664991278836,
    'longitude': -73.96680057048798,
    'name': 'Central Park W & W 91 St',
    'timestamp': '2023-08-29T15:03:07.958000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321292,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '6a52ceae-3b97-487a-9438-de844bfbf1c2'},
    'free_bikes': 2,
    'id': '27a9eed03d870dfeecb68b68cd861458',
    'latitude': 40.84925,
    'longitude': -73.93022,
    'name': 'Amsterdam Ave & W 183 St',
    'timestamp': '2023-08-29T15:03:08.861000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321283,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '9c2a741d-7f3e-4aa1-b58b-db5c3e6bcb20'},
    'free_bikes': 25,
    'id': '4ce6329557f7ea534d1d01c4861c65e3',
    'latitude': 40.833909,
    'longitude': -73.92112,
    'name': 'Gerard Ave & McClellan St',
    'timestamp': '2023-08-29T15:03:07.941000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321307,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '0f536c08-dde3-40af-a66d-1fe1e7edecd2'},
    'free_bikes': 7,
    'id': '8768e38b0c721ed174ce8fd5098741b8',
    'latitude': 40.83173,
    'longitude': -73.922394,
    'name': 'Gerard Ave & E 165 St',
    'timestamp': '2023-08-29T15:03:08.459000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 13,
     'has_ebikes': True,
     'last_updated': 1693321260,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '17c45d34-0d8d-46ba-9078-e9a2a7c5867c'},
    'free_bikes': 18,
    'id': '3bb1d17813291d3cd959eaecd50bcee7',
    'latitude': 40.834263,
    'longitude': -73.917641,
    'name': 'Grand Concourse & E 167 St',
    'timestamp': '2023-08-29T15:03:08.161000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321231,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'a4bb6fac-b795-4aa7-a266-613419019290'},
    'free_bikes': 10,
    'id': '091363b289454cd265e586c98d85080a',
    'latitude': 40.830262,
    'longitude': -73.923391,
    'name': 'Gerard Ave & E 164 St',
    'timestamp': '2023-08-29T15:03:08.671000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321290,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '481624f3-9377-4dfd-a5dd-de05a7fef760'},
    'free_bikes': 3,
    'id': '225442af0468f2a7e887552c28eebd8a',
    'latitude': 40.834457,
    'longitude': -73.928381,
    'name': 'Ogden Ave & W 165 St',
    'timestamp': '2023-08-29T15:03:08.796000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321254,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': 'b96507c5-7c90-499d-9c45-58f25d6f636a'},
    'free_bikes': 6,
    'id': '816ded3bc701ccc696a516eba5f09fae',
    'latitude': 40.839312,
    'longitude': -73.922423,
    'name': 'Shakespeare Ave & W 169 St',
    'timestamp': '2023-08-29T15:03:08.398000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321275,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': 'a0eec052-257a-4c79-8171-6e2ad9864ad0'},
    'free_bikes': 11,
    'id': '1f0aa7c55f92c1b023cbdb4e47621dd6',
    'latitude': 40.72506551015475,
    'longitude': -73.97515833377838,
    'name': 'Avenue D & E 10 St',
    'timestamp': '2023-08-29T15:03:09.129000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321273,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'e0b80983-c520-47e3-9c8d-a17fff5e5582'},
    'free_bikes': 18,
    'id': '7d6535586d6b9f755ce9fbeb0abc57f4',
    'latitude': 40.834015,
    'longitude': -73.908863,
    'name': 'E 169 St & Webster Ave',
    'timestamp': '2023-08-29T15:03:07.876000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321231,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': 'ba0a4ada-c9f6-48b4-a7b3-7220f6fb88c2'},
    'free_bikes': 16,
    'id': '1c06103496ad8131ccc2e3d93b217c99',
    'latitude': 40.839549,
    'longitude': -73.913004,
    'name': 'Grand Concourse & E 171 St',
    'timestamp': '2023-08-29T15:03:08.761000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321290,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '79c4a612-a5df-4814-9e6b-6305da61ebc4'},
    'free_bikes': 18,
    'id': 'd2d94273d6e713415da55bb03a4eeddd',
    'latitude': 40.840536,
    'longitude': -73.919228,
    'name': 'Inwood Ave & W 170 St',
    'timestamp': '2023-08-29T15:03:08.539000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321259,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '9d56294e-61fc-4176-bb9c-4692f45bb374'},
    'free_bikes': 21,
    'id': 'eb1883b17a32f18a47bfe7505dcd2971',
    'latitude': 40.822215,
    'longitude': -73.914688,
    'name': 'E 158 St & Melrose Ave',
    'timestamp': '2023-08-29T15:03:08.090000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321304,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66de5ace-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': '20033983bc8432af9f50b9f7d5d6a545',
    'latitude': 40.6793307,
    'longitude': -73.97519523,
    'name': 'Prospect Pl & 6 Ave',
    'timestamp': '2023-08-29T15:03:08.776000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321329,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '09a0c507-7cda-4f3f-9988-78de0baa28e4'},
    'free_bikes': 1,
    'id': '76d654df0d9dc9702b7f64261c0a387e',
    'latitude': 40.823429,
    'longitude': -73.924689,
    'name': 'Grand Concourse & E 156 St',
    'timestamp': '2023-08-29T15:03:09.174000Z'},
   {'empty_slots': 41,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321278,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 43,
     'uid': '66dde197-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': 'e5723d87e43ca6b91d78d65c63d86315',
    'latitude': 40.78839,
    'longitude': -73.9747,
    'name': 'W 87 St & Amsterdam Ave',
    'timestamp': '2023-08-29T15:03:08.395000Z'},
   {'empty_slots': 44,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321282,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 47,
     'uid': '66dde271-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': '0247e4455157e703b2059b05e99b1583',
    'latitude': 40.789622,
    'longitude': -73.97757,
    'name': 'W 87 St & West End Ave',
    'timestamp': '2023-08-29T15:03:08.364000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321227,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '1bb1af93-b433-4da7-8054-009c85f7755a'},
    'free_bikes': 15,
    'id': '2f3b31369758bd42df0bbe0fee76f8b1',
    'latitude': 40.830179,
    'longitude': -73.928747,
    'name': 'Jerome Ave & Anderson Ave',
    'timestamp': '2023-08-29T15:03:08.002000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321255,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': 'abc1311e-e000-4211-af9e-0cf92242711e'},
    'free_bikes': 3,
    'id': '539b9ac394eb1be807f07efb5c6c231c',
    'latitude': 40.829608,
    'longitude': -73.921461,
    'name': 'Grand Concourse & E 164 St',
    'timestamp': '2023-08-29T15:03:07.974000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321298,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '514afe43-84d4-4941-8281-75a93c5cd365'},
    'free_bikes': 13,
    'id': '1438a2638d7050480b05072dfd2e65e0',
    'latitude': 40.831584,
    'longitude': -73.9149,
    'name': 'Morris Ave & McClellan St',
    'timestamp': '2023-08-29T15:03:09.025000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321320,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': 'b896d83d-5524-4c9c-a2aa-c1b0edaadc22'},
    'free_bikes': 4,
    'id': '5b6ead3760691701c0fb8a811d32e5aa',
    'latitude': 40.83649,
    'longitude': -73.918316,
    'name': 'Walton Ave & E 168 St',
    'timestamp': '2023-08-29T15:03:07.936000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321308,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'c6c10756-ef41-491a-8e6c-ee0aa27b8cbe'},
    'free_bikes': 3,
    'id': 'cc07af3c38f67dc625ee3f25200216a3',
    'latitude': 40.833303,
    'longitude': -73.939326,
    'name': 'W 159 St & Edgecombe Ave',
    'timestamp': '2023-08-29T15:03:07.759000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321310,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '5db1fefa-0f10-4c58-a7ce-113f3164ced8'},
    'free_bikes': 12,
    'id': '5074c3a8c12bf198b082c34b04c49239',
    'latitude': 40.75742,
    'longitude': -73.945133,
    'name': '40 Ave & 9 St',
    'timestamp': '2023-08-29T15:03:09.019000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321312,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '38af3d1a-9916-46cf-b22e-86fc8648bf30'},
    'free_bikes': 6,
    'id': '887a1feb0f2629df90a9f89132c5d605',
    'latitude': 40.825716,
    'longitude': -73.915585,
    'name': 'Park Ave & E 162 St',
    'timestamp': '2023-08-29T15:03:09.144000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321273,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '595cf79f-7783-4373-b3d5-775bcf76033b'},
    'free_bikes': 3,
    'id': '82bb08635ec74b9a91459293aa1bd534',
    'latitude': 40.839142,
    'longitude': -73.925961,
    'name': 'Ogden Ave & Merriam Ave',
    'timestamp': '2023-08-29T15:03:08.582000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321275,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '05d03a63-b5f2-40d9-9a3d-d2fe666a307f'},
    'free_bikes': 5,
    'id': '8121dda5c07977ce90969b8acc1b8b21',
    'latitude': 40.837576,
    'longitude': -73.910489,
    'name': 'College Ave & E 170 St',
    'timestamp': '2023-08-29T15:03:08.076000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321318,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '8a13182a-4823-4fe7-afcd-a4ef0b134ed9'},
    'free_bikes': 15,
    'id': '24bceb83a849b507e01c89aff0d62edb',
    'latitude': 40.843264,
    'longitude': -73.904867,
    'name': 'Clay Ave & E 173 St',
    'timestamp': '2023-08-29T15:03:08.377000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321320,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 63,
     'uid': 'de0c1800-f7cc-41b4-ab7a-c9d219180d06'},
    'free_bikes': 54,
    'id': 'c8158de4066769d065d46285082ff694',
    'latitude': 40.749498546025194,
    'longitude': -73.97729203113158,
    'name': 'E 39 St & Lexington Ave',
    'timestamp': '2023-08-29T15:03:08.139000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321234,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '00284700-9d22-42ce-8485-113fed9879c1'},
    'free_bikes': 1,
    'id': '5ba015beac09575892adf8c2b17c0d6b',
    'latitude': 40.76408932350688,
    'longitude': -73.91065120697021,
    'name': '28 Ave & 44 St',
    'timestamp': '2023-08-29T15:03:07.773000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '971cddfa-695e-4b44-ba8b-26154ab4a83b'},
    'free_bikes': 14,
    'id': '325144d972617ff140a410abb38a425a',
    'latitude': 40.812769,
    'longitude': -73.901583,
    'name': 'Southern Blvd & Avenue St. John',
    'timestamp': '2023-08-29T15:03:08.183000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321313,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': 'c0a3b8fe-ba64-4cbb-b010-f760998d6c3a'},
    'free_bikes': 16,
    'id': 'bcd56c1753bd56710334a2846084cc5f',
    'latitude': 40.815077,
    'longitude': -73.899939,
    'name': 'Beck St & Leggett Ave',
    'timestamp': '2023-08-29T15:03:08.498000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321303,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'f752c376-3a6f-4cd3-b9fd-3c049d45a9a6'},
    'free_bikes': 14,
    'id': 'a5725b6c30947559d2ecc49a28db3a54',
    'latitude': 40.829797,
    'longitude': -73.931015,
    'name': 'Jerome Ave & Ogden Ave',
    'timestamp': '2023-08-29T15:03:08.149000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321232,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '8ce7325e-d5c7-46f9-9b73-95356e48c3eb'},
    'free_bikes': 19,
    'id': '25af6f2f3633c375549caa431a1adc8b',
    'latitude': 40.816343,
    'longitude': -73.896447,
    'name': 'Longwood Ave & Southern Blvd',
    'timestamp': '2023-08-29T15:03:08.813000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321273,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '7cd61426-ed98-434e-9235-56ed856fead6'},
    'free_bikes': 5,
    'id': 'b8a38fda3dec483de10f763b4bfff1fd',
    'latitude': 40.819701,
    'longitude': -73.901311,
    'name': 'Westchester Ave & Longwood Ave',
    'timestamp': '2023-08-29T15:03:07.722000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321256,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '8a89684b-40a5-49fe-b75d-fdf32ffa8102'},
    'free_bikes': 15,
    'id': 'e96cfb33a431f10e7c5766a987ebf0a0',
    'latitude': 40.818185,
    'longitude': -73.894143,
    'name': 'Southern Blvd & Tiffany St',
    'timestamp': '2023-08-29T15:03:08.553000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321335,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '66de867e-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 10,
    'id': 'f3b68140aec0b0434cedcd137cee864b',
    'latitude': 40.721319,
    'longitude': -74.010065,
    'name': 'Greenwich St & Hubert St',
    'timestamp': '2023-08-29T15:03:08.003000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321321,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '6476c5fd-611e-436c-9736-e0f43bb7774e'},
    'free_bikes': 3,
    'id': 'e8720caf59880913fe1ef7e642ba74f9',
    'latitude': 40.821075,
    'longitude': -73.895069,
    'name': 'E 163 St & Tiffany St',
    'timestamp': '2023-08-29T15:03:09.179000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321296,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '6e5a8cab-cf1a-4584-8133-01835b56ad71'},
    'free_bikes': 25,
    'id': 'de54accb14b7cd132b41a1a38dd42171',
    'latitude': 40.82441,
    'longitude': -73.92818,
    'name': 'River Ave & E 153 St',
    'timestamp': '2023-08-29T15:03:07.982000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321293,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '66dbf288-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': 'b0f423dc5500907c4db00fb3c54d02f0',
    'latitude': 40.69512845,
    'longitude': -73.99595065,
    'name': 'Hicks St & Montague St',
    'timestamp': '2023-08-29T15:03:07.854000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321337,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'c29c9178-bcb1-4c0c-b789-f4a89512a4e4'},
    'free_bikes': 4,
    'id': '168945a14fa09790975c2f6baff2553a',
    'latitude': 40.823162,
    'longitude': -73.923267,
    'name': 'Concourse Village West & E 156 St',
    'timestamp': '2023-08-29T15:03:09.096000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321319,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': 'b471c112-1770-4dfe-9e13-fe7479dcb5a5'},
    'free_bikes': 9,
    'id': 'b61167d0bbfad45be37a06681b244715',
    'latitude': 40.821967,
    'longitude': -73.896752,
    'name': 'Intervale Ave & Westchester Ave',
    'timestamp': '2023-08-29T15:03:09.225000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321236,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'ebce9ecb-9678-4c42-89d7-08e54bc6fe90'},
    'free_bikes': 14,
    'id': '70503d005dbfbbbbd19def75cabf17b2',
    'latitude': 40.820578,
    'longitude': -73.888271,
    'name': 'Faile St & Garrison Ave',
    'timestamp': '2023-08-29T15:03:08.378000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321302,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'db91c9e0-d80b-4cb4-9cc2-9453ec8fbeac'},
    'free_bikes': 5,
    'id': 'c48d7dba8b6bd7222b031acbd63081be',
    'latitude': 40.84301,
    'longitude': -73.91172,
    'name': 'Grand Concourse & East Mount Eden Ave',
    'timestamp': '2023-08-29T15:03:08.131000Z'},
   {'empty_slots': 27,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321268,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': 'c9cf9887-9f1a-420f-9ab3-8a35a5db4ad1'},
    'free_bikes': 4,
    'id': 'c82909c98b31dac05e9306b63a323ec3',
    'latitude': 40.83299,
    'longitude': -73.94592,
    'name': 'Broadway & W 155 St',
    'timestamp': '2023-08-29T15:03:08.330000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321331,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '1a5eae13-8f27-4875-8330-a796c95f8ad6'},
    'free_bikes': 7,
    'id': '4516368a93b99c2ea07c226e5a37fc2c',
    'latitude': 40.827184,
    'longitude': -73.893721,
    'name': 'E 169 St & Fox St',
    'timestamp': '2023-08-29T15:03:07.778000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321258,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '531e6d94-5f4c-4ef0-9c83-47191be9d8f9'},
    'free_bikes': 16,
    'id': 'e4d564c4a3bd49cbc9de1e0a7106282a',
    'latitude': 40.824796,
    'longitude': -73.90242,
    'name': 'Tinton Ave & E 165 St',
    'timestamp': '2023-08-29T15:03:08.558000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321303,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '94624d6e-4150-4ab1-92ff-bf55cb58ab61'},
    'free_bikes': 6,
    'id': '35cb4c22b58cd751194c6e632adf0d9f',
    'latitude': 40.834124,
    'longitude': -73.88955,
    'name': 'Southern Blvd & E 172 St',
    'timestamp': '2023-08-29T15:03:07.998000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321278,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'd4c34830-972f-4cd1-81bb-071df209d065'},
    'free_bikes': 5,
    'id': 'dbe3cf1caac1f3526e56e8305d0fae6f',
    'latitude': 40.85168,
    'longitude': -73.94186,
    'name': 'W 181 St & Riverside Dr',
    'timestamp': '2023-08-29T15:03:09.233000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321226,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 53,
     'uid': '66db2953-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 49,
    'id': '2cd44523a6a2c76c784864c504b2a4b1',
    'latitude': 40.69608941,
    'longitude': -73.97803415,
    'name': 'Park Ave & St Edwards St',
    'timestamp': '2023-08-29T15:03:07.850000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321287,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '203d7b9a-8666-4af1-81c7-f9fc36aa0952'},
    'free_bikes': 1,
    'id': '70a340ea27e937e2d816647d828af95c',
    'latitude': 40.832057,
    'longitude': -73.927421,
    'name': 'Anderson Ave & W 164 St',
    'timestamp': '2023-08-29T15:03:08.074000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321309,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '78ec2f0d-c309-46d4-8808-7eb1a0674e38'},
    'free_bikes': 11,
    'id': '78a6d91d2c3e20e1bb788d63b076f92e',
    'latitude': 40.823732,
    'longitude': -73.919379,
    'name': 'Concourse Village East & E 158 St',
    'timestamp': '2023-08-29T15:03:08.580000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321295,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 42,
     'uid': '66dd2208-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 27,
    'id': '29bfff7d2e0648f6c010fc519dd1f711',
    'latitude': 40.73555,
    'longitude': -73.95284,
    'name': 'McGuinness Blvd & Eagle St',
    'timestamp': '2023-08-29T15:03:08.026000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321229,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '1d977221-b2b5-4fa2-bba0-b00136834fb3'},
    'free_bikes': 12,
    'id': '3d8cf5ee5e8fa4ced1ebb4a2d6db9b47',
    'latitude': 40.83406,
    'longitude': -73.92243,
    'name': 'River Ave & McClellan St',
    'timestamp': '2023-08-29T15:03:09.127000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321301,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'bf880f45-422c-4e0b-b3b0-2b1f5ba94da4'},
    'free_bikes': 0,
    'id': '9eeca8aac99d0c966ba652db42405326',
    'latitude': 40.83545,
    'longitude': -73.90153,
    'name': "Fulton Ave & St. Paul's Pl",
    'timestamp': '2023-08-29T15:03:08.022000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 9,
     'has_ebikes': True,
     'last_updated': 1693321314,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'c46a2889-258b-4fc5-a452-1d4e7dfe683a'},
    'free_bikes': 15,
    'id': 'bcfab22be47d8a8883eeb6474ee28557',
    'latitude': 40.82696,
    'longitude': -73.907451,
    'name': '3 Ave & Franklin Ave',
    'timestamp': '2023-08-29T15:03:08.883000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321324,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'c8060816-b4aa-4fd9-bc66-af28bf61dc87'},
    'free_bikes': 4,
    'id': 'eaa62a119b6c9ac52f902847a03e5812',
    'latitude': 40.822756,
    'longitude': -73.951346,
    'name': 'Hamilton Pl & W 140 St',
    'timestamp': '2023-08-29T15:03:08.475000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321312,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '8d8a381c-21df-4095-837e-65924d85a06d'},
    'free_bikes': 5,
    'id': 'c96a4a5a1b3aa0ae9047e15326276725',
    'latitude': 40.834857,
    'longitude': -73.903743,
    'name': '3 Ave & E 170 St',
    'timestamp': '2023-08-29T15:03:08.962000Z'},
   {'empty_slots': 27,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321326,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 49,
     'uid': '55ccb271-7035-422e-bee1-20e84caa0217'},
    'free_bikes': 21,
    'id': '39e0c5535a118b97e5c64d0fd2da9b8e',
    'latitude': 40.745686,
    'longitude': -74.005141,
    'name': 'W 20 St & 10 Ave',
    'timestamp': '2023-08-29T15:03:07.894000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321325,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '0c106e83-c47a-4233-b5e4-62bbb75d0bed'},
    'free_bikes': 8,
    'id': '0bac8585a63ad3d5fdc718738103cae5',
    'latitude': 40.830471,
    'longitude': -73.904556,
    'name': 'Fulton Ave & E 168 St',
    'timestamp': '2023-08-29T15:03:08.535000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321268,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'aa0e6301-4162-428d-8943-7b684089b0d1'},
    'free_bikes': 17,
    'id': '00f0ea447a1af60aa053a510d944e623',
    'latitude': 40.825737,
    'longitude': -73.927311,
    'name': 'E 157 St & River Ave',
    'timestamp': '2023-08-29T15:03:09.246000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321307,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '66de11bc-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 18,
    'id': 'd06e6498c31efd64e51222f1f718eb33',
    'latitude': 40.6753274,
    'longitude': -74.0100698,
    'name': 'Wolcott St & Dwight St',
    'timestamp': '2023-08-29T15:03:09.216000Z'},
   {'empty_slots': 24,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321286,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 47,
     'uid': '66dd1846-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 17,
    'id': '726ad43c35065e99538191eb70b287fe',
    'latitude': 40.72079821,
    'longitude': -73.95484712,
    'name': 'N 12 St & Bedford Ave',
    'timestamp': '2023-08-29T15:03:08.609000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321335,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 41,
     'uid': '66de2b97-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 25,
    'id': 'e99c97fd8792bc37d9669ace03f8887f',
    'latitude': 40.680611,
    'longitude': -73.99475825,
    'name': 'Carroll St & Smith St',
    'timestamp': '2023-08-29T15:03:09.298000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321313,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'b4b5824b-3c23-44b7-92a3-cec6a54583a0'},
    'free_bikes': 4,
    'id': '5e29d9445c919d17f826bda15df4e440',
    'latitude': 40.83899,
    'longitude': -73.9109,
    'name': 'Morris Ave & E 171 St',
    'timestamp': '2023-08-29T15:03:07.902000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321325,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '66dcf897-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 22,
    'id': '4c75b208e6bc6c0aa04224b6bf639827',
    'latitude': 40.715143,
    'longitude': -73.944507,
    'name': 'Graham Ave & Conselyea St',
    'timestamp': '2023-08-29T15:03:08.564000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321332,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '99614ecb-2329-49fa-a13a-fa1ef2bb32d6'},
    'free_bikes': 12,
    'id': 'b20b28529e5a4f53f3854c34f903fd3d',
    'latitude': 40.83999,
    'longitude': -73.90549,
    'name': 'Clay Ave & Claremont Pkwy',
    'timestamp': '2023-08-29T15:03:08.611000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321255,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '66dc3782-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 11,
    'id': '537b7462ea4c5df12d48bda50dc7c8b2',
    'latitude': 40.71286844,
    'longitude': -73.95698119,
    'name': 'Grand St & Havemeyer St',
    'timestamp': '2023-08-29T15:03:08.596000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321238,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'a2ef8ed2-6031-4049-b7dc-9838ef39889b'},
    'free_bikes': 7,
    'id': '38d18b335b85f074082f18bf37444250',
    'latitude': 40.819999,
    'longitude': -73.897263,
    'name': 'Dawson St & Intervale Ave',
    'timestamp': '2023-08-29T15:03:09.116000Z'},
   {'empty_slots': 22,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321316,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': 'c530a1cb-7c60-4651-be8a-9bfa5eb43f8a'},
    'free_bikes': 11,
    'id': '16192e9e9c1fd9881678a172bbe8859d',
    'latitude': 40.84224,
    'longitude': -73.8985,
    'name': '3 Ave & E 174 St',
    'timestamp': '2023-08-29T15:03:08.187000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321280,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '18267c09-1916-48d8-951c-caf88c89edd1'},
    'free_bikes': 10,
    'id': '480bd31f85deae5bb5630c392ef5555f',
    'latitude': 40.839586,
    'longitude': -73.900277,
    'name': '3 Ave & E 172 St',
    'timestamp': '2023-08-29T15:03:09.353000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321268,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '5d994b32-b7a5-450d-9bbb-93bf3b03e6d5'},
    'free_bikes': 6,
    'id': 'b42c6731e2904fd95fdabe51cc3a7a71',
    'latitude': 40.827301,
    'longitude': -73.896372,
    'name': 'Intervale Ave & Kelly St',
    'timestamp': '2023-08-29T15:03:08.320000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321323,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '66de06ef-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': 'f0d48ab5d236667d32ea45385e2cc6bf',
    'latitude': 40.668603,
    'longitude': -73.9904394,
    'name': '12 St & 4 Ave',
    'timestamp': '2023-08-29T15:03:08.790000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321323,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': '66de1448-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 8,
    'id': '861172d57fe65cc958f1142e03b758e1',
    'latitude': 40.675146838709786,
    'longitude': -73.97523209452629,
    'name': 'Berkeley Pl & 7 Ave',
    'timestamp': '2023-08-29T15:03:08.545000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321321,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '19002a4c-3229-450b-ad69-76948696e60d'},
    'free_bikes': 4,
    'id': 'ef0c8fb29b82ed7bf6a2b26759c6d65c',
    'latitude': 40.82895,
    'longitude': -73.90521,
    'name': 'E 167 St & Franklin Ave',
    'timestamp': '2023-08-29T15:03:08.799000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 10,
     'has_ebikes': True,
     'last_updated': 1693321282,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '05969d95-8a64-4007-abf1-afb847f2d426'},
    'free_bikes': 14,
    'id': '815b6b1b25d68369bd34f150e6a3854c',
    'latitude': 40.822545,
    'longitude': -73.901824,
    'name': 'E 163 St & Union Ave',
    'timestamp': '2023-08-29T15:03:08.774000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321259,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': 'dfe2c398-ff5c-4a8d-83c8-fa18801540d8'},
    'free_bikes': 15,
    'id': '84b3a53612debeb461de4a703985747e',
    'latitude': 40.840484,
    'longitude': -73.917946,
    'name': 'Plaza Dr & W 170 St',
    'timestamp': '2023-08-29T15:03:08.683000Z'},
   {'empty_slots': 57,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321302,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 79,
     'uid': '66dc7957-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 21,
    'id': '4c020f4fb17b6234df87153d677e9bd6',
    'latitude': 40.73912601,
    'longitude': -73.97973776,
    'name': 'E 25 St & 2 Ave',
    'timestamp': '2023-08-29T15:03:08.552000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '4e747443-d481-4aea-a6d1-cf20204af4ba'},
    'free_bikes': 16,
    'id': '4179c4529740008c41947e647a9c9f51',
    'latitude': 40.838379,
    'longitude': -73.905838,
    'name': 'E 171 St & Webster Ave',
    'timestamp': '2023-08-29T15:03:07.804000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321261,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'd3433b47-99a7-4b21-9fa7-d7052bb5c23b'},
    'free_bikes': 3,
    'id': 'a579c6a8097904660dd5d2894abf4af4',
    'latitude': 40.840683,
    'longitude': -73.915073,
    'name': 'Walton Ave & E 171 St',
    'timestamp': '2023-08-29T15:03:08.652000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321296,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 34,
     'uid': '66dd26f9-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 22,
    'id': '72848b662aae6385dd750ef7aa644ebf',
    'latitude': 40.74966,
    'longitude': -73.9521,
    'name': '9 St & 44 Rd',
    'timestamp': '2023-08-29T15:03:09.169000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '6fd84197-56e2-47df-849f-701aca0e7cc3'},
    'free_bikes': 14,
    'id': '2c9261e7f49293de7c2360ef8d939a17',
    'latitude': 40.83130549267296,
    'longitude': -73.91744792461395,
    'name': 'Sherman Ave & E 166 St',
    'timestamp': '2023-08-29T15:03:09.144000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321303,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'ecbfcdb7-fffc-4d45-bed2-1510fd45834d'},
    'free_bikes': 18,
    'id': 'bc05be112e18306e55314b793b6b162c',
    'latitude': 40.831444,
    'longitude': -73.926226,
    'name': 'Jerome Ave & E 164 St',
    'timestamp': '2023-08-29T15:03:08.952000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321284,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': '655ad2f2-6bcc-4eee-95a9-4f528c0b81cd'},
    'free_bikes': 1,
    'id': '285b8a7624e283226cf8b7f1547bc96f',
    'latitude': 40.78294,
    'longitude': -73.93077,
    'name': 'Wards Meadow Comfort Station',
    'timestamp': '2023-08-29T15:03:09.330000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 11,
     'has_ebikes': True,
     'last_updated': 1693321322,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '461b4f37-c980-4e50-9c92-a6125ce52881'},
    'free_bikes': 16,
    'id': 'f432d2bef9ce1c2ab5e8dd875a8529c0',
    'latitude': 40.79346,
    'longitude': -73.92389,
    'name': 'Icahn Stadium',
    'timestamp': '2023-08-29T15:03:08.502000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321335,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '3db2fa34-0b56-4644-9ae9-bbee1583e717'},
    'free_bikes': 11,
    'id': '7e90a5491bea7bb00bb25036c44c0f29',
    'latitude': 40.80046,
    'longitude': -73.92404,
    'name': 'Bronx Shore Comfort Station',
    'timestamp': '2023-08-29T15:03:08.092000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321262,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': 'b4a320d6-2611-4940-96ca-17fb297ec826'},
    'free_bikes': 18,
    'id': 'f94c608006091d14afc8a771d3362e25',
    'latitude': 40.79558,
    'longitude': -73.91906,
    'name': 'Sunken Meadow Comfort Station',
    'timestamp': '2023-08-29T15:03:08.286000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321288,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'a8560d28-9ee1-4af4-9180-7e9c4dd0d147'},
    'free_bikes': 10,
    'id': 'e5459c377ca23214f7d780514c90613b',
    'latitude': 40.826677,
    'longitude': -73.929327,
    'name': 'E 153 St & E 157 St',
    'timestamp': '2023-08-29T15:03:08.488000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321255,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '0197e9da-ae03-40a7-8270-fe500bfc9e18'},
    'free_bikes': 13,
    'id': '7621c7f870cdd96f3a909da9be523f39',
    'latitude': 40.828199,
    'longitude': -73.903719,
    'name': 'Boston Rd & E 167 St',
    'timestamp': '2023-08-29T15:03:07.968000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321278,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'b7c6ce96-a24d-4c1e-93ee-6f49c1adf119'},
    'free_bikes': 19,
    'id': 'c34a0a3eefad070faeceed7a3d8f2d80',
    'latitude': 40.82809,
    'longitude': -73.91288,
    'name': 'E 165 St & Clay Ave',
    'timestamp': '2023-08-29T15:03:08.634000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321288,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 11,
     'uid': '1057229c-f8f8-4014-80cd-f40421c61cf0'},
    'free_bikes': 12,
    'id': '1ffc249cff29342a164b5808df24160c',
    'latitude': 40.70413,
    'longitude': -73.90737,
    'name': 'Onderdonk Ave & Gates Ave',
    'timestamp': '2023-08-29T15:03:07.822000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321287,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '068b919c-f649-4091-8e12-ccf37191cad5'},
    'free_bikes': 11,
    'id': 'f1ad2d411ca41d27990cc9ba4e8b9a53',
    'latitude': 40.835302,
    'longitude': -73.895133,
    'name': 'Wilkins Ave & Crotona Park E',
    'timestamp': '2023-08-29T15:03:08.925000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321315,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '77a498ea-5693-46cc-a4b1-6e428f574797'},
    'free_bikes': 25,
    'id': '0359e3baa47255485ec2eb5bf9418c1f',
    'latitude': 40.818154,
    'longitude': -73.925294,
    'name': 'E 149 St & Park Ave',
    'timestamp': '2023-08-29T15:03:08.418000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321294,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': 'b4ae292d-5e89-4c58-8154-0496893394b5'},
    'free_bikes': 3,
    'id': '3e5cd35351fe3940e1235f1aff387f27',
    'latitude': 40.83196,
    'longitude': -73.91956,
    'name': 'Grand Concourse & E 166 St',
    'timestamp': '2023-08-29T15:03:08.127000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321294,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': 'facb0195-8daa-46e3-95e1-6f22fb678e8a'},
    'free_bikes': 11,
    'id': '609030c953ea4cfc352ad9bf22f199a5',
    'latitude': 40.831762,
    'longitude': -73.896853,
    'name': 'Prospect Ave & Jennings St',
    'timestamp': '2023-08-29T15:03:07.824000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321252,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '9b4a92ae-cefe-467a-8e35-5ce02d4f3a45'},
    'free_bikes': 14,
    'id': '859cefe1951bdccdfcd1888edcc511bc',
    'latitude': 40.831998,
    'longitude': -73.892686,
    'name': 'Louis Nine Blvd & Intervale Ave',
    'timestamp': '2023-08-29T15:03:08.778000Z'},
   {'empty_slots': 76,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 84,
     'uid': '66dc259a-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 8,
    'id': '26647e48c84f4e48fb8da1fc40697eb2',
    'latitude': 40.73587678,
    'longitude': -73.98205027,
    'name': 'E 20 St & 2 Ave',
    'timestamp': '2023-08-29T15:03:08.518000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 13,
     'has_ebikes': True,
     'last_updated': 1693321295,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 69,
     'uid': '66db33fc-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 63,
    'id': '3235cbacd9cbd52957594657c6d4161c',
    'latitude': 40.73971301,
    'longitude': -73.99456405,
    'name': 'W 18 St & 6 Ave',
    'timestamp': '2023-08-29T15:03:09.252000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321326,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'a3e2b360-f050-48ea-b8c8-57d897b8f7fc'},
    'free_bikes': 4,
    'id': 'e17c12d12f92938ae7eefd3c06ab68d5',
    'latitude': 40.70577,
    'longitude': -73.91292,
    'name': 'Harman St & Seneca Ave',
    'timestamp': '2023-08-29T15:03:08.636000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321295,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '89171660-8cef-443f-8f75-67503532d1ce'},
    'free_bikes': 3,
    'id': 'c88839fa370beb7ce3a2bc5e1a9d6ed5',
    'latitude': 40.824811,
    'longitude': -73.916407,
    'name': 'E 161 St & Park Ave',
    'timestamp': '2023-08-29T15:03:08.942000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321251,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 18,
     'uid': 'ba7bf20d-b6bc-43dd-bf30-acb940eaeec8'},
    'free_bikes': 6,
    'id': 'bcc6925828e062deb1be8df10545a6bb',
    'latitude': 40.838706,
    'longitude': -73.927034,
    'name': 'University Ave & W 168 St',
    'timestamp': '2023-08-29T15:03:08.590000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321293,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '7d9a1b9e-0123-4561-a111-b3735fada687'},
    'free_bikes': 8,
    'id': 'b14edc1ece9991f3a55c449c06603703',
    'latitude': 40.837213,
    'longitude': -73.908345,
    'name': 'E 170 St & Clay Ave',
    'timestamp': '2023-08-29T15:03:08.377000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321276,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'ab29ce96-c2e8-4929-b27b-e0fe4aae17d5'},
    'free_bikes': 18,
    'id': '3ea0bf9dd10e24632d5bc6b1fa7c9a97',
    'latitude': 40.828975,
    'longitude': -73.911259,
    'name': 'Webster Ave & E 166 St',
    'timestamp': '2023-08-29T15:03:08.573000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321296,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'fec4aa1b-9fc1-4dd9-ab39-c1d7370a6e54'},
    'free_bikes': 12,
    'id': '66106c98d0e56bbb0e4b738f22828e27',
    'latitude': 40.813991,
    'longitude': -73.8855,
    'name': 'Hunts Point Ave & Bryant Ave',
    'timestamp': '2023-08-29T15:03:09.316000Z'},
   {'empty_slots': 23,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321337,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': 'cbf76774-1276-4cf8-9442-f00571f1451c'},
    'free_bikes': 9,
    'id': '123338b34eddfe0824668b056d4294db',
    'latitude': 40.696232971293156,
    'longitude': -73.99142056703568,
    'name': 'Clinton St & Tillary St',
    'timestamp': '2023-08-29T15:03:07.970000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321255,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'fea72f55-d296-47af-9446-149688dcccbd'},
    'free_bikes': 9,
    'id': 'b12447acff7f0f3e36207b607b345288',
    'latitude': 40.83171,
    'longitude': -73.90208,
    'name': 'Franklin Ave & E 169 St',
    'timestamp': '2023-08-29T15:03:08.848000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321260,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '6fab98b7-b06a-49d8-a4d1-087ffce0ebcf'},
    'free_bikes': 7,
    'id': '75bc9a899c6aa8806a0a85b4bfb31f3f',
    'latitude': 40.833246,
    'longitude': -73.896599,
    'name': 'Boston Rd & Prospect Ave',
    'timestamp': '2023-08-29T15:03:08.928000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321228,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '039d4cc9-8560-4d22-88c3-20753c54a50f'},
    'free_bikes': 19,
    'id': '50596ad6364c301a728c2d46ecac7b2d',
    'latitude': 40.823872,
    'longitude': -73.908699,
    'name': '3 Ave & E 163 St',
    'timestamp': '2023-08-29T15:03:08.362000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321266,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '1f088432-0460-421e-a1d9-36890fa5396d'},
    'free_bikes': 11,
    'id': 'd46e87a213cb984bf70f4cb629aa5923',
    'latitude': 40.816126,
    'longitude': -73.891559,
    'name': 'Barry St & Tiffany St',
    'timestamp': '2023-08-29T15:03:08.749000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321259,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '93c28953-7e65-436e-9c5a-9d7ca0e3729f'},
    'free_bikes': 1,
    'id': '78466b7e0be084d30c6015c3e9b5374c',
    'latitude': 40.747573958954796,
    'longitude': -73.9788007736206,
    'name': 'Lexington Ave & E 36 St',
    'timestamp': '2023-08-29T15:03:09.105000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321267,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '141eb0e0-e78d-411a-a0be-202a6424cc93'},
    'free_bikes': 22,
    'id': '679c972b0ac6aefc3cb1c665cfee00c9',
    'latitude': 40.822217,
    'longitude': -73.928939,
    'name': 'River Ave & E 151 St',
    'timestamp': '2023-08-29T15:03:08.310000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321290,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'bb58e953-4953-4fbe-9ef2-367488dfef9b'},
    'free_bikes': 18,
    'id': '8404f4c189220e7ac2c3aa857b33178f',
    'latitude': 40.824,
    'longitude': -73.91089,
    'name': 'Washington Ave & E 163 St',
    'timestamp': '2023-08-29T15:03:07.861000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321239,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'f91170e6-a33c-4870-94da-9d51510515d2'},
    'free_bikes': 0,
    'id': 'c19e42eadd30100b2efed123e157f298',
    'latitude': 40.826303,
    'longitude': -73.898751,
    'name': 'Prospect Ave & E 167 St',
    'timestamp': '2023-08-29T15:03:07.938000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321289,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '9af90faf-0b9b-451b-9cb0-20ff421ca1d9'},
    'free_bikes': 6,
    'id': 'd37b0302fa765534a7d73a29fdfbed4b',
    'latitude': 40.82394,
    'longitude': -73.894025,
    'name': 'E 165 St & Fox St',
    'timestamp': '2023-08-29T15:03:07.761000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321322,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '55146e49-9bc4-4f13-bdf7-25422342b638'},
    'free_bikes': 1,
    'id': '89c8a5327c7bf25d87d8b2dd3598754e',
    'latitude': 40.839194,
    'longitude': -73.888587,
    'name': 'Waterloo Pl & Crotona Park East',
    'timestamp': '2023-08-29T15:03:07.913000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321329,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '426862de-f8f2-4967-ba41-76680a4b460c'},
    'free_bikes': 7,
    'id': '9ffcd62c25d46a8e6288c61b9fa5ed7e',
    'latitude': 40.837037,
    'longitude': -73.890413,
    'name': 'Crotona Park East & E 173 St',
    'timestamp': '2023-08-29T15:03:08.034000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321304,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '82dd89f6-1e5a-4a8f-8660-13cb64349e94'},
    'free_bikes': 17,
    'id': '20dddc3f105234a7ceb7b1555253f9c9',
    'latitude': 40.832649,
    'longitude': -73.885272,
    'name': 'Boone Ave & E 172 St',
    'timestamp': '2023-08-29T15:03:07.884000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 28,
     'has_ebikes': True,
     'last_updated': 1693321338,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 96,
     'uid': '66db5fae-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 71,
    'id': '0eef504b5774d2a330442e1e6f0414c8',
    'latitude': 40.7643971,
    'longitude': -73.97371465,
    'name': 'Grand Army Plaza & Central Park S',
    'timestamp': '2023-08-29T15:03:07.962000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321316,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '44c23eaa-7ddf-40b3-8373-6f3880c5e1b1'},
    'free_bikes': 14,
    'id': '68940ab808000399f04aa5d6453e5afc',
    'latitude': 40.843079,
    'longitude': -73.900216,
    'name': 'Washington Ave & E 174 St',
    'timestamp': '2023-08-29T15:03:08.896000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321334,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 39,
     'uid': '66de44ba-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 33,
    'id': 'fc271da0e69a16c52ab27f8c168a6b37',
    'latitude': 40.6830456,
    'longitude': -74.00348559,
    'name': 'Carroll St & Columbia St',
    'timestamp': '2023-08-29T15:03:08.023000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321275,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '66dbc7d2-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 13,
    'id': '403c392bf680dd8abc82b43f51572713',
    'latitude': 40.71622644,
    'longitude': -73.98261206,
    'name': 'Bialystoker Pl & Delancey St',
    'timestamp': '2023-08-29T15:03:08.930000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321326,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '943be327-0320-4ae1-8eb0-8a56f86a4fb6'},
    'free_bikes': 24,
    'id': '540091527688a9e68bc468e0c971d6cc',
    'latitude': 40.823061,
    'longitude': -73.941928,
    'name': 'Frederick Douglass Blvd & W 145 St',
    'timestamp': '2023-08-29T15:03:08.669000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321255,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '9790606b-a00d-4d5e-b6ec-abd11c9d25b3'},
    'free_bikes': 8,
    'id': '1b800b28d1b36340f6e68813fd284d27',
    'latitude': 40.8358771,
    'longitude': -73.8931428,
    'name': 'Charlotte St & Boston Rd',
    'timestamp': '2023-08-29T15:03:09.030000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321283,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'b9970fb5-176c-4a66-8772-6d76c4b6245a'},
    'free_bikes': 2,
    'id': '1b4baab0056562152c1599d45e3335f0',
    'latitude': 40.839335,
    'longitude': -73.886445,
    'name': 'Southern Blvd & E 175 St',
    'timestamp': '2023-08-29T15:03:09.118000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321250,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 22,
     'uid': '90b141b9-c39f-4a26-a32d-08c7d1474d52'},
    'free_bikes': 2,
    'id': '3e3258a9e5393e6b4bcda20ca62376d8',
    'latitude': 40.816567,
    'longitude': -73.888161,
    'name': 'Lafayette Ave & Hunts Point Ave',
    'timestamp': '2023-08-29T15:03:08.745000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 44,
     'has_ebikes': True,
     'last_updated': 1693321337,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 81,
     'uid': '66dc7b10-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 77,
    'id': '7d96bf47b87370da4c1d7dd2b9cc0c2d',
    'latitude': 40.7606597,
    'longitude': -73.98042047,
    'name': 'W 51 St & 6 Ave',
    'timestamp': '2023-08-29T15:03:09.335000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321308,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': 'cb4926e6-0a79-4902-80ee-d365fbf42aec'},
    'free_bikes': 7,
    'id': '126b7d05d7960c82f656c78707771ff0',
    'latitude': 40.840494,
    'longitude': -73.911479,
    'name': 'Sheridan Ave & E 172 St',
    'timestamp': '2023-08-29T15:03:08.574000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321329,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '81a34754-ae08-47a6-964d-4733849a8fab'},
    'free_bikes': 25,
    'id': 'd1fbd6a3ad6dc066d07cfbe81f823da2',
    'latitude': 40.818743,
    'longitude': -73.890247,
    'name': 'Garrison Ave & Manida St',
    'timestamp': '2023-08-29T15:03:09.156000Z'},
   {'empty_slots': 36,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321227,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 61,
     'uid': '66db8ca4-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 24,
    'id': 'bd19161058cb9f95e61a05708d0f83f8',
    'latitude': 40.72953837,
    'longitude': -73.98426726,
    'name': 'E 11 St & 1 Ave',
    'timestamp': '2023-08-29T15:03:09.012000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321330,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': 'c4d6b123-df5a-446d-b0ae-d3c4846565d5'},
    'free_bikes': 15,
    'id': 'd7d6aad1f9573bd930267222cc51ad00',
    'latitude': 40.83617913677475,
    'longitude': -73.90730146322765,
    'name': 'E 170 St & Webster Ave',
    'timestamp': '2023-08-29T15:03:09.198000Z'},
   {'empty_slots': 54,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321321,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 66,
     'uid': '99d149f9-ad40-461e-beea-fcbf086f9b5a'},
    'free_bikes': 11,
    'id': '74181cfa0669cabb339792d84b2dccb9',
    'latitude': 40.72746420692392,
    'longitude': -73.97950418293476,
    'name': 'E 11 St & Avenue B',
    'timestamp': '2023-08-29T15:03:09.113000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321288,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '4aa6bb27-b76b-444e-a3ce-6fb25b822494'},
    'free_bikes': 9,
    'id': '8902018d8d3bd83337c447004f3e7dc0',
    'latitude': 40.832164,
    'longitude': -73.949702,
    'name': 'Riverside Dr & W 153 St',
    'timestamp': '2023-08-29T15:03:07.831000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321232,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '2a66ed0a-5e6d-4893-a1d1-876bb2bac4be'},
    'free_bikes': 9,
    'id': 'd4194ca1de3dcfe0b4bae22a28d7f53f',
    'latitude': 40.844811,
    'longitude': -73.912042,
    'name': 'E 174 St & Walton Ave',
    'timestamp': '2023-08-29T15:03:08.718000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321279,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '1e6c5d0c-f406-4b60-88f6-6284a38d3930'},
    'free_bikes': 9,
    'id': '1893182f1749443fa887a5e5833cfc94',
    'latitude': 40.839229,
    'longitude': -73.899047,
    'name': 'Fulton Ave & E 172 St',
    'timestamp': '2023-08-29T15:03:08.741000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321217,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '7938263e-e5b8-4ca7-b8bf-1adbaae5fead'},
    'free_bikes': 11,
    'id': '81086b8a7cf19759b4038a647e4921bf',
    'latitude': 40.811892,
    'longitude': -73.904192,
    'name': 'Southern Blvd & E 149 St',
    'timestamp': '2023-08-29T15:03:08.664000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 11,
     'has_ebikes': True,
     'last_updated': 1693321325,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 58,
     'uid': '66de1bc3-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 39,
    'id': '9901bed45d6a567441d9da5738cb195d',
    'latitude': 40.7691572,
    'longitude': -73.96703464,
    'name': 'E 68 St & Madison Ave',
    'timestamp': '2023-08-29T15:03:07.973000Z'},
   {'empty_slots': 24,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321239,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 36,
     'uid': '66dd3d7f-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 11,
    'id': '9009763d6496a22bc2c997f814fcf045',
    'latitude': 40.76712840349542,
    'longitude': -73.96224617958069,
    'name': 'E 68 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:08.431000Z'},
   {'empty_slots': 38,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321331,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 57,
     'uid': '199ea9dd-8f7e-4e05-a730-55edaacd8787'},
    'free_bikes': 16,
    'id': 'b5237f73f14d31cd67a37c5524f91a65',
    'latitude': 40.763954,
    'longitude': -73.9646,
    'name': 'E 63 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:08.390000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321267,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '66de0a78-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 16,
    'id': 'ae24ee4f57686e255f3357e47f1cfb3d',
    'latitude': 40.6725058,
    'longitude': -74.00494695,
    'name': 'Henry St & Bay St',
    'timestamp': '2023-08-29T15:03:08.103000Z'},
   {'empty_slots': 23,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321240,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '66dd45c7-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 2,
    'id': 'f8b59837ed7104dd6ec101d925ed03b8',
    'latitude': 40.77565541,
    'longitude': -73.95068615,
    'name': 'E 84 St & 1 Ave',
    'timestamp': '2023-08-29T15:03:09.181000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321300,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '387e2863-83ad-4589-8004-794a7b624801'},
    'free_bikes': 3,
    'id': 'e4fc92640874c6d2c7f32931de569bcd',
    'latitude': 40.774591,
    'longitude': -73.918544,
    'name': '24 Ave & 26 St',
    'timestamp': '2023-08-29T15:03:07.947000Z'},
   {'empty_slots': 27,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321288,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 59,
     'uid': '1f872052-38c4-4701-96c4-c363de51c2b5'},
    'free_bikes': 22,
    'id': 'abdcdbcf1151ca310c2178cca9324b94',
    'latitude': 40.768333,
    'longitude': -73.992573,
    'name': 'W 54 St & 11 Ave',
    'timestamp': '2023-08-29T15:03:07.983000Z'},
   {'empty_slots': 72,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321334,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 79,
     'uid': '2c321ea3-e1dd-4d32-be70-bd158fe1f568'},
    'free_bikes': 1,
    'id': 'edb4bf0bc9b428451a329ae665584805',
    'latitude': 40.762009,
    'longitude': -73.996975,
    'name': 'W 44 St & 11 Ave',
    'timestamp': '2023-08-29T15:03:08.779000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321310,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'c0c6a931-c1d3-4202-a433-c4127a4cd846'},
    'free_bikes': 7,
    'id': '51e298f399fe3bb0ddd0054c90156e86',
    'latitude': 40.824956,
    'longitude': -73.891677,
    'name': 'Westchester Ave & Southern Blvd',
    'timestamp': '2023-08-29T15:03:08.899000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321248,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'c602146e-d69d-43b6-9e8f-054c4df5377e'},
    'free_bikes': 2,
    'id': '3d17da6f50dfb86af3779f4709189abd',
    'latitude': 40.81872569990116,
    'longitude': -73.88862490653992,
    'name': 'Seneca Ave & Irvine St',
    'timestamp': '2023-08-29T15:03:08.627000Z'},
   {'empty_slots': 46,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321281,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 50,
     'uid': '66dbecd0-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 1,
    'id': '02c41dad36a8b93e2b1c99e55e460703',
    'latitude': 40.72521311,
    'longitude': -73.97768752,
    'name': 'E 9 St & Avenue C',
    'timestamp': '2023-08-29T15:03:08.827000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 14,
     'has_ebikes': True,
     'last_updated': 1693321319,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 93,
     'uid': 'ff2869f0-4381-4cf3-863e-a0d776ec53b4'},
    'free_bikes': 72,
    'id': 'f8749f39ecf3a3b876af8291112bd1b8',
    'latitude': 40.70336686695866,
    'longitude': -74.007867872715,
    'name': 'Old Slip & South St',
    'timestamp': '2023-08-29T15:03:08.584000Z'},
   {'empty_slots': 41,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321289,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 79,
     'uid': '66dc8a3d-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 35,
    'id': '82c95fccd83d2b95126aebe558e4fffe',
    'latitude': 40.74025878,
    'longitude': -73.98409214,
    'name': 'Lexington Ave & E 24 St',
    'timestamp': '2023-08-29T15:03:08.199000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321336,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 42,
     'uid': '0c923abb-298a-4a47-b132-9fae73cc59e6'},
    'free_bikes': 39,
    'id': 'cc30dff379477641f49e0ce34474aeec',
    'latitude': 40.74005708567285,
    'longitude': -74.0052741765976,
    'name': 'Hudson St & W 13 St',
    'timestamp': '2023-08-29T15:03:07.820000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 5,
     'has_ebikes': True,
     'last_updated': 1693321337,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 73,
     'uid': '66dbcbbc-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 61,
    'id': 'b4d730fd6a9238ffa183bd5e7efcc807',
    'latitude': 40.70834698,
    'longitude': -74.01713445,
    'name': 'West Thames St',
    'timestamp': '2023-08-29T15:03:07.933000Z'},
   {'empty_slots': 45,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321289,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 95,
     'uid': '66db76a1-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 48,
    'id': '707f06d68130f07c41591c107a02ba36',
    'latitude': 40.72453734,
    'longitude': -73.98185424,
    'name': 'E 6 St & Avenue B',
    'timestamp': '2023-08-29T15:03:08.182000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 52,
     'uid': '66db3aa3-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 41,
    'id': 'e18cbef0188beb59e10d3d4d867067bd',
    'latitude': 40.69597683,
    'longitude': -73.99014892,
    'name': 'Cadman Plaza E & Tillary St',
    'timestamp': '2023-08-29T15:03:09.074000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321226,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 43,
     'uid': '33c533cd-5f0e-4c15-a00a-6a2bf1e2d077'},
    'free_bikes': 41,
    'id': '43828393c477c196592743dd7eca394c',
    'latitude': 40.72583996792375,
    'longitude': -74.0076532959938,
    'name': 'Spring St & Hudson St',
    'timestamp': '2023-08-29T15:03:08.570000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321310,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 61,
     'uid': 'b6a4770e-9077-4a0e-a0fb-b45b1d457559'},
    'free_bikes': 41,
    'id': 'f275ff49c30c175683e23f81dd77c626',
    'latitude': 40.72840059450829,
    'longitude': -73.99968780577183,
    'name': 'Thompson St & Bleecker St',
    'timestamp': '2023-08-29T15:03:09.258000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321296,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '77e31650-e86a-4b06-b2de-b92df2a7a7f5'},
    'free_bikes': 20,
    'id': '6992a33fd7c2545bc6caeaed5031e46b',
    'latitude': 40.76535380385866,
    'longitude': -73.93986314535141,
    'name': '34th Ave & Vernon Blvd',
    'timestamp': '2023-08-29T15:03:09.051000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321281,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 68,
     'uid': 'a19d37cc-6070-4e4c-b4ad-3ee21e4a11cb'},
    'free_bikes': 45,
    'id': 'e5e0c8b1300dfcad64c11d9cd1fb41d4',
    'latitude': 40.73342399437081,
    'longitude': -74.00851495563984,
    'name': 'W 10 St & Washington St',
    'timestamp': '2023-08-29T15:03:08.825000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321307,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'b64eb0a5-d6d4-4f45-8c9a-e2d004819c99'},
    'free_bikes': 6,
    'id': 'b5b45297e6220215795f1845c6e96d2a',
    'latitude': 40.759604471387945,
    'longitude': -73.92714411020279,
    'name': '34 Ave & 31 St',
    'timestamp': '2023-08-29T15:03:09.268000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321319,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '45865207-8700-4ef2-99ed-b08889ef0250'},
    'free_bikes': 5,
    'id': '27a6b95f8cd1c450fa3c0a0e8dd73427',
    'latitude': 40.772768286288304,
    'longitude': -73.92743647098541,
    'name': '18 St & 27 Ave',
    'timestamp': '2023-08-29T15:03:09.142000Z'},
   {'empty_slots': 25,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321220,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 57,
     'uid': '4e862dc1-0652-4f29-a26f-315d763df67d'},
    'free_bikes': 24,
    'id': 'ce3f685a607abba0008a1cdefd6e01ff',
    'latitude': 40.73191132323174,
    'longitude': -74.008769094944,
    'name': 'Washington St & Barrow St',
    'timestamp': '2023-08-29T15:03:08.477000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321227,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'e152a2e1-c510-404e-a100-24246bb6cc95'},
    'free_bikes': 9,
    'id': 'a506b769f792329094cf33580e355f46',
    'latitude': 40.7725996921817,
    'longitude': -73.93266275525093,
    'name': '8 St & Astoria Blvd',
    'timestamp': '2023-08-29T15:03:08.142000Z'},
   {'empty_slots': 36,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321329,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 41,
     'uid': '0138452a-b9f4-4aee-80b0-7fae9a122ffe'},
    'free_bikes': 3,
    'id': '88f1c034f2b7c250ea1a3ee8f2a5a54c',
    'latitude': 40.756265,
    'longitude': -73.964179,
    'name': 'E 54 St & 1 Ave',
    'timestamp': '2023-08-29T15:03:08.788000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 16,
     'has_ebikes': True,
     'last_updated': 1693321311,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '82c85f05-4722-48ae-9f64-0522012eb3c8'},
    'free_bikes': 21,
    'id': '0549d72407dd6bd460a627c469a106d3',
    'latitude': 40.836733,
    'longitude': -73.887931,
    'name': 'Southern Blvd & E 174 St',
    'timestamp': '2023-08-29T15:03:07.894000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321279,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '067d5007-bda5-4697-b0a2-ccc2837f295c'},
    'free_bikes': 19,
    'id': '84cfa7d3dd184797fa540f1ecc3778d0',
    'latitude': 40.756351,
    'longitude': -73.936515,
    'name': '24 St & 38 Ave',
    'timestamp': '2023-08-29T15:03:08.213000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 11,
     'has_ebikes': True,
     'last_updated': 1693321312,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '83a5d761-57d0-4cd6-aa2b-7eb350120d99'},
    'free_bikes': 13,
    'id': '0e244de03bb280f8d02d09c58fd22814',
    'latitude': 40.827629,
    'longitude': -73.886659,
    'name': 'Home St & Westchester Ave',
    'timestamp': '2023-08-29T15:03:08.280000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321286,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'f3140fb8-347b-4dca-96df-eeef2d1bfc50'},
    'free_bikes': 5,
    'id': '2e69b7f6729c08ce99df4308fa02cc2c',
    'latitude': 40.827230499624726,
    'longitude': -73.91765579597632,
    'name': 'Morris Ave & E 163 St',
    'timestamp': '2023-08-29T15:03:08.970000Z'},
   {'empty_slots': 28,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321229,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': '0de1f95f-8b1b-4e5e-9eff-73c63265b0ab'},
    'free_bikes': 0,
    'id': '56cce545e819e753948d38fa46051a4b',
    'latitude': 40.76547569244953,
    'longitude': -73.91811579465866,
    'name': '35 St & 30 Ave',
    'timestamp': '2023-08-29T15:03:08.226000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 9,
     'has_ebikes': True,
     'last_updated': 1693321292,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 32,
     'uid': '0f98907a-d4cc-45e0-b174-7d9dfda74106'},
    'free_bikes': 24,
    'id': '743e20d43f56b3cf710087c4df73cb90',
    'latitude': 40.75905795418586,
    'longitude': -73.91897544264793,
    'name': 'Steinway St & Broadway',
    'timestamp': '2023-08-29T15:03:08.098000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321304,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '4e1a13af-1c3b-48f2-8586-5edceea97d61'},
    'free_bikes': 15,
    'id': 'edb559c2dec76ecc0e802cfeb3856b1f',
    'latitude': 40.83670566862804,
    'longitude': -73.92608866095543,
    'name': 'Nelson Ave & 167 St',
    'timestamp': '2023-08-29T15:03:08.541000Z'},
   {'empty_slots': 23,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321276,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': 'a381b37a-a928-4834-87ee-da9922cb3b3d'},
    'free_bikes': 6,
    'id': '50e3826db7b729e12278f38cdaa53bc5',
    'latitude': 40.77977,
    'longitude': -73.923162,
    'name': 'Shore Blvd & Astoria Park',
    'timestamp': '2023-08-29T15:03:09.022000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 26,
     'has_ebikes': True,
     'last_updated': 1693321332,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 49,
     'uid': '1e226f22-034f-4b99-8184-a8eaa591fbd8'},
    'free_bikes': 47,
    'id': '8e8703fdcbc21e79d9d6ef988e0acb80',
    'latitude': 40.752643,
    'longitude': -73.974996,
    'name': 'E 44 St & Lexington Ave',
    'timestamp': '2023-08-29T15:03:08.709000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 9,
     'has_ebikes': True,
     'last_updated': 1693321267,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 69,
     'uid': 'e6c2a46e-431a-4101-af84-870f660ff4cb'},
    'free_bikes': 56,
    'id': 'e0a9acfb2284b446b096f3ba8be9c7e5',
    'latitude': 40.74275179648995,
    'longitude': -73.9847157150507,
    'name': 'E 27 St & Park Ave S',
    'timestamp': '2023-08-29T15:03:08.190000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321314,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': '66dc7c31-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 4,
    'id': 'f64c060aad3a6ed470ee3f04583cdfa3',
    'latitude': 40.7500727,
    'longitude': -73.99839279,
    'name': 'W 29 St & 9 Ave',
    'timestamp': '2023-08-29T15:03:08.126000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321334,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'c80c55c4-d623-42d7-8acf-6bfa68a84ecb'},
    'free_bikes': 5,
    'id': '76d90ebcca4d0bf5c61394fded8fbc0e',
    'latitude': 40.832678,
    'longitude': -73.905158,
    'name': '3 Ave & E 169 St',
    'timestamp': '2023-08-29T15:03:08.994000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321332,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '4223f276-a4d4-45e0-b914-67f5ef1e81ba'},
    'free_bikes': 8,
    'id': '516afd055f8e784cd0217e07df21589d',
    'latitude': 40.752443,
    'longitude': -73.929737,
    'name': '34 St & 38 Ave',
    'timestamp': '2023-08-29T15:03:08.842000Z'},
   {'empty_slots': 24,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321314,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': 'e3e6105e-eaa2-43c5-badb-fb8592ad7227'},
    'free_bikes': 0,
    'id': '21ce1930f04b1b5d97bcf987aad15423',
    'latitude': 40.754139,
    'longitude': -73.919543,
    'name': '43 St & 35 Ave',
    'timestamp': '2023-08-29T15:03:08.333000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321269,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '61be9a4a-737c-413a-9b72-d47b28a366d5'},
    'free_bikes': 5,
    'id': '2423b332b9b3e8842ffadfbba7c93923',
    'latitude': 40.752372,
    'longitude': -73.925384,
    'name': '38 St & Northern Blvd',
    'timestamp': '2023-08-29T15:03:08.005000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321307,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '2743a950-3a1f-4a58-8fe0-f4105033e0e3'},
    'free_bikes': 4,
    'id': '4a7667bbf319714c3a3b665085ae5b16',
    'latitude': 40.763422,
    'longitude': -73.914142,
    'name': '30 Ave & 41 St',
    'timestamp': '2023-08-29T15:03:08.892000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321252,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '9719498d-bd5c-4424-86ac-dfe0795c57d1'},
    'free_bikes': 2,
    'id': '7f7a926b828a7307c98138b30b6cee01',
    'latitude': 40.754795,
    'longitude': -73.917014,
    'name': '34 Ave & 45 St',
    'timestamp': '2023-08-29T15:03:09.178000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321282,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '398aa734-3893-4dba-a704-57ae8632c4f9'},
    'free_bikes': 1,
    'id': 'eb8c17fb0fc05d3fb99c611167feae7d',
    'latitude': 40.761294,
    'longitude': -73.909562,
    'name': '30 Ave & 47 St',
    'timestamp': '2023-08-29T15:03:07.747000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321230,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '6a671276-d345-4a4c-a7df-98f5dbb19e4c'},
    'free_bikes': 4,
    'id': 'ba40eb4b37cbb1c6b33a1ca08851d900',
    'latitude': 40.750181,
    'longitude': -73.919998,
    'name': '43 St & 37 Ave',
    'timestamp': '2023-08-29T15:03:08.662000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321322,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': 'f3f46097-54cf-4c30-805a-6b2a4851eed7'},
    'free_bikes': 3,
    'id': 'd1869103950fed1e8dd6bbf51a3a64c2',
    'latitude': 40.765753,
    'longitude': -73.90676,
    'name': '46 St & 25 Ave',
    'timestamp': '2023-08-29T15:03:08.229000Z'},
   {'empty_slots': 22,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321301,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '7a725e59-49be-4c1d-9c3d-3b3a8ed1232f'},
    'free_bikes': 1,
    'id': 'fe9ebb874e7c965a962cd95ab1e067a8',
    'latitude': 40.760083,
    'longitude': -73.907107,
    'name': '50 St & 30 Ave',
    'timestamp': '2023-08-29T15:03:08.494000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321265,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '5a6218aa-c5b7-4436-93c1-dee7cb5322d9'},
    'free_bikes': 13,
    'id': 'f3e02a990584cbee72647b1088d67296',
    'latitude': 40.75388,
    'longitude': -73.914952,
    'name': '34 Ave & 48 St',
    'timestamp': '2023-08-29T15:03:08.099000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'c7be2714-14db-421f-a19e-f6a7bf6e8d26'},
    'free_bikes': 2,
    'id': '9c0738b4900353c7778a4c928c13e498',
    'latitude': 40.767666,
    'longitude': -73.910963,
    'name': '25 Ave & 41 St',
    'timestamp': '2023-08-29T15:03:08.203000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321336,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': 'cd5e7c3e-c618-416a-ae99-b509bd56e1b2'},
    'free_bikes': 14,
    'id': 'e5cf2f49dbcffcff6d3108f4336677ba',
    'latitude': 40.755763,
    'longitude': -73.912715,
    'name': '48 St & Broadway',
    'timestamp': '2023-08-29T15:03:08.265000Z'},
   {'empty_slots': 9,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321218,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '901ad0c4-383e-490a-8b54-0656ce2358d6'},
    'free_bikes': 9,
    'id': '01b08d95d5980014234b0647fcce591a',
    'latitude': 40.762507,
    'longitude': -73.902534,
    'name': 'Bulova Ave & Brooklyn Queens Expressway W',
    'timestamp': '2023-08-29T15:03:08.501000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321314,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': 'c56739c2-b310-4d73-ab0e-b6036abd9561'},
    'free_bikes': 16,
    'id': '162c15bd63401c838fbd81de82f556e5',
    'latitude': 40.755389,
    'longitude': -73.911517,
    'name': 'Broadway & 49 St',
    'timestamp': '2023-08-29T15:03:07.992000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': 'e6a32ec8-fc8b-4ed6-93a2-3ace3921b89d'},
    'free_bikes': 15,
    'id': '8228063def7901d503c1345cee7e969b',
    'latitude': 40.753441,
    'longitude': -73.912402,
    'name': '50 St & Northern Blvd',
    'timestamp': '2023-08-29T15:03:08.576000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321257,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '499e10ad-c008-461e-8cf7-20757218a9cc'},
    'free_bikes': 16,
    'id': 'ad4c20d69edd53cfe5ca4c03712b3584',
    'latitude': 40.757357,
    'longitude': -73.904726,
    'name': '31 Ave & 57 St',
    'timestamp': '2023-08-29T15:03:08.978000Z'},
   {'empty_slots': 4,
    'extra': {'ebikes': 4,
     'has_ebikes': True,
     'last_updated': 1693321287,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '05b9e7cd-f3a2-4d48-b7c4-f5fbe09d9de3'},
    'free_bikes': 21,
    'id': '44fad9aa648f78a98b5bfc440f9ed263',
    'latitude': 40.754164,
    'longitude': -73.908906,
    'name': 'Broadway & 51 St',
    'timestamp': '2023-08-29T15:03:08.422000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 7,
     'has_ebikes': True,
     'last_updated': 1693321299,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'd7bdc3d7-6e6d-4899-9cc7-f4238a86c695'},
    'free_bikes': 10,
    'id': '71027abe941922b1e018d70f6cfa222c',
    'latitude': 40.769673,
    'longitude': -73.906018,
    'name': '43 St & 23 Ave',
    'timestamp': '2023-08-29T15:03:07.955000Z'},
   {'empty_slots': 27,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321223,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 32,
     'uid': '66ddede1-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 3,
    'id': 'f055da17e830624c9e27580e930309b7',
    'latitude': 40.7937704,
    'longitude': -73.971888,
    'name': 'W 95 St & Broadway',
    'timestamp': '2023-08-29T15:03:07.852000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321308,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': 'bbaae5d3-7e2b-46a8-872e-152404c664f7'},
    'free_bikes': 7,
    'id': '596c72528d7da0222a0ef4e822bbd6b5',
    'latitude': 40.754176,
    'longitude': -73.900318,
    'name': '62 St & Northern Blvd',
    'timestamp': '2023-08-29T15:03:08.576000Z'},
   {'empty_slots': 39,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321273,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 41,
     'uid': '3ac7b47b-2253-4a0b-bf7d-8a2eb6b78a38'},
    'free_bikes': 1,
    'id': 'de8a1f7039afb814db478f2d2127959a',
    'latitude': 40.727243,
    'longitude': -73.976831,
    'name': 'E 12 St & Ave C',
    'timestamp': '2023-08-29T15:03:08.731000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '160e21da-6dd2-47ff-8385-e13c8cdce4fa'},
    'free_bikes': 19,
    'id': '245cdd0cec69df88bcfd6d4918d3769a',
    'latitude': 40.646377,
    'longitude': -74.023087,
    'name': '57 St & 1 Ave',
    'timestamp': '2023-08-29T15:03:08.783000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321295,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'f62526d4-9c6a-4c76-be76-c64b5be669d2'},
    'free_bikes': 11,
    'id': '81241ccaf5c459e5992254d50c14e43a',
    'latitude': 40.772717,
    'longitude': -73.906127,
    'name': 'Steinway St & Ditmars Blvd',
    'timestamp': '2023-08-29T15:03:09.195000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 35,
     'uid': '3013d5ac-f7bb-4e98-a49a-b9f7b76a3b50'},
    'free_bikes': 34,
    'id': '60786d71b624ed5275879ca5723c74ce',
    'latitude': 40.644512,
    'longitude': -74.021506,
    'name': '58 St & 2 Ave',
    'timestamp': '2023-08-29T15:03:08.174000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '76c1ef9c-3984-4b4e-bff4-5c398e2395bd'},
    'free_bikes': 12,
    'id': '2f19fed362b1b979fdaae809c504d28a',
    'latitude': 40.774306,
    'longitude': -73.908335,
    'name': '36 St & Ditmars Blvd',
    'timestamp': '2023-08-29T15:03:09.098000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321272,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '330ee4e3-29cb-48e5-845f-a8ccf1aa2ce6'},
    'free_bikes': 6,
    'id': 'd80981905a4f312302c6233218adb4e9',
    'latitude': 40.771203,
    'longitude': -73.903865,
    'name': 'Ditmars Blvd & 43 St',
    'timestamp': '2023-08-29T15:03:09.130000Z'},
   {'empty_slots': 14,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321315,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'dcdaa64b-4d2c-4017-bfb9-da25924f851d'},
    'free_bikes': 6,
    'id': 'dd73d704e59dd96b69384490a140d1a2',
    'latitude': 40.774798,
    'longitude': -73.903787,
    'name': 'Steinway St & 21 Ave',
    'timestamp': '2023-08-29T15:03:09.267000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '7a8bf573-275f-41d5-ad8b-1ff9ee7c2dce'},
    'free_bikes': 17,
    'id': '76c3edbb0321436e5fcab1e57763e3c2',
    'latitude': 40.77813,
    'longitude': -73.90842,
    'name': '31 St & 21 Ave',
    'timestamp': '2023-08-29T15:03:07.862000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321307,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'a70b26b7-fbad-4787-bf15-29f7b13a19ab'},
    'free_bikes': 11,
    'id': '55b3b9cc0bdd565520cac086a1f20e0e',
    'latitude': 40.783956,
    'longitude': -73.916894,
    'name': '21 Ave & Shore Blvd',
    'timestamp': '2023-08-29T15:03:07.972000Z'},
   {'empty_slots': 20,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321240,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '8c6cba48-d803-4a90-99f7-e06edcdbbf92'},
    'free_bikes': 4,
    'id': 'fdc434827095569a0617bd1eb255044a',
    'latitude': 40.780478,
    'longitude': -73.912212,
    'name': '21 Ave & Crescent St',
    'timestamp': '2023-08-29T15:03:07.976000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321295,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'ca7ec509-cefc-4ac6-b729-08999d191051'},
    'free_bikes': 4,
    'id': 'd59724dcbdac93aa20fe628abf28b5f1',
    'latitude': 40.772092,
    'longitude': -73.895166,
    'name': 'Hazen St & 20 Ave',
    'timestamp': '2023-08-29T15:03:07.838000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321331,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': 'f34ea09d-32f9-492c-9124-99059bc0b5dd'},
    'free_bikes': 20,
    'id': 'fd0f92e2b55b1f8d13158098eed865ab',
    'latitude': 40.778089,
    'longitude': -73.899558,
    'name': 'Steinway St & 19 Ave',
    'timestamp': '2023-08-29T15:03:09Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321218,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '9157a3bc-43fa-4221-8bb8-17273fc09540'},
    'free_bikes': 3,
    'id': '160e0db82e7ad769008cf4176050d0a9',
    'latitude': 40.768728,
    'longitude': -73.890745,
    'name': 'Ditmars Blvd & 79 St',
    'timestamp': '2023-08-29T15:03:08.765000Z'},
   {'empty_slots': 19,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321262,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '98af0e1d-ea33-4c6e-95fe-97846e81081e'},
    'free_bikes': 1,
    'id': 'da369a54539ac860967d94cc11a7be03',
    'latitude': 40.77028,
    'longitude': -73.893675,
    'name': '76 St & 21 Ave',
    'timestamp': '2023-08-29T15:03:08.481000Z'},
   {'empty_slots': 11,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321260,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': '9e9acfaf-0bbf-4bc2-a825-b2befb6bee55'},
    'free_bikes': 15,
    'id': '203433e5eba2054b84ad31bda0844f08',
    'latitude': 40.747968,
    'longitude': -73.996637,
    'name': '8 Ave & W 27 St',
    'timestamp': '2023-08-29T15:03:07.964000Z'},
   {'empty_slots': 39,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321315,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 43,
     'uid': '66dc7ba2-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 0,
    'id': 'b5af08d02717e2d41a6433db456bf30d',
    'latitude': 40.72938685,
    'longitude': -73.97772429,
    'name': 'E 14 St & Avenue B',
    'timestamp': '2023-08-29T15:03:07.801000Z'},
   {'empty_slots': 30,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321286,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 54,
     'uid': '348c5e65-cbc3-4da6-9856-fc253a0ba546'},
    'free_bikes': 20,
    'id': 'ee82af892d66dd7d9da02af46b7d7316',
    'latitude': 40.73153937464073,
    'longitude': -73.9853024482727,
    'name': 'E 13 St & 2 Ave',
    'timestamp': '2023-08-29T15:03:09.097000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 29,
     'uid': '6cb5fac5-f7e8-4ec9-94cf-816771d91ecd'},
    'free_bikes': 26,
    'id': '3aa004af7c409ccf3527e2f8eb94faff',
    'latitude': 40.777112,
    'longitude': -73.902382,
    'name': '20 Ave & 38 St',
    'timestamp': '2023-08-29T15:03:08.267000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321236,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'c02864f0-2611-440b-98f4-45fddfd545fe'},
    'free_bikes': 18,
    'id': 'e34eb6ee9e32849fb236add92542ad21',
    'latitude': 40.772899,
    'longitude': -73.896849,
    'name': '20 Ave & 48 St',
    'timestamp': '2023-08-29T15:03:08.500000Z'},
   {'empty_slots': 15,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321307,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '0cc38ba1-4625-4821-9a6f-e490525cbce2'},
    'free_bikes': 3,
    'id': '7640134d9d17edceea685ed1aa28d8e9',
    'latitude': 40.660906,
    'longitude': -73.983074,
    'name': 'Windsor Pl & 8 Ave',
    'timestamp': '2023-08-29T15:03:08.052000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 12,
     'has_ebikes': True,
     'last_updated': 1693321283,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '54782566-697b-497e-a503-dc1f39963eb2'},
    'free_bikes': 17,
    'id': '56597d404e3ce437fb2f883eda8a840f',
    'latitude': 40.764174520197685,
    'longitude': -73.91583994030952,
    'name': '38 St & 30 Ave',
    'timestamp': '2023-08-29T15:03:08.440000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321320,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '0eacb768-c7d5-4499-9182-9a1331d9280c'},
    'free_bikes': 23,
    'id': 'fd18598d8da48d2a2b0ea8229a938025',
    'latitude': 40.666197,
    'longitude': -73.992466,
    'name': '16th St & 4th Ave',
    'timestamp': '2023-08-29T15:03:08.956000Z'},
   {'empty_slots': 18,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321243,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '5526b855-dc09-4159-a20a-99651861a481'},
    'free_bikes': 6,
    'id': '9912b90a6f86cf3fe2b06f6a4edaf128',
    'latitude': 40.663493,
    'longitude': -73.991007,
    'name': '17 St & 5 Ave',
    'timestamp': '2023-08-29T15:03:07.909000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': '340036c3-2787-4998-9a77-fe54f352d619'},
    'free_bikes': 6,
    'id': '1314cd63a88b3c7ad322a020370b70d9',
    'latitude': 40.66016,
    'longitude': -73.990974,
    'name': '6 Ave & 21 St',
    'timestamp': '2023-08-29T15:03:09.137000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321302,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '7bdd60e9-c0fd-40f6-aa9a-d5fa004d4fe3'},
    'free_bikes': 13,
    'id': '603896ec564262da4effd848030c4b0e',
    'latitude': 40.662584,
    'longitude': -73.995554,
    'name': '21 St & 4 Ave',
    'timestamp': '2023-08-29T15:03:08.701000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 3,
     'has_ebikes': True,
     'last_updated': 1693321319,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': 'e4980fd0-e540-40ca-acba-c2a74f3294fc'},
    'free_bikes': 3,
    'id': 'd89a642cfb6a9d55954c6010462d0eb8',
    'latitude': 40.656633,
    'longitude': -73.983864,
    'name': 'Prospect Park W & 20 St',
    'timestamp': '2023-08-29T15:03:08.326000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321306,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '36b55a0f-e55d-4849-859a-09b3273fb782'},
    'free_bikes': 21,
    'id': '4e0277be70b178af6c38d28943b48965',
    'latitude': 40.662611,
    'longitude': -73.998623,
    'name': '23 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:09.231000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321252,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '0efa08a3-1c38-48fe-ab37-8c9b72b20126'},
    'free_bikes': 17,
    'id': '61be8e7723f5361480a2be2698449a5d',
    'latitude': 40.657743,
    'longitude': -74.001141,
    'name': '30 St & 4 Ave',
    'timestamp': '2023-08-29T15:03:07.798000Z'},
   {'empty_slots': 12,
    'extra': {'ebikes': 6,
     'has_ebikes': True,
     'last_updated': 1693321218,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '3f031133-ec95-4a92-9d63-2ae28183f498'},
    'free_bikes': 7,
    'id': '7e56fffce820eecf8677eb5105c36ddf',
    'latitude': 40.65629,
    'longitude': -73.977335,
    'name': '11 Ave & Prospect Ave',
    'timestamp': '2023-08-29T15:03:08.214000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321302,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': 'fd0e86e3-079d-40aa-8231-ec2cbdbd9e7f'},
    'free_bikes': 16,
    'id': 'fea1c6dc13d875d608d2285662e22a96',
    'latitude': 40.655278,
    'longitude': -74.003101,
    'name': '34 St & 4 Ave',
    'timestamp': '2023-08-29T15:03:08.029000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321328,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 31,
     'uid': '248d2318-ebbf-422d-987f-87b8602ee0d4'},
    'free_bikes': 21,
    'id': 'abf8528007df3c90bcfb9086049a3d92',
    'latitude': 40.656326,
    'longitude': -74.009627,
    'name': '2 Av & 37 St',
    'timestamp': '2023-08-29T15:03:07.826000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321321,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '8d2eff37-be09-4b46-a95d-abff89e16d56'},
    'free_bikes': 18,
    'id': '99aa613528fc8cd3aa7e176fda4d7202',
    'latitude': 40.666168,
    'longitude': -73.995549,
    'name': '3 Ave & 17 St',
    'timestamp': '2023-08-29T15:03:08.035000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321338,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'd6834194-029d-4e2d-83b0-ee78ab5acda2'},
    'free_bikes': 16,
    'id': 'bae8eb536a15b565e28d44a2db10bc9a',
    'latitude': 40.656986,
    'longitude': -73.998194,
    'name': '29 St & 5 Ave',
    'timestamp': '2023-08-29T15:03:08.840000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321281,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': 'dccab832-b4a2-4105-927d-b52ec0d92c92'},
    'free_bikes': 15,
    'id': 'aa49e51183b5dfbeec64a2fa2efa2d14',
    'latitude': 40.654098,
    'longitude': -74.001131,
    'name': '34 St & 5 Ave',
    'timestamp': '2023-08-29T15:03:09.077000Z'},
   {'empty_slots': 5,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321274,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '4d24ab76-2f4a-4004-9fc5-09c00c1d9aa4'},
    'free_bikes': 24,
    'id': 'd324a6253185bd483fa4fab93be22840',
    'latitude': 40.652657,
    'longitude': -74.002356,
    'name': '5 Ave & 37 St',
    'timestamp': '2023-08-29T15:03:07.743000Z'},
   {'empty_slots': 30,
    'extra': {'ebikes': 2,
     'has_ebikes': True,
     'last_updated': 1693321320,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 57,
     'uid': 'cdb6e2aa-4da3-4ed7-9b13-ce626addf6b0'},
    'free_bikes': 23,
    'id': '19d87c626574f6b6eea5401903ea81c8',
    'latitude': 40.741723510974715,
    'longitude': -73.97809267044067,
    'name': '2 Ave & E 29 St',
    'timestamp': '2023-08-29T15:03:07.931000Z'},
   {'empty_slots': 0,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321273,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 27,
     'uid': 'b200a8bf-2d79-4511-9a16-ac41e7245622'},
    'free_bikes': 26,
    'id': 'd2b844eb803935155ebd289e017f8884',
    'latitude': 40.659176,
    'longitude': -74.006584,
    'name': '2 Ave & 32 St',
    'timestamp': '2023-08-29T15:03:08.451000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321320,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 46,
     'uid': '3e9e50cc-f336-439f-bd0b-dec5499c038d'},
    'free_bikes': 41,
    'id': 'd193ffe1f2b11d804a23adfda41e6999',
    'latitude': 40.709267,
    'longitude': -74.013247,
    'name': 'Albany St & Greenwich St',
    'timestamp': '2023-08-29T15:03:07.934000Z'},
   {'empty_slots': 1,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321235,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '29a41b09-698f-43e2-82ff-f94f73e74841'},
    'free_bikes': 17,
    'id': '5e8ced07d6439b767fa4563a966f66ff',
    'latitude': 40.652512,
    'longitude': -74.008906,
    'name': '41 St & 3 Ave',
    'timestamp': '2023-08-29T15:03:08.684000Z'},
   {'empty_slots': 6,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321271,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '5780ae63-54e5-48e3-a00c-9c403cb75401'},
    'free_bikes': 16,
    'id': 'c1bc2006552cd372c7aa1284a7262742',
    'latitude': 40.651354,
    'longitude': -74.007168,
    'name': '41 St & 4 Ave',
    'timestamp': '2023-08-29T15:03:08.389000Z'},
   {'empty_slots': 13,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321333,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 30,
     'uid': '4eb6d6a8-ecc1-4e89-a586-4f96ed3d83e1'},
    'free_bikes': 16,
    'id': 'c2f59296b1aaea20711d2e2f936accd4',
    'latitude': 40.649983,
    'longitude': -74.005144,
    'name': '5 Ave & 41 St',
    'timestamp': '2023-08-29T15:03:09.037000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321264,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 20,
     'uid': '35a5b4d6-2d90-4b60-b68b-03bb60fb1afc'},
    'free_bikes': 1,
    'id': 'e264b8d03a951e65d5ca156616d62eb5',
    'latitude': 40.659053,
    'longitude': -73.98854,
    'name': '7 Ave & 20 St',
    'timestamp': '2023-08-29T15:03:07.774000Z'},
   {'empty_slots': 7,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321315,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 63,
     'uid': '9e3603ee-2b7d-4147-a7b5-48bbd778902c'},
    'free_bikes': 49,
    'id': '4423814816a934c78ef7128a36ba548d',
    'latitude': 40.71779817737835,
    'longitude': -73.99316132068634,
    'name': 'Forsyth St & Grand St',
    'timestamp': '2023-08-29T15:03:07.978000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321325,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '1c82b223-42ba-4d15-8e8a-bd8ae2a57cde'},
    'free_bikes': 15,
    'id': '4136a69dfaafd98435725c8aa7206573',
    'latitude': 40.659555,
    'longitude': -73.995068,
    'name': '24 St & 5 Ave',
    'timestamp': '2023-08-29T15:03:07.782000Z'},
   {'empty_slots': 21,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321237,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 25,
     'uid': '403c310e-26d5-4db5-9928-13c38b25053d'},
    'free_bikes': 2,
    'id': 'eaa9ea36f7bc5464e6a3d7066ce56a8c',
    'latitude': 40.658029,
    'longitude': -73.989605,
    'name': '7 Ave & 22 St',
    'timestamp': '2023-08-29T15:03:08.854000Z'},
   {'empty_slots': 74,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321323,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 84,
     'uid': '66dbe4db-0aca-11e7-82f6-3863bb44ef7c'},
    'free_bikes': 5,
    'id': '6ad83fd80e7705e67779021e1f729f23',
    'latitude': 40.749156,
    'longitude': -73.9916,
    'name': 'W 31 St & 7 Ave',
    'timestamp': '2023-08-29T15:03:08.839000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321319,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 19,
     'uid': '48e7e465-f861-452a-9bf7-7eacd0b2bcac'},
    'free_bikes': 15,
    'id': '70b919d8992a475d837bc10909dd51a2',
    'latitude': 40.650176,
    'longitude': -74.015606,
    'name': '48 St & 2 Ave',
    'timestamp': '2023-08-29T15:03:08.249000Z'},
   {'empty_slots': 10,
    'extra': {'ebikes': 0,
     'has_ebikes': True,
     'last_updated': 1693321299,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '7155b0a6-2545-4b02-ae8c-9c0c4220f8c3'},
    'free_bikes': 10,
    'id': 'b0121f78921cea05c41afc050cdbfb11',
    'latitude': 40.645921,
    'longitude': -74.005708,
    'name': '46 St & 6 Ave',
    'timestamp': '2023-08-29T15:03:07.875000Z'},
   {'empty_slots': 8,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321327,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 24,
     'uid': '753415aa-9bb4-4f72-bb5c-0906365177d0'},
    'free_bikes': 15,
    'id': '6522952e53d5518063e2427e7b089347',
    'latitude': 40.647105,
    'longitude': -74.004483,
    'name': '44 St & 6 Ave',
    'timestamp': '2023-08-29T15:03:08.443000Z'},
   {'empty_slots': 3,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321313,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 23,
     'uid': '3f05490b-a3d8-4d15-bd25-0212555b5dff'},
    'free_bikes': 19,
    'id': '85f8d556096d387b9c517789b4a72a96',
    'latitude': 40.649037,
    'longitude': -73.97673,
    'name': 'Ft. Hamilton Pkwy & E 5 St',
    'timestamp': '2023-08-29T15:03:09.032000Z'},
   {'empty_slots': 2,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321315,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '62e2b1dd-ca52-4e1c-a112-1d8846b9d9b5'},
    'free_bikes': 17,
    'id': 'f3a774db8c4b4e7a20afc4a48a9ecb4e',
    'latitude': 40.650739,
    'longitude': -73.977739,
    'name': 'Greenwood Ave & E 4 St',
    'timestamp': '2023-08-29T15:03:09.073000Z'},
   {'empty_slots': 16,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321317,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 33,
     'uid': 'f833d403-2cf5-424a-a3b3-0314a44b4a67'},
    'free_bikes': 14,
    'id': '43146ddbd9ba05a1fd795427bc449f56',
    'latitude': 40.711471394469264,
    'longitude': -73.98672603070736,
    'name': 'Clinton St & Cherry St',
    'timestamp': '2023-08-29T15:03:09.272000Z'},
   {'empty_slots': 17,
    'extra': {'ebikes': 1,
     'has_ebikes': True,
     'last_updated': 1693321242,
     'payment': ['key', 'creditcard'],
     'payment-terminal': True,
     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
     'renting': 1,
     'returning': 1,
     'slots': 21,
     'uid': '31f340f3-3201-449e-b017-a26813aa448f'},
    'free_bikes': 2,
    'id': '69caf37786dd7c365883bc8090fa8021',
    'latitude': 40.644743,
    'longitude': -74.003754,
    'name': '46 St & 7 Ave',
    'timestamp': '2023-08-29T15:03:08.773000Z'},
   ...]}}

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
## Putting my parsed results into a dataframe using dictionaries/for loop that I had also converted to a csv:
## Importing required libraries
import numpy as np
import pandas as pd

# %%
# Retrieving stations data from network and turning it into a dataframe

citybikes_df= pd.json_normalize(citybikes_df["network"]["stations"])
citybikes_df

# %%
# Creating Json file path for all bike stations
file_path = 'citybikes.json'

with open(file_path, 'w') as json_file:
    json.dump(res_json, json_file)

# %%
# Creating json lists for all bike stations in NYC
renting = [] 
empty_slots = [] 
returning = [] 
has_ebikes = [] 
longitude = [] 
latitude = [] 
station_names = [] 
number_of_bikes = []

# %%
# Dictionary for dataframe - creating a dataframe
import pandas as pd

dictionary = {'station_name' : station_names,
 'number_of_bikes' : number_of_bikes,
'longitude' : longitude,
'latitude' : latitude,

 }

citybikes_df=pd.DataFrame(dictionary)

citybikes_df.head()

# %%
# Adding my dictionary into a dataframe
citybikes_df=pd.DataFrame(citybikes_dict)

citybikes_df

# %%
# Converting my dataframe bike stations into a CSV
citybikes_df.to_csv('citybikes.csv')

# %%
# Will save my citybike CSV file
citybikes.to_csv(r'/Users/ibadetazemi/statistical-modeling-project-2023/Desktop/Data Science/citybikes.csv', index=False)

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
## Putting my parsed results into a pandas dataframe:

## Importing required libraries
import numpy as np
import pandas as pd

## City Bikes dataframe
​
citybikes= pd.DataFrame({'Bike Stations': ['Lexington Ave', '5TH Ave', 'W 29TH St', 'W 29TH St'],
                    'Station Name': ['Citi Bike Station', 'Citi Bike Station', 'Citi Bike Station', 'Citi Bike Station'],
                    'Slots':['1', '10', '0', '3'],
                    'Renting':['0', '12', '7', '4'],
                    'Returned':['0', '1', '10', '8'],
                    'Latitude': ['40.734786', '40.737604', '40.724605', '40.728745'],
                    'Longitude': ['-74.050444', '-74.052478', '-74.078406', '-74.032108'],
                    'Number of Bikes':[12,19,0,13]})


citybikes

# %%
# Converting my dataframe bike stations into a CSV
citybikes_df.to_csv('citybikes.csv')

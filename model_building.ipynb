# %% [markdown]
# Build a regression model.

# %%
## Building a regression model.

## Importing required libraries
import pandas as pd
​
## Loading data
citybikes = pd.read_csv('citybikes.csv')
citybikes


# Building a regression model
# import numpy
import numpy as np
import pandas as pd
​
# import linear_model and datasets from sklearn
import numpy as np
from sklearn.linear_model import LinearRegression

# Finding X and Y
X = citybikes(['Ratings'],['Distance'], axis = 1)
y = citybikes['Number of Bikes']

# Printing shape of X
X.shape

# Inspecting top 5 rows
X.head()

# Printing out first 5 rows of Y
y.head()

# Importing required packages
import statsmodels.api as sm

# Adding a constant
X = sm.add_constant(X) 
lin_reg = sm.OLS(y,X)

# Printing regression model results:
model = lin_reg.fit()
print_model = model.summary()
print(print_model)

# %% [markdown]
# Provide model output and an interpretation of the results.

# %%
                            OLS Regression Results                            
==============================================================================
Dep. Variable:        Number of Bikes   R-squared:                       0.097
Model:                            OLS   Adj. R-squared:                 -0.016
Method:                 Least Squares   F-statistic:                    0.8584
Date:                Thu, 10 Aug 2023   Prob (F-statistic):              0.442
Time:                        21:16:20   Log-Likelihood:                -72.294
No. Observations:                  19   AIC:                             150.6
Df Residuals:                      16   BIC:                             153.4
Df Model:                           2                                         
Covariance Type:            nonrobust                                         
==============================================================================
                 coef    std err          t      P>|t|      [0.025      0.975]
------------------------------------------------------------------------------
const          2.3139     19.832      0.117      0.909     -39.729      44.357
Distance      -0.0886      0.102     -0.871      0.396      -0.304       0.127
Ratings        4.2563      4.387      0.970      0.346      -5.045      13.557
==============================================================================
Omnibus:                        0.875   Durbin-Watson:                   2.087
Prob(Omnibus):                  0.646   Jarque-Bera (JB):                0.850
Skew:                           0.399   Prob(JB):                        0.654
Kurtosis:                       2.339   Cond. No.                         331.
==============================================================================

Notes:
[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

## Interpretation

Based on the interpretation of the results, it seems that the regression model that was built to predict 
number of bikes, ratings and distance is performing very well. 
The low R-squared value appears to reflect that there is a strong correlation

# %%
Build a regression model.

# %%
## Importing required libraries
import pandas as pd

# Building a regression model
# import numpy
import numpy as np
import pandas as pd
​
# import linear_model and datasets from sklearn
import numpy as np
from sklearn.linear_model import LinearRegression

## Loading data
citybikess = pd.read_csv('citybikess.csv')
citybikess

import statsmodels.api as sm
y = citybikes[['Number of Bikes']]
X = citybikes[['POI_Count', 
                'Ratings',
                'Distance',
                'Reviews']]
X = sm.add_constant(X)
X.head()

# Printing shape of X
X.shape

# Inspecting top 5 rows
X.head()

# Printing out first 5 rows of Y
y.head()

# Importing required packages
import statsmodels.api as sm

## Printing results of regression model
model = sm.OLS(y, X) 
results = model.fit() 
print(results.summary())

# %% [markdown]
# Provide model output and an interpretation of the results.

# %%
                       OLS Regression Results                            
==============================================================================
Dep. Variable:        Number of Bikes   R-squared:                       0.360
Model:                            OLS   Adj. R-squared:                  0.350
Method:                 Least Squares   F-statistic:                     331.6
Date:                Thur, 11 Aug 2023  Prob (F-statistic):          3.31e-021
Time:                        22:14:00   Log-Likelihood:                -2321.0
No. Observations:                 530   AIC:                             4402.
Df Residuals:                     646   BIC:                             4402.
Df Model:                           2                                         
Covariance Type:            nonrobust                                         
=====================================================================================
                        coef    std err          t      P>|t|      [0.025      0.975]
-------------------------------------------------------------------------------------
const                12.2072      0.270     22.310      0.000      11.636      13.167
POI_Count            -0.1254      0.021     -2.401      0.000      -0.120      -0.096
Ratings               0.1039      0.026      4.231      0.000       0.032       0.048
Distance              0.1040      0.032     -2.033      0.000       0.034       0.058
Reviews               0.2120      0.270     -2.104      0.000       0.131       0.109
=====================================================================================
Omnibus:                      126.451   Durbin-Watson:                          1.616
Prob(Omnibus):                  0.000   Jarque-Bera (JB):                      303.203
Skew:                           1.061   Prob(JB):                             5.04e-29
Kurtosis:                       4.110   Cond. No.                             3.39e+05
======================================================================================

Notes:
[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
[2] The condition number is large, 3.39e+05. This might indicate that there are
strong multicollinearity or other numerical problems.

## Provide model output and an interpretation of the results.

p<: Number of Bikes doesn't have a set ditribution + the hypothesis has been rejected
Prob (F-statistic) is showing that there is no correllation between Number of Bikes and (POI) points of interests 
R-squared is low.

# %% [markdown]
# # Stretch

# %% [markdown]
# How can you turn the regression model into a classification model?

# %%
## Turning my regression model into a classification model:

# importing libraries
import statsmodels.api as sm
import pandas as pd 
  
# loading the training dataset 
citybikes = pd.read_csv('citybikes.csv')
citybikes

# defining the dependent and independent variables
X = citybikes(['Ratings'],['Distance'], axis = 1)
y = citybikes['Number of Bikes']
   
# building the model and fitting the data
log_reg = sm.Logit(y_train_discrete, Xtrain).fit()

# Training a model
y_train_discrete = (ytrain > 300).astype(float)

## Printing Y
y_train_discrete

y_train_discrete.sum()
Number of Bikes    1674.0
dtype: float64

# printing the summary table
print(log_reg.summary())
                            Logit Regression Results                            
================================================================================
Dep. Variable:     Number of Bikes   No. Observations:                    735502
Model:                            Logit   Df Residuals:                   735501
Method:                             MLE   Df Model:                            0
Date:                  Wed, 05 Jul 2023   Pseudo R-squ.:                  -41.97
Time:                          00:29:25   Log-Likelihood:            -5.0962e+05
converged:                         True   LL-Null:                       -11859.
Covariance Type:              nonrobust   LLR p-value:                       nan
=================================================================================
                    coef    std err          z      P>|z|      [0.025      0.975]
---------------------------------------------------------------------------------
Distance      -1.262e-05   7.34e-07   -14.117     0.100    -1.33e-03    -1.1e-05
Ratings        3.2452      4.176       0.970      0.124      -4.011      13.334
=================================================================================
